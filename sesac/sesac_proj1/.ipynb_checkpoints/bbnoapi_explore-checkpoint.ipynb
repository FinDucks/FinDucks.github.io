# %%
import json
import pandas as pd
import requests
import time

#Create Empty DataFrame To Append To
wine_cols = ['Winery','Wine','Rating','Review_Count','Region','SubRegion']
wine_df = pd.DataFrame(columns=wine_cols)

#Loop
for x in range(1,10):
    r = requests.get(
        "https://www.vivino.com/api/explore/explore",
        params = {
            "currency_code":"USA",
            "min_rating":"1",
            "order_by":"price",
            "order":"asc",
            "page": 4,
            "wine_type_ids[]":"1"
        },
        headers= {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:66.0) Gecko/20100101 Firefox/66.0"
        }
    )
    results = [
        (
        t["vintage"]["wine"]["winery"]["name"], 
        f'{t["vintage"]["wine"]["name"]} {t["vintage"]["year"]}',
        t["vintage"]["statistics"]["ratings_average"],
        t["vintage"]["statistics"]["ratings_count"],
        t["vintage"]["wine"]["region"]["country"]["name"],
        t["vintage"]["wine"]["region"]["name"]
        )
        for t in r.json()["explore_vintage"]["matches"]
    ]
    temp_df = pd.DataFrame(results,columns=wine_cols)
    wine_df = wine_df.append(temp_df, ignore_index=True)

#Explore Columns To Include
wine_dict = json.loads(json.dumps(r.json()))

# %%
wine_dict
# Out:
# {'explore_vintage': {'market': {'country': 'kr',
#    'currency': {'code': 'USD',
#     'name': 'US Dollars',
#     'prefix': '$',
#     'suffix': None}},
#   'records_matched': 3173,
#   'matches': [{'vintage': {'id': 11630423,
#      'seo_name': 'dulong-reserve-saint-emilion-2013',
#      'name': 'Dulong Reserve Saint-Émilion 2013',
#      'statistics': {'status': 'Normal',
#       'ratings_count': 69,
#       'ratings_average': 3.3,
#       'labels_count': 1226,
#       'wine_ratings_count': 628,
#       'wine_ratings_average': 3.5,
#       'wine_status': 'Normal'},
#      'image': {'location': '//images.vivino.com/thumbs/xcjkIWBgQ2ayExtEwKjm_g_pl_480x640.png',
#       'variations': {'bottle_large': '//images.vivino.com/thumbs/xcjkIWBgQ2ayExtEwKjm_g_pb_x960.png',
#        'bottle_medium': '//images.vivino.com/thumbs/xcjkIWBgQ2ayExtEwKjm_g_pb_x600.png',
#        'bottle_medium_square': '//images.vivino.com/thumbs/xcjkIWBgQ2ayExtEwKjm_g_pb_600x600.png',
#        'bottle_small': '//images.vivino.com/thumbs/xcjkIWBgQ2ayExtEwKjm_g_pb_x300.png',
#        'bottle_small_square': '//images.vivino.com/thumbs/xcjkIWBgQ2ayExtEwKjm_g_pb_300x300.png',
#        'label': '//images.vivino.com/thumbs/xcjkIWBgQ2ayExtEwKjm_g_pl_480x640.png',
#        'label_large': '//images.vivino.com/thumbs/xcjkIWBgQ2ayExtEwKjm_g_pl_375x500.png',
#        'label_medium': '//images.vivino.com/thumbs/xcjkIWBgQ2ayExtEwKjm_g_pl_150x200.png',
#        'label_medium_square': '//images.vivino.com/thumbs/xcjkIWBgQ2ayExtEwKjm_g_pl_150x150.png',
#        'label_small_square': '//images.vivino.com/thumbs/xcjkIWBgQ2ayExtEwKjm_g_pl_80x80.png',
#        'large': '//images.vivino.com/thumbs/xcjkIWBgQ2ayExtEwKjm_g_pl_375x500.png',
#        'medium': '//images.vivino.com/thumbs/xcjkIWBgQ2ayExtEwKjm_g_pl_150x200.png',
#        'medium_square': '//images.vivino.com/thumbs/xcjkIWBgQ2ayExtEwKjm_g_pl_150x150.png',
#        'small_square': '//images.vivino.com/thumbs/xcjkIWBgQ2ayExtEwKjm_g_pl_80x80.png'}},
#      'wine': {'id': 1136315,
#       'name': 'Reserve Saint-Émilion',
#       'seo_name': 'reserve-saint-emilion',
#       'type_id': 1,
#       'vintage_type': 0,
#       'is_natural': False,
#       'region': {'id': 436,
#        'name': 'Saint-Émilion',
#        'name_en': '',
#        'seo_name': 'saint-emilion',
#        'country': {'code': 'fr',
#         'name': 'France',
#         'native_name': 'France',
#         'seo_name': 'france',
#         'currency': {'code': 'EUR',
#          'name': 'Euros',
#          'prefix': '€',
#          'suffix': None},
#         'regions_count': 1304,
#         'users_count': 5552423,
#         'wines_count': 568341,
#         'wineries_count': 67611,
#         'most_used_grapes': [{'id': 14,
#           'name': 'Pinot Noir',
#           'seo_name': 'pinot-noir',
#           'has_detailed_info': True,
#           'wines_count': 572334},
#          {'id': 5,
#           'name': 'Chardonnay',
#           'seo_name': 'chardonnay',
#           'has_detailed_info': True,
#           'wines_count': 604208},
#          {'id': 10,
#           'name': 'Merlot',
#           'seo_name': 'merlot',
#           'has_detailed_info': True,
#           'wines_count': 566719}]},
#        'class': {'typecast_map': {'background_image': {}, 'class': {}}},
#        'background_image': {'location': '//images.vivino.com/regions/backgrounds/FfzIrdtQS1mdPyifcUFfGQ.jpg',
#         'variations': {'large': '//thumbs.vivino.com/region_backgrounds/FfzIrdtQS1mdPyifcUFfGQ_1280x760.jpg',
#          'medium': '//thumbs.vivino.com/region_backgrounds/FfzIrdtQS1mdPyifcUFfGQ_600x356.jpg'}}},
#       'winery': {'id': 13657,
#        'name': 'Dulong',
#        'seo_name': 'dulong',
#        'status': 0,
#        'background_image': None},
#       'taste': {'structure': {'acidity': 3.348242,
#         'fizziness': None,
#         'intensity': 4.3980494,
#         'sweetness': 1.1950549,
#         'tannin': 3.3200002,
#         'user_structure_count': 9,
#         'calculated_structure_count': 40},
#        'flavor': [{'group': 'oak',
#          'stats': {'count': 15, 'score': 1304},
#          'primary_keywords': [{'id': 434, 'name': 'vanilla', 'count': 6},
#           {'id': 292, 'name': 'oak', 'count': 5},
#           {'id': 83, 'name': 'cedar', 'count': 2},
#           {'id': 422, 'name': 'tobacco', 'count': 1}],
#          'secondary_keywords': [{'id': 242, 'name': 'leather', 'count': 3},
#           {'id': 105, 'name': 'cinnamon', 'count': 1}]},
#         {'group': 'black_fruit',
#          'stats': {'count': 11, 'score': 1800},
#          'primary_keywords': [{'id': 470, 'name': 'cassis', 'count': 3},
#           {'id': 52, 'name': 'blackcurrant', 'count': 3},
#           {'id': 39, 'name': 'black fruit', 'count': 3},
#           {'id': 49, 'name': 'blackberry', 'count': 3},
#           {'id': 334, 'name': 'plum', 'count': 2},
#           {'id': 55, 'name': 'blueberry', 'count': 2},
#           {'id': 135, 'name': 'dark fruit', 'count': 2}]},
#         {'group': 'spices',
#          'stats': {'count': 11, 'score': 687},
#          'primary_keywords': [{'id': 249, 'name': 'licorice', 'count': 4},
#           {'id': 373, 'name': 'rosemary', 'count': 1},
#           {'id': 320, 'name': 'pepper', 'count': 1},
#           {'id': 105, 'name': 'cinnamon', 'count': 1}],
#          'secondary_keywords': [{'id': 434, 'name': 'vanilla', 'count': 6}]},
#         {'group': 'non_oak',
#          'stats': {'count': 8, 'score': 175},
#          'primary_keywords': [{'id': 417, 'name': 'toast', 'count': 1}],
#          'secondary_keywords': [{'id': 434, 'name': 'vanilla', 'count': 6},
#           {'id': 83, 'name': 'cedar', 'count': 2},
#           {'id': 422, 'name': 'tobacco', 'count': 1},
#           {'id': 105, 'name': 'cinnamon', 'count': 1}]},
#         {'group': 'earth',
#          'stats': {'count': 8, 'score': 701},
#          'primary_keywords': [{'id': 242, 'name': 'leather', 'count': 3},
#           {'id': 156, 'name': 'earthy', 'count': 2},
#           {'id': 276, 'name': 'minerals', 'count': 1},
#           {'id': 398, 'name': 'stone', 'count': 1}],
#          'secondary_keywords': [{'id': 422, 'name': 'tobacco', 'count': 1}]},
#         {'group': 'red_fruit',
#          'stats': {'count': 8, 'score': 800},
#          'primary_keywords': [{'id': 354, 'name': 'red fruit', 'count': 4},
#           {'id': 93, 'name': 'cherry', 'count': 1},
#           {'id': 353, 'name': 'red currant', 'count': 1},
#           {'id': 348, 'name': 'raspberry', 'count': 1},
#           {'id': 352, 'name': 'red cherry', 'count': 1}]},
#         {'group': 'microbio',
#          'stats': {'count': 2, 'score': 133},
#          'primary_keywords': [{'id': 91, 'name': 'cheese', 'count': 1}],
#          'secondary_keywords': [{'id': 417, 'name': 'toast', 'count': 1}]},
#         {'group': 'tree_fruit',
#          'stats': {'count': 1, 'score': 100},
#          'primary_keywords': [{'id': 469, 'name': 'stone fruit', 'count': 1}]},
#         {'group': 'dried_fruit',
#          'stats': {'count': 1, 'score': 100},
#          'primary_keywords': [{'id': 347, 'name': 'raisin', 'count': 1}]}]},
#       'statistics': {'status': 'Normal',
#        'ratings_count': 628,
#        'ratings_average': 3.5,
#        'labels_count': 8934,
#        'vintages_count': 31},
#       'style': {'id': 266,
#        'seo_name': 'bordeaux-right-bank-saint-emilion',
#        'regional_name': 'Bordeaux Right Bank',
#        'varietal_name': 'Saint-Émilion',
#        'name': 'Bordeaux Saint-Émilion',
#        'image': None,
#        'background_image': {'location': '//images.vivino.com/backgrounds/styles/JqMTW-DLSdK6KYE6rtaiiA.jpg',
#         'variations': {'small': '//images.vivino.com/backgrounds/styles/thumbs/JqMTW-DLSdK6KYE6rtaiiA_932x810.jpg'}},
#        'description': "Made predominantly from Merlot and Cabernet Franc, Saint-Émilion wines tend to have a rich, mouth-drying tannic structure, which is balanced by the more juicy characteristics of plum and black cherry fruit, along with chocolate and sweet spice, developing savory tobacco and cedar characteristics with age.\n\nThe best Saint-Émilion wines will exhibit a terrific mineral vein, the result of vines being planted on the region's limestone escarpment. Vines planted on sandy soils tend to produce grapes that make lighter styled wines.\n\nSituated on the right bank of Bordeaux, the region of Saint-Émilion can boast of producing the most diverse range of styles, partly due to differences in soil types, from gravel to limestone to sand, but also thanks to production variations and winemakers looking to make their mark.",
#        'blurb': None,
#        'interesting_facts': ['The village of Saint-Émilion is a UNESCO World Heritage Site.',
#         'Saint-Émilion was the first Bordeaux region to export its wines.',
#         "Saint-Émilion is Bordeaux's largest major wine-producing region.",
#         'Unlike other classified regions within Bordeaux, Saint-Émilion updates its classification roughly every 10 years.',
#         'In Saint-Émilion Cabernet Franc is referred to as Bouchet.'],
#        'body': 4,
#        'body_description': 'Full-bodied',
#        'acidity': 2,
#        'acidity_description': 'Medium',
#        'country': {'code': 'fr',
#         'name': 'France',
#         'native_name': 'France',
#         'seo_name': 'france',
#         'currency': {'code': 'EUR',
#          'name': 'Euros',
#          'prefix': '€',
#          'suffix': None},
#         'regions_count': 1304,
#         'users_count': 5552423,
#         'wines_count': 568341,
#         'wineries_count': 67611,
#         'most_used_grapes': [{'id': 14,
#           'name': 'Pinot Noir',
#           'seo_name': 'pinot-noir',
#           'has_detailed_info': True,
#           'wines_count': 572334},
#          {'id': 5,
#           'name': 'Chardonnay',
#           'seo_name': 'chardonnay',
#           'has_detailed_info': True,
#           'wines_count': 604208},
#          {'id': 10,
#           'name': 'Merlot',
#           'seo_name': 'merlot',
#           'has_detailed_info': True,
#           'wines_count': 566719}]},
#        'wine_type_id': 1,
#        'food': [{'id': 4,
#          'name': 'Beef',
#          'background_image': {'location': '//images.vivino.com/backgrounds/foods/4_beef.png',
#           'variations': {'small': '//images.vivino.com/backgrounds/foods/thumbs/4_beef_932x810.png'}},
#          'seo_name': 'beef'},
#         {'id': 8,
#          'name': 'Lamb',
#          'background_image': {'location': '//images.vivino.com/backgrounds/foods/8_lamb.png',
#           'variations': {'small': '//images.vivino.com/backgrounds/foods/thumbs/8_lamb_932x810.png'}},
#          'seo_name': 'lamb'},
#         {'id': 11,
#          'name': 'Game (deer, venison)',
#          'background_image': {'location': '//images.vivino.com/backgrounds/foods/11_venison.png',
#           'variations': {'small': '//images.vivino.com/backgrounds/foods/thumbs/11_venison_932x810.png'}},
#          'seo_name': 'game'},
#         {'id': 20,
#          'name': 'Poultry',
#          'background_image': {'location': '//images.vivino.com/backgrounds/foods/20_chicken.png',
#           'variations': {'small': '//images.vivino.com/backgrounds/foods/thumbs/20_chicken_932x810.png'}},
#          'seo_name': 'poultry'}],
#        'grapes': [{'id': 2,
#          'name': 'Cabernet Sauvignon',
#          'seo_name': 'cabernet-sauvignon',
#          'has_detailed_info': True,
#          'wines_count': 801751},
#         {'id': 3,
#          'name': 'Cabernet Franc',
#          'seo_name': 'cabernet-franc',
#          'has_detailed_info': True,
#          'wines_count': 269578},
#         {'id': 9,
#          'name': 'Malbec',
#          'seo_name': 'malbec',
#          'has_detailed_info': True,
#          'wines_count': 219735},
#         {'id': 10,
#          'name': 'Merlot',
#          'seo_name': 'merlot',
#          'has_detailed_info': True,
#          'wines_count': 566719},
#         {'id': 42,
#          'name': 'Petit Verdot',
#          'seo_name': 'petit-verdot',
#          'has_detailed_info': True,
#          'wines_count': 82567},
#         {'id': 51,
#          'name': 'Carménère',
#          'seo_name': 'carmenere',
#          'has_detailed_info': True,
#          'wines_count': 50087}],
#        'region': {'id': 383,
#         'name': 'Bordeaux',
#         'name_en': '',
#         'seo_name': 'bordeaux',
#         'country': {'code': 'fr',
#          'name': 'France',
#          'native_name': 'France',
#          'seo_name': 'france',
#          'currency': {'code': 'EUR',
#           'name': 'Euros',
#           'prefix': '€',
#           'suffix': None},
#          'regions_count': 1304,
#          'users_count': 5552423,
#          'wines_count': 568341,
#          'wineries_count': 67611,
#          'most_used_grapes': [{'id': 14,
#            'name': 'Pinot Noir',
#            'seo_name': 'pinot-noir',
#            'has_detailed_info': True,
#            'wines_count': 572334},
#           {'id': 5,
#            'name': 'Chardonnay',
#            'seo_name': 'chardonnay',
#            'has_detailed_info': True,
#            'wines_count': 604208},
#           {'id': 10,
#            'name': 'Merlot',
#            'seo_name': 'merlot',
#            'has_detailed_info': True,
#            'wines_count': 566719}]},
#         'parent_id': None,
#         'background_image': {'location': '//images.vivino.com/regions/backgrounds/3z0tiBnOSPaSk5LxoYKRYg.jpeg',
#          'variations': {'large': '//thumbs.vivino.com/region_backgrounds/3z0tiBnOSPaSk5LxoYKRYg_1280x760.jpeg',
#           'medium': '//thumbs.vivino.com/region_backgrounds/3z0tiBnOSPaSk5LxoYKRYg_600x356.jpeg'}},
#         'statistics': {'wineries_count': 13306,
#          'wines_count': 42722,
#          'sub_regions_count': 12,
#          'parent_regions_count': 0}}},
#       'has_valid_ratings': True},
#      'year': 2013,
#      'grapes': None,
#      'has_valid_ratings': True},
#     'price': {'id': 14829052,
#      'amount': 0.0336154031460408,
#      'discounted_from': None,
#      'discount_percent': None,
#      'type': 'ppc',
#      'sku': '5268',
#      'url': 'http://www.winebow.co.kr/shop/goods/goods_view.php?goodsno=5268&category=002',
#      'visibility': 1,
#      'bottle_type_id': 1,
#      'currency': {'code': 'USD',
#       'name': 'US Dollars',
#       'prefix': '$',
#       'suffix': None},
#      'bottle_type': {'id': 1,
#       'name': 'Bottle (0.75l)',
#       'short_name': 'bottle',
#       'short_name_plural': 'bottles',
#       'volume_ml': 750}},
#     'prices': [{'id': 14829052,
#       'amount': 0.0336154031460408,
#       'discounted_from': None,
#       'discount_percent': None,
#       'type': 'ppc',
#       'sku': '5268',
#       'url': 'http://www.winebow.co.kr/shop/goods/goods_view.php?goodsno=5268&category=002',
#       'visibility': 1,
#       'bottle_type_id': 1,
#       'currency': {'code': 'USD',
#        'name': 'US Dollars',
#        'prefix': '$',
#        'suffix': None},
#       'bottle_type': {'id': 1,
#        'name': 'Bottle (0.75l)',
#        'short_name': 'bottle',
#        'short_name_plural': 'bottles',
#        'volume_ml': 750}}]},
#    {'vintage': {'id': 3396181,
#      'seo_name': 'viu-manent-estate-collection-reserva-merlot-2013',
#      'name': 'Viu Manent Estate Collection Reserva Merlot 2013',
#      'statistics': {'status': 'Normal',
#       'ratings_count': 436,
#       'ratings_average': 3.3,
#       'labels_count': 2387,
#       'wine_ratings_count': 3506,
#       'wine_ratings_average': 3.4,
#       'wine_status': 'Normal'},
#      'image': {'location': '//images.vivino.com/thumbs/kjrmXrJ5QjyjzD2yI-7F-A_pl_480x640.png',
#       'variations': {'bottle_large': '//images.vivino.com/thumbs/kjrmXrJ5QjyjzD2yI-7F-A_pb_x960.png',
#        'bottle_medium': '//images.vivino.com/thumbs/kjrmXrJ5QjyjzD2yI-7F-A_pb_x600.png',
#        'bottle_medium_square': '//images.vivino.com/thumbs/kjrmXrJ5QjyjzD2yI-7F-A_pb_600x600.png',
#        'bottle_small': '//images.vivino.com/thumbs/kjrmXrJ5QjyjzD2yI-7F-A_pb_x300.png',
#        'bottle_small_square': '//images.vivino.com/thumbs/kjrmXrJ5QjyjzD2yI-7F-A_pb_300x300.png',
#        'label': '//images.vivino.com/thumbs/kjrmXrJ5QjyjzD2yI-7F-A_pl_480x640.png',
#        'label_large': '//images.vivino.com/thumbs/kjrmXrJ5QjyjzD2yI-7F-A_pl_375x500.png',
#        'label_medium': '//images.vivino.com/thumbs/kjrmXrJ5QjyjzD2yI-7F-A_pl_150x200.png',
#        'label_medium_square': '//images.vivino.com/thumbs/kjrmXrJ5QjyjzD2yI-7F-A_pl_150x150.png',
#        'label_small_square': '//images.vivino.com/thumbs/kjrmXrJ5QjyjzD2yI-7F-A_pl_80x80.png',
#        'large': '//images.vivino.com/thumbs/kjrmXrJ5QjyjzD2yI-7F-A_pl_375x500.png',
#        'medium': '//images.vivino.com/thumbs/kjrmXrJ5QjyjzD2yI-7F-A_pl_150x200.png',
#        'medium_square': '//images.vivino.com/thumbs/kjrmXrJ5QjyjzD2yI-7F-A_pl_150x150.png',
#        'small_square': '//images.vivino.com/thumbs/kjrmXrJ5QjyjzD2yI-7F-A_pl_80x80.png'}},
#      'wine': {'id': 1126932,
#       'name': 'Estate Collection Reserva Merlot',
#       'seo_name': 'estate-collection-reserva-merlot',
#       'type_id': 1,
#       'vintage_type': 0,
#       'is_natural': False,
#       'region': {'id': 737,
#        'name': 'Colchagua Valley',
#        'name_en': 'Valle de Colchagua',
#        'seo_name': 'colchagua-valley',
#        'country': {'code': 'cl',
#         'name': 'Chile',
#         'native_name': 'Chile',
#         'seo_name': 'chile',
#         'currency': {'code': 'CLP',
#          'name': 'Chiliean Peso',
#          'prefix': '$',
#          'suffix': None},
#         'regions_count': 40,
#         'users_count': 313378,
#         'wines_count': 56307,
#         'wineries_count': 5692,
#         'most_used_grapes': [{'id': 2,
#           'name': 'Cabernet Sauvignon',
#           'seo_name': 'cabernet-sauvignon',
#           'has_detailed_info': True,
#           'wines_count': 801751},
#          {'id': 51,
#           'name': 'Carménère',
#           'seo_name': 'carmenere',
#           'has_detailed_info': True,
#           'wines_count': 50087},
#          {'id': 10,
#           'name': 'Merlot',
#           'seo_name': 'merlot',
#           'has_detailed_info': True,
#           'wines_count': 566719}]},
#        'class': {'typecast_map': {'background_image': {}, 'class': {}}},
#        'background_image': {'location': '//images.vivino.com/regions/backgrounds/8zBR4VOATF-f18S-MKm1Cg.jpg',
#         'variations': {'large': '//thumbs.vivino.com/region_backgrounds/8zBR4VOATF-f18S-MKm1Cg_1280x760.jpg',
#          'medium': '//thumbs.vivino.com/region_backgrounds/8zBR4VOATF-f18S-MKm1Cg_600x356.jpg'}}},
#       'winery': {'id': 3020,
#        'name': 'Viu Manent',
#        'seo_name': 'viu-manent',
#        'status': 0,
#        'background_image': None},
#       'taste': {'structure': {'acidity': 1.8850452,
#         'fizziness': None,
#         'intensity': 3.8648508,
#         'sweetness': 2.1662664,
#         'tannin': 2.1647537,
#         'user_structure_count': 57,
#         'calculated_structure_count': 90},
#        'flavor': [{'group': 'oak',
#          'stats': {'count': 46, 'score': 6867},
#          'primary_keywords': [{'id': 292, 'name': 'oak', 'count': 28},
#           {'id': 434, 'name': 'vanilla', 'count': 22},
#           {'id': 101, 'name': 'chocolate', 'count': 11},
#           {'id': 422, 'name': 'tobacco', 'count': 8},
#           {'id': 112, 'name': 'clove', 'count': 2},
#           {'id': 117, 'name': 'coffee', 'count': 2},
#           {'id': 79, 'name': 'caramel', 'count': 1},
#           {'id': 118, 'name': 'cola', 'count': 1}],
#          'secondary_keywords': [{'id': 242, 'name': 'leather', 'count': 4},
#           {'id': 384, 'name': 'smoke', 'count': 2},
#           {'id': 105, 'name': 'cinnamon', 'count': 1},
#           {'id': 88, 'name': 'charcoal', 'count': 1}]},
#         {'group': 'black_fruit',
#          'stats': {'count': 39, 'score': 5763},
#          'primary_keywords': [{'id': 334, 'name': 'plum', 'count': 21},
#           {'id': 52, 'name': 'blackcurrant', 'count': 9},
#           {'id': 49, 'name': 'blackberry', 'count': 7},
#           {'id': 55, 'name': 'blueberry', 'count': 6},
#           {'id': 38, 'name': 'black cherry', 'count': 4},
#           {'id': 229, 'name': 'jam', 'count': 3},
#           {'id': 39, 'name': 'black fruit', 'count': 3},
#           {'id': 470, 'name': 'cassis', 'count': 2},
#           {'id': 135, 'name': 'dark fruit', 'count': 2},
#           {'id': 43, 'name': 'black plum', 'count': 1},
#           {'id': 53, 'name': 'blackcurrant jam', 'count': 1}],
#          'secondary_keywords': [{'id': 341, 'name': 'prune', 'count': 1}]},
#         {'group': 'red_fruit',
#          'stats': {'count': 33, 'score': 3800},
#          'primary_keywords': [{'id': 93, 'name': 'cherry', 'count': 15},
#           {'id': 354, 'name': 'red fruit', 'count': 7},
#           {'id': 348, 'name': 'raspberry', 'count': 6},
#           {'id': 400, 'name': 'strawberry', 'count': 4},
#           {'id': 361, 'name': 'ripe strawberry', 'count': 2},
#           {'id': 352, 'name': 'red cherry', 'count': 1},
#           {'id': 387, 'name': 'sour cherry', 'count': 1},
#           {'id': 353, 'name': 'red currant', 'count': 1}],
#          'secondary_keywords': [{'id': 38, 'name': 'black cherry', 'count': 4},
#           {'id': 229, 'name': 'jam', 'count': 3}]},
#         {'group': 'non_oak',
#          'stats': {'count': 33, 'score': 452},
#          'secondary_keywords': [{'id': 434, 'name': 'vanilla', 'count': 22},
#           {'id': 422, 'name': 'tobacco', 'count': 8},
#           {'id': 112, 'name': 'clove', 'count': 2},
#           {'id': 384, 'name': 'smoke', 'count': 2},
#           {'id': 117, 'name': 'coffee', 'count': 2},
#           {'id': 79, 'name': 'caramel', 'count': 1},
#           {'id': 118, 'name': 'cola', 'count': 1},
#           {'id': 105, 'name': 'cinnamon', 'count': 1},
#           {'id': 163, 'name': 'fig', 'count': 1}]},
#         {'group': 'spices',
#          'stats': {'count': 30, 'score': 1019},
#          'primary_keywords': [{'id': 249, 'name': 'licorice', 'count': 3},
#           {'id': 320, 'name': 'pepper', 'count': 2},
#           {'id': 159, 'name': 'eucalyptus', 'count': 1},
#           {'id': 26, 'name': 'bay leaf', 'count': 1},
#           {'id': 148, 'name': 'dried herbs', 'count': 1},
#           {'id': 105, 'name': 'cinnamon', 'count': 1}],
#          'secondary_keywords': [{'id': 434, 'name': 'vanilla', 'count': 22},
#           {'id': 112, 'name': 'clove', 'count': 2}]},
#         {'group': 'earth',
#          'stats': {'count': 15, 'score': 1021},
#          'primary_keywords': [{'id': 242, 'name': 'leather', 'count': 4},
#           {'id': 384, 'name': 'smoke', 'count': 2},
#           {'id': 398, 'name': 'stone', 'count': 1},
#           {'id': 156, 'name': 'earthy', 'count': 1},
#           {'id': 284, 'name': 'mushroom', 'count': 1},
#           {'id': 88, 'name': 'charcoal', 'count': 1}],
#          'secondary_keywords': [{'id': 422, 'name': 'tobacco', 'count': 8}]},
#         {'group': 'dried_fruit',
#          'stats': {'count': 6, 'score': 328},
#          'primary_keywords': [{'id': 347, 'name': 'raisin', 'count': 1},
#           {'id': 163, 'name': 'fig', 'count': 1},
#           {'id': 341, 'name': 'prune', 'count': 1}],
#          'secondary_keywords': [{'id': 229, 'name': 'jam', 'count': 3}]},
#         {'group': 'microbio',
#          'stats': {'count': 6, 'score': 550},
#          'primary_keywords': [{'id': 91, 'name': 'cheese', 'count': 3},
#           {'id': 123, 'name': 'cream', 'count': 2}],
#          'secondary_keywords': [{'id': 284, 'name': 'mushroom', 'count': 1}]},
#         {'group': 'floral',
#          'stats': {'count': 4, 'score': 400},
#          'primary_keywords': [{'id': 436, 'name': 'violet', 'count': 4}]},
#         {'group': 'vegetal',
#          'stats': {'count': 3, 'score': 300},
#          'primary_keywords': [{'id': 425, 'name': 'tomato', 'count': 1},
#           {'id': 193, 'name': 'grass', 'count': 1},
#           {'id': 89, 'name': 'chard', 'count': 1}]},
#         {'group': 'tree_fruit',
#          'stats': {'count': 1, 'score': 100},
#          'primary_keywords': [{'id': 310, 'name': 'peach', 'count': 1}]}]},
#       'statistics': {'status': 'Normal',
#        'ratings_count': 3506,
#        'ratings_average': 3.4,
#        'labels_count': 30997,
#        'vintages_count': 34},
#       'style': {'id': 113,
#        'seo_name': 'chilean-merlot',
#        'regional_name': 'Chilean',
#        'varietal_name': 'Merlot',
#        'name': 'Chilean Merlot',
#        'image': None,
#        'background_image': None,
#        'description': "Merlot is a staple of the wine producing regions of South America. Alongside Cabernet Sauvignon and Carménère, the bold, spicy grape contributes to Chile's reputation for creating great, affordable wine.\n\nChilean Merlot tends to be full-bodied yet gentle, relatively low in alcohol yet with a bracing acidity, and it often has a divisive “green” characteristic to it.\n\nThis iconic Bordeaux grape was first brought to South America in the 19th century, yet only really came into its own during a massive surge in the consumption of Chilean and Argentinian wine in the 90s.\n\nIn 1994 it was discovered that much of what was thought to be Merlot was actually Carménère, an almost identical grape native to France that growers more or less turned their back on due to its relatively low yields.\n\nThe best Merlot in Chile grows in the Apalta region in the Colchagua province. The grape thrives in many countries around the world, and enjoys a subtle yet compelling variance from climate to climate.\n\nChilean Merlot can stand up to strong flavors fairly well, so pair with a big red-sauce Italian meal, some meatballs, a bit of roasted turkey or even a good pizza.",
#        'blurb': None,
#        'interesting_facts': ['All Merlot sales took a fairly sizeable hit when the 2004 movie Sideways was released.',
#         'The grape is one of the principal varietals used in Bordeaux blends.',
#         'Merlot is a thin-skinned grape and typically tends to ripen faster than Cabernet Sauvignon.'],
#        'body': 4,
#        'body_description': 'Full-bodied',
#        'acidity': 3,
#        'acidity_description': 'High',
#        'country': {'code': 'cl',
#         'name': 'Chile',
#         'native_name': 'Chile',
#         'seo_name': 'chile',
#         'currency': {'code': 'CLP',
#          'name': 'Chiliean Peso',
#          'prefix': '$',
#          'suffix': None},
#         'regions_count': 40,
#         'users_count': 313378,
#         'wines_count': 56307,
#         'wineries_count': 5692,
#         'most_used_grapes': [{'id': 2,
#           'name': 'Cabernet Sauvignon',
#           'seo_name': 'cabernet-sauvignon',
#           'has_detailed_info': True,
#           'wines_count': 801751},
#          {'id': 51,
#           'name': 'Carménère',
#           'seo_name': 'carmenere',
#           'has_detailed_info': True,
#           'wines_count': 50087},
#          {'id': 10,
#           'name': 'Merlot',
#           'seo_name': 'merlot',
#           'has_detailed_info': True,
#           'wines_count': 566719}]},
#        'wine_type_id': 1,
#        'food': [{'id': 4,
#          'name': 'Beef',
#          'background_image': {'location': '//images.vivino.com/backgrounds/foods/4_beef.png',
#           'variations': {'small': '//images.vivino.com/backgrounds/foods/thumbs/4_beef_932x810.png'}},
#          'seo_name': 'beef'},
#         {'id': 8,
#          'name': 'Lamb',
#          'background_image': {'location': '//images.vivino.com/backgrounds/foods/8_lamb.png',
#           'variations': {'small': '//images.vivino.com/backgrounds/foods/thumbs/8_lamb_932x810.png'}},
#          'seo_name': 'lamb'},
#         {'id': 9,
#          'name': 'Veal',
#          'background_image': {'location': '//images.vivino.com/backgrounds/foods/9_veal.png',
#           'variations': {'small': '//images.vivino.com/backgrounds/foods/thumbs/9_veal_932x810.png'}},
#          'seo_name': 'veal'}],
#        'grapes': [{'id': 10,
#          'name': 'Merlot',
#          'seo_name': 'merlot',
#          'has_detailed_info': True,
#          'wines_count': 566719}],
#        'region': None},
#       'has_valid_ratings': True},
#      'year': 2013,
#      'grapes': None,
#      'has_valid_ratings': True},
#     'price': {'id': 14829053,
#      'amount': 0.0147067388763928,
#      'discounted_from': None,
#      'discount_percent': None,
#      'type': 'ppc',
#      'sku': '5310',
#      'url': 'http://www.winebow.co.kr/shop/goods/goods_view.php?goodsno=5310&category=002',
#      'visibility': 1,
#      'bottle_type_id': 1,
#      'currency': {'code': 'USD',
#       'name': 'US Dollars',
#       'prefix': '$',
#       'suffix': None},
#      'bottle_type': {'id': 1,
#       'name': 'Bottle (0.75l)',
#       'short_name': 'bottle',
#       'short_name_plural': 'bottles',
#       'volume_ml': 750}},
#     'prices': [{'id': 14829053,
#       'amount': 0.0147067388763928,
#       'discounted_from': None,
#       'discount_percent': None,
#       'type': 'ppc',
#       'sku': '5310',
#       'url': 'http://www.winebow.co.kr/shop/goods/goods_view.php?goodsno=5310&category=002',
#       'visibility': 1,
#       'bottle_type_id': 1,
#       'currency': {'code': 'USD',
#        'name': 'US Dollars',
#        'prefix': '$',
#        'suffix': None},
#       'bottle_type': {'id': 1,
#        'name': 'Bottle (0.75l)',
#        'short_name': 'bottle',
#        'short_name_plural': 'bottles',
#        'volume_ml': 750}}]},
#    {'vintage': {'id': 2674893,
#      'seo_name': 'domaine-perrot-minot-charmes-chambertin-grand-cru-2007',
#      'name': 'Domaine Perrot-Minot Charmes-Chambertin Grand Cru 2007',
#      'statistics': {'status': 'Normal',
#       'ratings_count': 66,
#       'ratings_average': 4.5,
#       'labels_count': 307,
#       'wine_ratings_count': 754,
#       'wine_ratings_average': 4.4,
#       'wine_status': 'Normal'},
#      'image': {'location': '//images.vivino.com/thumbs/ELOywF5zQRWOpsVX3gOE1w_pl_480x640.png',
#       'variations': {'bottle_large': '//images.vivino.com/thumbs/ELOywF5zQRWOpsVX3gOE1w_pb_x960.png',
#        'bottle_medium': '//images.vivino.com/thumbs/ELOywF5zQRWOpsVX3gOE1w_pb_x600.png',
#        'bottle_medium_square': '//images.vivino.com/thumbs/ELOywF5zQRWOpsVX3gOE1w_pb_600x600.png',
#        'bottle_small': '//images.vivino.com/thumbs/ELOywF5zQRWOpsVX3gOE1w_pb_x300.png',
#        'bottle_small_square': '//images.vivino.com/thumbs/ELOywF5zQRWOpsVX3gOE1w_pb_300x300.png',
#        'label': '//images.vivino.com/thumbs/ELOywF5zQRWOpsVX3gOE1w_pl_480x640.png',
#        'label_large': '//images.vivino.com/thumbs/ELOywF5zQRWOpsVX3gOE1w_pl_375x500.png',
#        'label_medium': '//images.vivino.com/thumbs/ELOywF5zQRWOpsVX3gOE1w_pl_150x200.png',
#        'label_medium_square': '//images.vivino.com/thumbs/ELOywF5zQRWOpsVX3gOE1w_pl_150x150.png',
#        'label_small_square': '//images.vivino.com/thumbs/ELOywF5zQRWOpsVX3gOE1w_pl_80x80.png',
#        'large': '//images.vivino.com/thumbs/ELOywF5zQRWOpsVX3gOE1w_pl_375x500.png',
#        'medium': '//images.vivino.com/thumbs/ELOywF5zQRWOpsVX3gOE1w_pl_150x200.png',
#        'medium_square': '//images.vivino.com/thumbs/ELOywF5zQRWOpsVX3gOE1w_pl_150x150.png',
#        'small_square': '//images.vivino.com/thumbs/ELOywF5zQRWOpsVX3gOE1w_pl_80x80.png'}},
#      'wine': {'id': 1270154,
#       'name': 'Charmes-Chambertin Grand Cru',
#       'seo_name': 'charmes-chambertin-grand-cru',
#       'type_id': 1,
#       'vintage_type': 0,
#       'is_natural': False,
#       'region': {'id': 2204,
#        'name': 'Charmes-Chambertin Grand Cru',
#        'name_en': 'Charmes-Chambertin',
#        'seo_name': 'charmes-chambertin',
#        'country': {'code': 'fr',
#         'name': 'France',
#         'native_name': 'France',
#         'seo_name': 'france',
#         'currency': {'code': 'EUR',
#          'name': 'Euros',
#          'prefix': '€',
#          'suffix': None},
#         'regions_count': 1304,
#         'users_count': 5552423,
#         'wines_count': 568341,
#         'wineries_count': 67611,
#         'most_used_grapes': [{'id': 14,
#           'name': 'Pinot Noir',
#           'seo_name': 'pinot-noir',
#           'has_detailed_info': True,
#           'wines_count': 572334},
#          {'id': 5,
#           'name': 'Chardonnay',
#           'seo_name': 'chardonnay',
#           'has_detailed_info': True,
#           'wines_count': 604208},
#          {'id': 10,
#           'name': 'Merlot',
#           'seo_name': 'merlot',
#           'has_detailed_info': True,
#           'wines_count': 566719}]},
#        'class': {'typecast_map': {'background_image': {}, 'class': {}}},
#        'background_image': None},
#       'winery': {'id': 1555,
#        'name': 'Domaine Perrot-Minot',
#        'seo_name': 'domaine-perrot-minot',
#        'status': 0,
#        'background_image': None},
#       'taste': {'structure': {'acidity': 4.142918,
#         'fizziness': None,
#         'intensity': 2.9081469,
#         'sweetness': 1.8789289,
#         'tannin': 2.4771507,
#         'user_structure_count': 55,
#         'calculated_structure_count': 55},
#        'flavor': [{'group': 'red_fruit',
#          'stats': {'count': 44, 'score': 7941},
#          'primary_keywords': [{'id': 93, 'name': 'cherry', 'count': 26},
#           {'id': 348, 'name': 'raspberry', 'count': 17},
#           {'id': 400, 'name': 'strawberry', 'count': 14},
#           {'id': 354, 'name': 'red fruit', 'count': 12},
#           {'id': 352, 'name': 'red cherry', 'count': 3},
#           {'id': 387, 'name': 'sour cherry', 'count': 2},
#           {'id': 122, 'name': 'cranberry', 'count': 1},
#           {'id': 452, 'name': 'wild strawberry', 'count': 1},
#           {'id': 361, 'name': 'ripe strawberry', 'count': 1},
#           {'id': 353, 'name': 'red currant', 'count': 1},
#           {'id': 357, 'name': 'red plum', 'count': 1}],
#          'secondary_keywords': [{'id': 229, 'name': 'jam', 'count': 1},
#           {'id': 335, 'name': 'plum sauce', 'count': 1},
#           {'id': 38, 'name': 'black cherry', 'count': 1}]},
#         {'group': 'oak',
#          'stats': {'count': 37, 'score': 3824},
#          'primary_keywords': [{'id': 292, 'name': 'oak', 'count': 17},
#           {'id': 422, 'name': 'tobacco', 'count': 6},
#           {'id': 434, 'name': 'vanilla', 'count': 3},
#           {'id': 83, 'name': 'cedar', 'count': 3},
#           {'id': 79, 'name': 'caramel', 'count': 2},
#           {'id': 21, 'name': 'baking spice', 'count': 1},
#           {'id': 118, 'name': 'cola', 'count': 1},
#           {'id': 280, 'name': 'mocha', 'count': 1},
#           {'id': 112, 'name': 'clove', 'count': 1},
#           {'id': 117, 'name': 'coffee', 'count': 1},
#           {'id': 275, 'name': 'milk chocolate', 'count': 1},
#           {'id': 101, 'name': 'chocolate', 'count': 1}],
#          'secondary_keywords': [{'id': 242, 'name': 'leather', 'count': 10},
#           {'id': 384, 'name': 'smoke', 'count': 8},
#           {'id': 105, 'name': 'cinnamon', 'count': 1},
#           {'id': 6, 'name': 'almond', 'count': 1},
#           {'id': 267, 'name': 'marzipan', 'count': 1},
#           {'id': 113, 'name': 'cocoa', 'count': 1}]},
#         {'group': 'earth',
#          'stats': {'count': 36, 'score': 4517},
#          'primary_keywords': [{'id': 242, 'name': 'leather', 'count': 10},
#           {'id': 430, 'name': 'truffle', 'count': 9},
#           {'id': 276, 'name': 'minerals', 'count': 9},
#           {'id': 384, 'name': 'smoke', 'count': 8},
#           {'id': 156, 'name': 'earthy', 'count': 6},
#           {'id': 165, 'name': 'forest floor', 'count': 2},
#           {'id': 284, 'name': 'mushroom', 'count': 2},
#           {'id': 149, 'name': 'dried leaves', 'count': 2},
#           {'id': 178, 'name': 'game', 'count': 1},
#           {'id': 47, 'name': 'black truffle', 'count': 1},
#           {'id': 113, 'name': 'cocoa', 'count': 1},
#           {'id': 22, 'name': 'balsamic', 'count': 1}],
#          'secondary_keywords': [{'id': 422, 'name': 'tobacco', 'count': 6},
#           {'id': 280, 'name': 'mocha', 'count': 1},
#           {'id': 6, 'name': 'almond', 'count': 1},
#           {'id': 267, 'name': 'marzipan', 'count': 1},
#           {'id': 381, 'name': 'savory', 'count': 1}]},
#         {'group': 'non_oak',
#          'stats': {'count': 25, 'score': 604},
#          'primary_keywords': [{'id': 312, 'name': 'peanut', 'count': 1},
#           {'id': 6, 'name': 'almond', 'count': 1},
#           {'id': 267, 'name': 'marzipan', 'count': 1}],
#          'secondary_keywords': [{'id': 384, 'name': 'smoke', 'count': 8},
#           {'id': 422, 'name': 'tobacco', 'count': 6},
#           {'id': 434, 'name': 'vanilla', 'count': 3},
#           {'id': 83, 'name': 'cedar', 'count': 3},
#           {'id': 149, 'name': 'dried leaves', 'count': 2},
#           {'id': 163, 'name': 'fig', 'count': 2},
#           {'id': 79, 'name': 'caramel', 'count': 2},
#           {'id': 118, 'name': 'cola', 'count': 1},
#           {'id': 280, 'name': 'mocha', 'count': 1},
#           {'id': 105, 'name': 'cinnamon', 'count': 1},
#           {'id': 112, 'name': 'clove', 'count': 1},
#           {'id': 117, 'name': 'coffee', 'count': 1}]},
#         {'group': 'black_fruit',
#          'stats': {'count': 19, 'score': 2543},
#          'primary_keywords': [{'id': 470, 'name': 'cassis', 'count': 6},
#           {'id': 49, 'name': 'blackberry', 'count': 5},
#           {'id': 334, 'name': 'plum', 'count': 4},
#           {'id': 39, 'name': 'black fruit', 'count': 4},
#           {'id': 55, 'name': 'blueberry', 'count': 2},
#           {'id': 229, 'name': 'jam', 'count': 1},
#           {'id': 56, 'name': 'boysenberry', 'count': 1},
#           {'id': 38, 'name': 'black cherry', 'count': 1},
#           {'id': 135, 'name': 'dark fruit', 'count': 1},
#           {'id': 335, 'name': 'plum sauce', 'count': 1}]},
#         {'group': 'microbio',
#          'stats': {'count': 14, 'score': 735},
#          'primary_keywords': [{'id': 91, 'name': 'cheese', 'count': 2},
#           {'id': 123, 'name': 'cream', 'count': 1},
#           {'id': 404, 'name': 'sweaty', 'count': 1}],
#          'secondary_keywords': [{'id': 430, 'name': 'truffle', 'count': 9},
#           {'id': 284, 'name': 'mushroom', 'count': 2},
#           {'id': 6, 'name': 'almond', 'count': 1}]},
#         {'group': 'spices',
#          'stats': {'count': 12, 'score': 912},
#          'primary_keywords': [{'id': 249, 'name': 'licorice', 'count': 5},
#           {'id': 105, 'name': 'cinnamon', 'count': 1},
#           {'id': 416, 'name': 'thyme', 'count': 1},
#           {'id': 277, 'name': 'mint', 'count': 1},
#           {'id': 148, 'name': 'dried herbs', 'count': 1},
#           {'id': 381, 'name': 'savory', 'count': 1}],
#          'secondary_keywords': [{'id': 434, 'name': 'vanilla', 'count': 3},
#           {'id': 112, 'name': 'clove', 'count': 1}]},
#         {'group': 'floral',
#          'stats': {'count': 11, 'score': 1125},
#          'primary_keywords': [{'id': 241, 'name': 'lavender', 'count': 5},
#           {'id': 322, 'name': 'perfume', 'count': 3},
#           {'id': 299, 'name': 'orange blossom', 'count': 1},
#           {'id': 371, 'name': 'rose petal', 'count': 1},
#           {'id': 436, 'name': 'violet', 'count': 1}],
#          'secondary_keywords': [{'id': 381, 'name': 'savory', 'count': 1}]},
#         {'group': 'vegetal',
#          'stats': {'count': 5, 'score': 201},
#          'primary_keywords': [{'id': 425, 'name': 'tomato', 'count': 1}],
#          'secondary_keywords': [{'id': 149,
#            'name': 'dried leaves',
#            'count': 2},
#           {'id': 6, 'name': 'almond', 'count': 1},
#           {'id': 381, 'name': 'savory', 'count': 1}]},
#         {'group': 'dried_fruit',
#          'stats': {'count': 3, 'score': 198},
#          'primary_keywords': [{'id': 163, 'name': 'fig', 'count': 2}],
#          'secondary_keywords': [{'id': 229, 'name': 'jam', 'count': 1}]},
#         {'group': 'citrus_fruit',
#          'stats': {'count': 2, 'score': 200},
#          'primary_keywords': [{'id': 298, 'name': 'orange', 'count': 1},
#           {'id': 106, 'name': 'citrus', 'count': 1}]},
#         {'group': 'tropical_fruit',
#          'stats': {'count': 1, 'score': 100},
#          'primary_keywords': [{'id': 256, 'name': 'lychee', 'count': 1}]},
#         {'group': 'tree_fruit',
#          'stats': {'count': 1, 'score': 100},
#          'primary_keywords': [{'id': 220,
#            'name': 'honeydew melon',
#            'count': 1}]}]},
#       'statistics': {'status': 'Normal',
#        'ratings_count': 754,
#        'ratings_average': 4.4,
#        'labels_count': 3870,
#        'vintages_count': 47},
#       'style': {'id': 283,
#        'seo_name': 'burgundy-cote-de-nuits-red',
#        'regional_name': 'Burgundy',
#        'varietal_name': 'Côte de Nuits Red',
#        'name': 'Burgundy Côte de Nuits Red',
#        'image': None,
#        'background_image': None,
#        'description': None,
#        'blurb': None,
#        'interesting_facts': None,
#        'body': 3,
#        'body_description': 'Medium-bodied',
#        'acidity': 3,
#        'acidity_description': 'High',
#        'country': {'code': 'fr',
#         'name': 'France',
#         'native_name': 'France',
#         'seo_name': 'france',
#         'currency': {'code': 'EUR',
#          'name': 'Euros',
#          'prefix': '€',
#          'suffix': None},
#         'regions_count': 1304,
#         'users_count': 5552423,
#         'wines_count': 568341,
#         'wineries_count': 67611,
#         'most_used_grapes': [{'id': 14,
#           'name': 'Pinot Noir',
#           'seo_name': 'pinot-noir',
#           'has_detailed_info': True,
#           'wines_count': 572334},
#          {'id': 5,
#           'name': 'Chardonnay',
#           'seo_name': 'chardonnay',
#           'has_detailed_info': True,
#           'wines_count': 604208},
#          {'id': 10,
#           'name': 'Merlot',
#           'seo_name': 'merlot',
#           'has_detailed_info': True,
#           'wines_count': 566719}]},
#        'wine_type_id': 1,
#        'food': [{'id': 4,
#          'name': 'Beef',
#          'background_image': {'location': '//images.vivino.com/backgrounds/foods/4_beef.png',
#           'variations': {'small': '//images.vivino.com/backgrounds/foods/thumbs/4_beef_932x810.png'}},
#          'seo_name': 'beef'},
#         {'id': 9,
#          'name': 'Veal',
#          'background_image': {'location': '//images.vivino.com/backgrounds/foods/9_veal.png',
#           'variations': {'small': '//images.vivino.com/backgrounds/foods/thumbs/9_veal_932x810.png'}},
#          'seo_name': 'veal'},
#         {'id': 11,
#          'name': 'Game (deer, venison)',
#          'background_image': {'location': '//images.vivino.com/backgrounds/foods/11_venison.png',
#           'variations': {'small': '//images.vivino.com/backgrounds/foods/thumbs/11_venison_932x810.png'}},
#          'seo_name': 'game'},
#         {'id': 20,
#          'name': 'Poultry',
#          'background_image': {'location': '//images.vivino.com/backgrounds/foods/20_chicken.png',
#           'variations': {'small': '//images.vivino.com/backgrounds/foods/thumbs/20_chicken_932x810.png'}},
#          'seo_name': 'poultry'}],
#        'grapes': [{'id': 14,
#          'name': 'Pinot Noir',
#          'seo_name': 'pinot-noir',
#          'has_detailed_info': True,
#          'wines_count': 572334}],
#        'region': {'id': 408,
#         'name': 'Côte de Nuits',
#         'name_en': '',
#         'seo_name': 'cote-de-nuits',
#         'country': {'code': 'fr',
#          'name': 'France',
#          'native_name': 'France',
#          'seo_name': 'france',
#          'currency': {'code': 'EUR',
#           'name': 'Euros',
#           'prefix': '€',
#           'suffix': None},
#          'regions_count': 1304,
#          'users_count': 5552423,
#          'wines_count': 568341,
#          'wineries_count': 67611,
#          'most_used_grapes': [{'id': 14,
#            'name': 'Pinot Noir',
#            'seo_name': 'pinot-noir',
#            'has_detailed_info': True,
#            'wines_count': 572334},
#           {'id': 5,
#            'name': 'Chardonnay',
#            'seo_name': 'chardonnay',
#            'has_detailed_info': True,
#            'wines_count': 604208},
#           {'id': 10,
#            'name': 'Merlot',
#            'seo_name': 'merlot',
#            'has_detailed_info': True,
#            'wines_count': 566719}]},
#         'parent_id': 385,
#         'background_image': {'location': '//images.vivino.com/regions/backgrounds/oTEcWwUcTWqCOoJmNa_J7w.jpg',
#          'variations': {'large': '//thumbs.vivino.com/region_backgrounds/oTEcWwUcTWqCOoJmNa_J7w_1280x760.jpg',
#           'medium': '//thumbs.vivino.com/region_backgrounds/oTEcWwUcTWqCOoJmNa_J7w_600x356.jpg'}},
#         'statistics': {'wineries_count': 763,
#          'wines_count': 6923,
#          'sub_regions_count': 11,
#          'parent_regions_count': 1}}},
#       'has_valid_ratings': True},
#      'year': 2007,
#      'grapes': None,
#      'has_valid_ratings': True},
#     'price': {'id': 25459162,
#      'amount': 0.4930259128085978,
#      'discounted_from': None,
#      'discount_percent': None,
#      'type': 'ppc',
#      'sku': '13014',
#      'url': 'http://www.winebow.co.kr/shop/goods/goods_view.php?goodsno=13014&category=002',
#      'visibility': 1,
#      'bottle_type_id': 1,
#      'currency': {'code': 'USD',
#       'name': 'US Dollars',
#       'prefix': '$',
#       'suffix': None},
#      'bottle_type': {'id': 1,
#       'name': 'Bottle (0.75l)',
#       'short_name': 'bottle',
#       'short_name_plural': 'bottles',
#       'volume_ml': 750}},
#     'prices': [{'id': 25459162,
#       'amount': 0.4930259128085978,
#       'discounted_from': None,
#       'discount_percent': None,
#       'type': 'ppc',
#       'sku': '13014',
#       'url': 'http://www.winebow.co.kr/shop/goods/goods_view.php?goodsno=13014&category=002',
#       'visibility': 1,
#       'bottle_type_id': 1,
#       'currency': {'code': 'USD',
#        'name': 'US Dollars',
#        'prefix': '$',
#        'suffix': None},
#       'bottle_type': {'id': 1,
#        'name': 'Bottle (0.75l)',
#        'short_name': 'bottle',
#        'short_name_plural': 'bottles',
#        'volume_ml': 750}}]},
#    {'vintage': {'id': 109662288,
#      'seo_name': 'les-grandes-serres-la-cour-des-papes-chateauneuf-du-pape-2016',
#      'name': 'Les Grandes Serres La Cour des Papes Châteauneuf-du-Pape 2016',
#      'statistics': {'status': 'Normal',
#       'ratings_count': 584,
#       'ratings_average': 3.9,
#       'labels_count': 7066,
#       'wine_ratings_count': 2668,
#       'wine_ratings_average': 3.9,
#       'wine_status': 'Normal'},
#      'image': {'location': '//images.vivino.com/labels/0mSUWiOySke2xLCUA0d4nQ.jpg',
#       'variations': {'large': '//images.vivino.com/thumbs/0mSUWiOySke2xLCUA0d4nQ_375x500.jpg',
#        'medium': '//images.vivino.com/thumbs/0mSUWiOySke2xLCUA0d4nQ_150x200.jpg',
#        'medium_square': '//images.vivino.com/thumbs/0mSUWiOySke2xLCUA0d4nQ_150x150.jpg',
#        'small_square': '//images.vivino.com/thumbs/0mSUWiOySke2xLCUA0d4nQ_80x80.jpg'}},
#      'wine': {'id': 1102945,
#       'name': 'La Cour des Papes Châteauneuf-du-Pape',
#       'seo_name': 'la-cour-des-papes-chateauneuf-du-pape',
#       'type_id': 1,
#       'vintage_type': 0,
#       'is_natural': False,
#       'region': {'id': 401,
#        'name': 'Châteauneuf-du-Pape',
#        'name_en': '',
#        'seo_name': 'chateauneuf-du-pape',
#        'country': {'code': 'fr',
#         'name': 'France',
#         'native_name': 'France',
#         'seo_name': 'france',
#         'currency': {'code': 'EUR',
#          'name': 'Euros',
#          'prefix': '€',
#          'suffix': None},
#         'regions_count': 1304,
#         'users_count': 5552423,
#         'wines_count': 568341,
#         'wineries_count': 67611,
#         'most_used_grapes': [{'id': 14,
#           'name': 'Pinot Noir',
#           'seo_name': 'pinot-noir',
#           'has_detailed_info': True,
#           'wines_count': 572334},
#          {'id': 5,
#           'name': 'Chardonnay',
#           'seo_name': 'chardonnay',
#           'has_detailed_info': True,
#           'wines_count': 604208},
#          {'id': 10,
#           'name': 'Merlot',
#           'seo_name': 'merlot',
#           'has_detailed_info': True,
#           'wines_count': 566719}]},
#        'class': {'typecast_map': {'background_image': {}, 'class': {}}},
#        'background_image': {'location': '//images.vivino.com/regions/backgrounds/5ZnLxlyTQJmWvI6GI9Bzdw.jpg',
#         'variations': {'large': '//thumbs.vivino.com/region_backgrounds/5ZnLxlyTQJmWvI6GI9Bzdw_1280x760.jpg',
#          'medium': '//thumbs.vivino.com/region_backgrounds/5ZnLxlyTQJmWvI6GI9Bzdw_600x356.jpg'}}},
#       'winery': {'id': 6882,
#        'name': 'Les Grandes Serres',
#        'seo_name': 'les-grandes-serres',
#        'status': 0,
#        'background_image': None},
#       'taste': {'structure': {'acidity': 3.0727909,
#         'fizziness': None,
#         'intensity': 4.6626816,
#         'sweetness': 1.526619,
#         'tannin': 2.7445278,
#         'user_structure_count': 49,
#         'calculated_structure_count': 118},
#        'flavor': [{'group': 'oak',
#          'stats': {'count': 71, 'score': 9265},
#          'primary_keywords': [{'id': 292, 'name': 'oak', 'count': 41},
#           {'id': 101, 'name': 'chocolate', 'count': 23},
# ...
#          'seo_name': 'beef'},
#         {'id': 9,
#          'name': 'Veal',
#          'background_image': {'location': '//images.vivino.com/backgrounds/foods/9_veal.png',
#           'variations': {'small': '//images.vivino.com/backgrounds/foods/thumbs/9_veal_932x810.png'}},
#          'seo_name': 'veal'},
#         {'id': 11,
#          'name': 'Game (deer, venison)',
#          'background_image': {'location': '//images.vivino.com/backgrounds/foods/11_venison.png',
#           'variations': {'small': '//images.vivino.com/backgrounds/foods/thumbs/11_venison_932x810.png'}},
#          'seo_name': 'game'},
#         {'id': 20,
#          'name': 'Poultry',
#          'background_image': {'location': '//images.vivino.com/backgrounds/foods/20_chicken.png',
#           'variations': {'small': '//images.vivino.com/backgrounds/foods/thumbs/20_chicken_932x810.png'}},
#          'seo_name': 'poultry'}],
#        'grapes': [{'id': 14,
#          'name': 'Pinot Noir',
#          'seo_name': 'pinot-noir',
#          'has_detailed_info': True,
#          'wines_count': 572334}],
#        'region': {'id': 45,
#         'name': 'Oregon',
#         'name_en': '',
#         'seo_name': 'oregon',
#         'country': {'code': 'us',
#          'name': 'United States',
#          'native_name': 'United States',
#          'seo_name': 'united-states',
#          'currency': {'code': 'USD',
#           'name': 'US Dollars',
#           'prefix': '$',
#           'suffix': None},
#          'regions_count': 361,
#          'users_count': 11751644,
#          'wines_count': 257016,
#          'wineries_count': 27952,
#          'most_used_grapes': [{'id': 2,
#            'name': 'Cabernet Sauvignon',
#            'seo_name': 'cabernet-sauvignon',
#            'has_detailed_info': True,
#            'wines_count': 801751},
#           {'id': 14,
#            'name': 'Pinot Noir',
#            'seo_name': 'pinot-noir',
#            'has_detailed_info': True,
#            'wines_count': 572334},
#           {'id': 5,
#            'name': 'Chardonnay',
#            'seo_name': 'chardonnay',
#            'has_detailed_info': True,
#            'wines_count': 604208}]},
#         'parent_id': None,
#         'background_image': {'location': '//images.vivino.com/regions/backgrounds/wQYqySNGQHOcNzoY02bZJg.jpg',
#          'variations': {'large': '//thumbs.vivino.com/region_backgrounds/wQYqySNGQHOcNzoY02bZJg_1280x760.jpg',
#           'medium': '//thumbs.vivino.com/region_backgrounds/wQYqySNGQHOcNzoY02bZJg_600x356.jpg'}},
#         'class': {'typecast_map': {'background_image': {}, 'class': {}}},
#         'statistics': {'wineries_count': 1303,
#          'wines_count': 7951,
#          'sub_regions_count': 6,
#          'parent_regions_count': 0}}},
#       'has_valid_ratings': True},
#      'year': 2010,
#      'grapes': None,
#      'has_valid_ratings': True},
#     'price': {'id': 12963239,
#      'amount': 0.0840385078651019,
#      'discounted_from': None,
#      'discount_percent': None,
#      'type': 'ppc',
#      'sku': '6820',
#      'url': 'http://www.winebow.co.kr/shop/goods/goods_view.php?goodsno=6820&category=002',
#      'visibility': 1,
#      'bottle_type_id': 1,
#      'currency': {'code': 'USD',
#       'name': 'US Dollars',
#       'prefix': '$',
#       'suffix': None},
#      'bottle_type': {'id': 1,
#       'name': 'Bottle (0.75l)',
#       'short_name': 'bottle',
#       'short_name_plural': 'bottles',
#       'volume_ml': 750}},
#     'prices': [{'id': 12963239,
#       'amount': 0.0840385078651019,
#       'discounted_from': None,
#       'discount_percent': None,
#       'type': 'ppc',
#       'sku': '6820',
#       'url': 'http://www.winebow.co.kr/shop/goods/goods_view.php?goodsno=6820&category=002',
#       'visibility': 1,
#       'bottle_type_id': 1,
#       'currency': {'code': 'USD',
#        'name': 'US Dollars',
#        'prefix': '$',
#        'suffix': None},
#       'bottle_type': {'id': 1,
#        'name': 'Bottle (0.75l)',
#        'short_name': 'bottle',
#        'short_name_plural': 'bottles',
#        'volume_ml': 750}}]},
#    {'vintage': {'id': 30315644,
#      'seo_name': 'chateau-la-lezardiere-bordeaux-bordeaux-2014',
#      'name': 'Château La Lézardière Bordeaux 2014',
#      'statistics': {'status': 'Normal',
#       'ratings_count': 40,
#       'ratings_average': 3,
#       'labels_count': 819,
#       'wine_ratings_count': 525,
#       'wine_ratings_average': 3,
#       'wine_status': 'Normal'},
#      'image': {'location': '//images.vivino.com/labels/REJnohUGRFOZSNuJ__J4tg.jpg',
#       'variations': {'large': '//images.vivino.com/thumbs/REJnohUGRFOZSNuJ__J4tg_375x500.jpg',
#        'medium': '//images.vivino.com/thumbs/REJnohUGRFOZSNuJ__J4tg_150x200.jpg',
#        'medium_square': '//images.vivino.com/thumbs/REJnohUGRFOZSNuJ__J4tg_150x150.jpg',
#        'small_square': '//images.vivino.com/thumbs/REJnohUGRFOZSNuJ__J4tg_80x80.jpg'}},
#      'wine': {'id': 1129389,
#       'name': 'Bordeaux',
#       'seo_name': 'bordeaux-bordeaux',
#       'type_id': 1,
#       'vintage_type': 0,
#       'is_natural': False,
#       'region': {'id': 383,
#        'name': 'Bordeaux',
#        'name_en': '',
#        'seo_name': 'bordeaux',
#        'country': {'code': 'fr',
#         'name': 'France',
#         'native_name': 'France',
#         'seo_name': 'france',
#         'currency': {'code': 'EUR',
#          'name': 'Euros',
#          'prefix': '€',
#          'suffix': None},
#         'regions_count': 1304,
#         'users_count': 5552423,
#         'wines_count': 568341,
#         'wineries_count': 67611,
#         'most_used_grapes': [{'id': 14,
#           'name': 'Pinot Noir',
#           'seo_name': 'pinot-noir',
#           'has_detailed_info': True,
#           'wines_count': 572334},
#          {'id': 5,
#           'name': 'Chardonnay',
#           'seo_name': 'chardonnay',
#           'has_detailed_info': True,
#           'wines_count': 604208},
#          {'id': 10,
#           'name': 'Merlot',
#           'seo_name': 'merlot',
#           'has_detailed_info': True,
#           'wines_count': 566719}]},
#        'background_image': {'location': '//images.vivino.com/regions/backgrounds/3z0tiBnOSPaSk5LxoYKRYg.jpeg',
#         'variations': {'large': '//thumbs.vivino.com/region_backgrounds/3z0tiBnOSPaSk5LxoYKRYg_1280x760.jpeg',
#          'medium': '//thumbs.vivino.com/region_backgrounds/3z0tiBnOSPaSk5LxoYKRYg_600x356.jpeg'}}},
#       'winery': {'id': 12763,
#        'name': 'Château La Lézardière',
#        'seo_name': 'chateau-la-lezardiere',
#        'status': 0,
#        'background_image': None},
#       'taste': {'structure': {'acidity': 4.1614842,
#         'fizziness': None,
#         'intensity': 3.8227093,
#         'sweetness': 1.4015484,
#         'tannin': 3.7952259,
#         'user_structure_count': 11,
#         'calculated_structure_count': 5},
#        'flavor': [{'group': 'black_fruit',
#          'stats': {'count': 2, 'score': 200},
#          'primary_keywords': [{'id': 52, 'name': 'blackcurrant', 'count': 1},
#           {'id': 135, 'name': 'dark fruit', 'count': 1}]},
#         {'group': 'earth',
#          'stats': {'count': 1, 'score': 100},
#          'primary_keywords': [{'id': 156, 'name': 'earthy', 'count': 1}]},
#         {'group': 'oak',
#          'stats': {'count': 1, 'score': 100},
#          'primary_keywords': [{'id': 101, 'name': 'chocolate', 'count': 1}]}]},
#       'statistics': {'status': 'Normal',
#        'ratings_count': 525,
#        'ratings_average': 3,
#        'labels_count': 8185,
#        'vintages_count': 37},
#       'style': {'id': 19,
#        'seo_name': 'bordeaux-red',
#        'regional_name': 'Bordeaux',
#        'varietal_name': 'Red',
#        'name': 'Bordeaux Red',
#        'image': None,
#        'background_image': {'location': '//images.vivino.com/backgrounds/styles/eEZtWq_WRoysTxYnXgQX_g.jpg',
#         'variations': {'small': '//images.vivino.com/backgrounds/styles/thumbs/eEZtWq_WRoysTxYnXgQX_g_932x810.jpg'}},
#        'description': "Bordeaux has a cool marine coastal climate, with mild weather and no dry season. Bordeaux reds tend to be lower in alcohol and are slightly lighter in body.\n\nStylistically, they exhibit more nuanced flavors and less up-front fruit. Sophisticated and elegant, they pair well with game meats, roast lamb, or hearty beef stews.\n\nBordeaux is the largest wine producing region in France. It consists of two major areas—the Left and the Right Bank. Both lie in the heart of the Gironde estuary and are further divided by its tributaries, the Garonne and the Dordogne rivers.\n\nWhile the Right Bank produces blends that are mostly Merlot dominant, the Left Bank produces blends that are primarily Cabernet Sauvignon dominant.\n\nBordeaux reds are said to be terroir-driven (if you like French wines, you'll hear this term a lot). Terroir is a concise way to define a specific region based upon the soil, climate, and the collective knowledge of the generations of people who have farmed the land.\n\nWhen shopping for Bordeaux reds, keep in mind, French wines are all about the region and the blend, not about individual grape varieties. In fact, you will rarely find blend percentages listed on the label.\n\nCollectively, Bordeaux produces 700 million bottles of wine in an average year! While some of the most expensive wines in the world come from Bordeaux, most are every day, affordable table wines.",
#        'blurb': None,
#        'interesting_facts': ['The Brits call red Bordeaux blends “claret.”',
#         'Château is a common term for a French wine producer.',
#         'Both dry and sweet whites can be found in Bordeaux, typically they are made from Sauvignon Blanc, Sémillon and sometimes Muscadelle.',
#         'Bordeaux has been a wine producing region for a very long time: The first vines were planted in the region during the mid-1st century by the Romans.',
#         "Phylloxera wiped out most of Bordeaux's vineyards in the late 19th century. Vineyards were gradually replanted with Phylloxera resistant root stock."],
#        'body': 4,
#        'body_description': 'Full-bodied',
#        'acidity': 3,
#        'acidity_description': 'High',
#        'country': {'code': 'fr',
#         'name': 'France',
#         'native_name': 'France',
#         'seo_name': 'france',
#         'currency': {'code': 'EUR',
#          'name': 'Euros',
#          'prefix': '€',
#          'suffix': None},
#         'regions_count': 1304,
#         'users_count': 5552423,
#         'wines_count': 568341,
#         'wineries_count': 67611,
#         'most_used_grapes': [{'id': 14,
#           'name': 'Pinot Noir',
#           'seo_name': 'pinot-noir',
#           'has_detailed_info': True,
#           'wines_count': 572334},
#          {'id': 5,
#           'name': 'Chardonnay',
#           'seo_name': 'chardonnay',
#           'has_detailed_info': True,
#           'wines_count': 604208},
#          {'id': 10,
#           'name': 'Merlot',
#           'seo_name': 'merlot',
#           'has_detailed_info': True,
#           'wines_count': 566719}]},
#        'wine_type_id': 1,
#        'food': [{'id': 4,
#          'name': 'Beef',
#          'background_image': {'location': '//images.vivino.com/backgrounds/foods/4_beef.png',
#           'variations': {'small': '//images.vivino.com/backgrounds/foods/thumbs/4_beef_932x810.png'}},
#          'seo_name': 'beef'},
#         {'id': 9,
#          'name': 'Veal',
#          'background_image': {'location': '//images.vivino.com/backgrounds/foods/9_veal.png',
#           'variations': {'small': '//images.vivino.com/backgrounds/foods/thumbs/9_veal_932x810.png'}},
#          'seo_name': 'veal'},
#         {'id': 11,
#          'name': 'Game (deer, venison)',
#          'background_image': {'location': '//images.vivino.com/backgrounds/foods/11_venison.png',
#           'variations': {'small': '//images.vivino.com/backgrounds/foods/thumbs/11_venison_932x810.png'}},
#          'seo_name': 'game'},
#         {'id': 20,
#          'name': 'Poultry',
#          'background_image': {'location': '//images.vivino.com/backgrounds/foods/20_chicken.png',
#           'variations': {'small': '//images.vivino.com/backgrounds/foods/thumbs/20_chicken_932x810.png'}},
#          'seo_name': 'poultry'}],
#        'grapes': [{'id': 2,
#          'name': 'Cabernet Sauvignon',
#          'seo_name': 'cabernet-sauvignon',
#          'has_detailed_info': True,
#          'wines_count': 801751},
#         {'id': 3,
#          'name': 'Cabernet Franc',
#          'seo_name': 'cabernet-franc',
#          'has_detailed_info': True,
#          'wines_count': 269578},
#         {'id': 9,
#          'name': 'Malbec',
#          'seo_name': 'malbec',
#          'has_detailed_info': True,
#          'wines_count': 219735},
#         {'id': 10,
#          'name': 'Merlot',
#          'seo_name': 'merlot',
#          'has_detailed_info': True,
#          'wines_count': 566719},
#         {'id': 42,
#          'name': 'Petit Verdot',
#          'seo_name': 'petit-verdot',
#          'has_detailed_info': True,
#          'wines_count': 82567},
#         {'id': 51,
#          'name': 'Carménère',
#          'seo_name': 'carmenere',
#          'has_detailed_info': True,
#          'wines_count': 50087}],
#        'region': {'id': 383,
#         'name': 'Bordeaux',
#         'name_en': '',
#         'seo_name': 'bordeaux',
#         'country': {'code': 'fr',
#          'name': 'France',
#          'native_name': 'France',
#          'seo_name': 'france',
#          'currency': {'code': 'EUR',
#           'name': 'Euros',
#           'prefix': '€',
#           'suffix': None},
#          'regions_count': 1304,
#          'users_count': 5552423,
#          'wines_count': 568341,
#          'wineries_count': 67611,
#          'most_used_grapes': [{'id': 14,
#            'name': 'Pinot Noir',
#            'seo_name': 'pinot-noir',
#            'has_detailed_info': True,
#            'wines_count': 572334},
#           {'id': 5,
#            'name': 'Chardonnay',
#            'seo_name': 'chardonnay',
#            'has_detailed_info': True,
#            'wines_count': 604208},
#           {'id': 10,
#            'name': 'Merlot',
#            'seo_name': 'merlot',
#            'has_detailed_info': True,
#            'wines_count': 566719}]},
#         'parent_id': None,
#         'background_image': {'location': '//images.vivino.com/regions/backgrounds/3z0tiBnOSPaSk5LxoYKRYg.jpeg',
#          'variations': {'large': '//thumbs.vivino.com/region_backgrounds/3z0tiBnOSPaSk5LxoYKRYg_1280x760.jpeg',
#           'medium': '//thumbs.vivino.com/region_backgrounds/3z0tiBnOSPaSk5LxoYKRYg_600x356.jpeg'}},
#         'statistics': {'wineries_count': 13306,
#          'wines_count': 42722,
#          'sub_regions_count': 12,
#          'parent_regions_count': 0}}},
#       'has_valid_ratings': True},
#      'year': 2014,
#      'grapes': None,
#      'has_valid_ratings': True},
#     'price': {'id': 14623113,
#      'amount': 0.0112051343820136,
#      'discounted_from': None,
#      'discount_percent': None,
#      'type': 'ppc',
#      'sku': '6983',
#      'url': 'http://www.winebow.co.kr/shop/goods/goods_view.php?goodsno=6983&category=002',
#      'visibility': 1,
#      'bottle_type_id': 1,
#      'currency': {'code': 'USD',
#       'name': 'US Dollars',
#       'prefix': '$',
#       'suffix': None},
#      'bottle_type': {'id': 1,
#       'name': 'Bottle (0.75l)',
#       'short_name': 'bottle',
#       'short_name_plural': 'bottles',
#       'volume_ml': 750}},
#     'prices': [{'id': 14623113,
#       'amount': 0.0112051343820136,
#       'discounted_from': None,
#       'discount_percent': None,
#       'type': 'ppc',
#       'sku': '6983',
#       'url': 'http://www.winebow.co.kr/shop/goods/goods_view.php?goodsno=6983&category=002',
#       'visibility': 1,
#       'bottle_type_id': 1,
#       'currency': {'code': 'USD',
#        'name': 'US Dollars',
#        'prefix': '$',
#        'suffix': None},
#       'bottle_type': {'id': 1,
#        'name': 'Bottle (0.75l)',
#        'short_name': 'bottle',
#        'short_name_plural': 'bottles',
#        'volume_ml': 750}}]}]},
#  'selected_filters': [{'type': 'wine_type_ids',
#    'items': [{'id': 1,
#      'name': 'Red Wine',
#      'background_image': {'location': '//images.vivino.com/backgrounds/winetypes/red.png',
#       'variations': {'small': '//images.vivino.com/backgrounds/winetypes/thumbs/red_932x810.png'}}}]}],
#  'e': 'eJzLLbI1VEu2DQ12VCuwNVHLL0qxTSxOVstPqrQtKMpMTlUrL4mOBSmptM0uAgBMJQ72'}
