# %%
import requests
import pandas as pd

r = requests.get(
    "https://www.vivino.com/api/explore/explore",
    params = {
        "country_code": "USA",
        #"country_codes[]":"pt",
        #"currency_code":"EUR",
        #"grape_filter":"varietal",
        "min_rating":"1",
        "order_by":"price",
        "order":"asc",
        "page": 1,
        #"price_range_max":"500",
        #"price_range_min":"0",
        "wine_type_ids[]":"1"
    },
    headers= {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:66.0) Gecko/20100101 Firefox/66.0"
    }
)
results = [
    (
        t["vintage"]["wine"]["winery"]["name"], 
        f'{t["vintage"]["wine"]["name"]} {t["vintage"]["year"]}',
        t["vintage"]["statistics"]["ratings_average"],
        t["vintage"]["statistics"]["ratings_count"]
    )
    for t in r.json()["explore_vintage"]["matches"]
]
dataframe = pd.DataFrame(results,columns=['Winery','Wine','Rating','num_review'])

print(dataframe)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23484/2746115676.py in <module>
#      28         t["vintage"]["statistics"]["ratings_count"]
#      29     )
# ---> 30     for t in r.json()["explore_vintage"]["matches"]
#      31 ]
#      32 dataframe = pd.DataFrame(results,columns=['Winery','Wine','Rating','num_review'])
#
# KeyError: 'explore_vintage'

# %%
numbers = ['one', 'two', 'three', 'four', 'five']
   
for n in numbers:
    print(n)
# Out:
# one
# two
# three
# four
# five

# %%
import requests
import pandas as pd

r = requests.get(
    "https://www.vivino.com/api/explore/explore",
    params = {
        "currency_code":"USA",
            "min_rating":"1",
            "order_by":"price",
            "order":"asc",
            "page": 1,
            "wine_type_ids[]":"1"
    },
    headers= {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:66.0) Gecko/20100101 Firefox/66.0"
    }
)
results = [
    (
        t["vintage"]["wine"]["winery"]["name"], 
        f'{t["vintage"]["wine"]["name"]} {t["vintage"]["year"]}',
        t["vintage"]["statistics"]["ratings_average"],
        t["vintage"]["statistics"]["ratings_count"]
    )
    for t in r.json()["explore_vintage"]["matches"]
]
dataframe = pd.DataFrame(results,columns=['Winery','Wine','Rating','num_review'])

wine_dict = json.loads(json.dumps(r.json()))
print(dataframe)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23484/1769692479.py in <module>
#      26 ]
#      27 dataframe = pd.DataFrame(results,columns=['Winery','Wine','Rating','num_review'])
# ---> 28 wine_dict = json.loads(json.dumps(r.json()))
#      29 print(dataframe)
#
# NameError: name 'json' is not defined

# %%
wine_dict = json.loads(json.dumps(r.json()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23484/610395348.py in <module>
# ----> 1 wine_dict = json.loads(json.dumps(r.json()))
#
# NameError: name 'json' is not defined

# %%
import requests
import pandas as pd

# get_wine_data(wine_id, year, page) 
# id year page 받아서 api에서 데이터 받아오기 함수
def get_wine_data(wine_id, year, page):
    headers = {
        "User-Agent": "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:89.0) Gecko/20100101 Firefox/89.0",
    }

    api_url = "https://www.vivino.com/api/wines/{id}/reviews?per_page=50&year={year}&page={page}"  # <-- increased the number of reviews to 9999

    data = requests.get(
        api_url.format(id=wine_id, year=year, page=page), headers=headers
    ).json()

    return data
#https://www.vivino.com/api/wines/2468359/reviews?per_page=50&year=2020&page=page
# 
r = requests.get(
    "https://www.vivino.com/api/explore/explore",
    params={
#         "country_code": "USA",
#         #"country_codes[]": "pt",
#         #"currency_code": "EUR",
#         #"grape_filter": "varietal",
#         "min_rating": "1",
#         "order_by": "price",
#         "order": "asc",
#         "page": 1,
#         "price_range_max": "500",
#         "price_range_min": "0",
#         "wine_type_ids[]": "1",
        "currency_code":"USA",
            "min_rating":"1",
            "order_by":"price",
            "order":"asc",
            "page": 1,
            "wine_type_ids[]":"1"
    },
    headers={
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:66.0) Gecko/20100101 Firefox/66.0"
    },
)

results = [
    (
        t["vintage"]["wine"]["winery"]["name"],
        t["vintage"]["year"],
        t["vintage"]["wine"]["id"],
        f'{t["vintage"]["wine"]["name"]} {t["vintage"]["year"]}',
        t["vintage"]["seo_name"],#Wine(eng) 영어이름 위에 이름은 불어등이 불러와짐. 
        t["vintage"]["statistics"]["ratings_average"],
        t["vintage"]["statistics"]["ratings_count"],
        t["vintage"]["image"]["variations"],#["bottle_large"], 추후에 뽑아서 자르는 것 필요
        t["vintage"]["wine"]['seo_name'], #이름 추가 뺴도될듯
        t["vintage"]["wine"]['region']['country']['most_used_grapes'],#['name']을 추출 필요
        t["vintage"]["wine"]['taste']['structure']['acidity'],
        t["vintage"]["wine"]['taste']['structure']['fizziness'],
        t["vintage"]["wine"]['taste']['structure']['intensity'],
        t["vintage"]["wine"]['taste']['structure']['sweetness'],
        t["vintage"]["wine"]['taste']['structure']['tannin'],
        t["vintage"]["wine"]['taste']['structure']['user_structure_count'],
        t["vintage"]["wine"]['taste']['structure']['calculated_structure_count'],
        t["vintage"]["wine"]['taste']['flavor'], # 추후 조금더 나눌 필요가 있지 않을까?
        t["vintage"]["wine"]['style']['description'],
        t["vintage"]["wine"]['style']['food'],#['name']  [안에 내용] 이것을 어떻게 처리할지 고민해봐야
        t["vintage"]["wine"]['style']['grapes'], # ['name'] 위와 같은 문제
        t["vintage"]["wine"]['style']['region'],#['name'] 지역정보가 없는 애들이 있어서 name을 찾지 못하는경우발생,
        t["vintage"]["wine"]['style']['region'],#['country']['name'], 같은 문제 발생 
        t["price"]["url"]
        #t["vintage"]["statistics"]["ratings_average"],
        #t["vintage"]["statistics"]["ratings_count"],
    )
    for t in r.json()["explore_vintage"]["matches"]
]

dataframe = pd.DataFrame(
    results,
    columns=["Winery", "Year", "Wine ID", "Wine","Winefullname(eng)", "Rating", "num_review",\
             "image",'name2', 'mostusedgrapes', 'acidity', 'fizziness', 'intensity', 'sweetness', \
             'tannin', 'user_structure_count', 'calculated_structure_count', 'flavor', 'description', 'food', \
            'grapes','region','country', 'url' ],
)
# 와인데이터(dataframe)에 리뷰 합치기 
ratings = []
for _, row in dataframe.iterrows():
    page = 1
    while True:
        print(
            f'Getting info about wine {row["Wine ID"]}-{row["Year"]} Page {page}'
        )

        d = get_wine_data(row["Wine ID"], row["Year"], page)

        if not d["reviews"]:
            break

        for r in d["reviews"]:
            ratings.append(
                [
                    row["Year"],
                    row["Wine ID"],
                    r["rating"],
                    r["note"],
                    r["created_at"],
                ]
            )

        page += 1

ratings = pd.DataFrame(
    ratings, columns=["Year", "Wine ID", "User Rating", "Note", "CreatedAt"]
)

df_out = ratings.merge(dataframe)
df_out.to_csv("data.csv", index=False)
# Out:
# Getting info about wine 1419579-2014 Page 1
# Getting info about wine 1419579-2014 Page 2
# Getting info about wine 1419579-2014 Page 3
# Getting info about wine 1419579-2014 Page 4
# Getting info about wine 1251301-2010 Page 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23484/2389712446.py in <module>
#      92         )
#      93
# ---> 94         d = get_wine_data(row["Wine ID"], row["Year"], page)
#      95
#      96         if not d["reviews"]:
#
# ~\AppData\Local\Temp/ipykernel_23484/2389712446.py in get_wine_data(wine_id, year, page)
#      11     api_url = "https://www.vivino.com/api/wines/{id}/reviews?per_page=50&year={year}&page={page}"  # <-- increased the number of reviews to 9999
#      12
# ---> 13     data = requests.get(
#      14         api_url.format(id=wine_id, year=year, page=page), headers=headers
#      15     ).json()
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# ~\anaconda3\lib\http\client.py in getresponse(self)
#    1369         try:
#    1370             try:
# -> 1371                 response.begin()
#    1372             except ConnectionError:
#    1373                 self.close()
#
# ~\anaconda3\lib\http\client.py in begin(self)
#     317         # read until we get a non-100 response
#     318         while True:
# --> 319             version, status, reason = self._read_status()
#     320             if status != CONTINUE:
#     321                 break
#
# ~\anaconda3\lib\http\client.py in _read_status(self)
#     278
#     279     def _read_status(self):
# --> 280         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     281         if len(line) > _MAXLINE:
#     282             raise LineTooLong("status line")
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# ~\anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~\anaconda3\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
dataframe
# Out:
#                           Winery  Year  Wine ID  \
# 0              Château la Plaige  2014  1419579
# 1                  Concha y Toro  2010  1251301
# 2                        Silenus  2011  1378259
# 3                      Two Hands  2012     6160
# 4                 La Pousse d'Or  2008   780003
# 5                      Scagliola  2011  1274761
# 6   Ciacci Piccolomini d'Aragona  2012    16996
# 7                     Casa Silva  2015    18302
# 8                     Wolf Blass  2015  1129969
# 9                 Santa Carolina  2017  1147986
# 10             Marchesi di Gresy  2009    82392
# 11                 Villa a Sesta  2012  1199031
# 12         Mission Estate Winery  2016  2475381
# 13             Viña Santa Helena  2015  1134446
# 14             Barton & Guestier  2015    78614
# 15               Catalina Sounds  2016  1209900
# 16                    Bald Hills  2007  1185676
# 17         Domaine de Chassorney  2014  4018942
# 18              Famiglia Marrone  2010  1297743
# 19               Contessa Carola  2013  1425716
# 20        Stimson Estate Cellars  2009     2618
# 21                   Félix Solís  2017  1323253
# 22                   Roger Sabon  2017    36174
# 23                         Cline  2017  1170343
# 24              Brothers In Arms  2006    83130
#
#                                                  Wine  \
# 0                                       Bordeaux 2014
# 1                         Gravas del Maipo Syrah 2010
# 2                     Reserve Cabernet Sauvignon 2011
# 3                       Samantha's Garden Shiraz 2012
# 4               Santenay 1er Cru 'Clos Tavannes' 2008
# 5                                           Frem 2011
# 6                                         Fabivs 2012
# 7                               Colección Merlot 2015
# 8                     Bilyara Cabernet Sauvignon 2015
# 9                              Merlot (Varietal) 2017
# 10                Dolcetto d'Alba Monte Aribaldo 2009
# 11                  Ripaltella Chianti Superiore 2012
# 12                                    Pinot Noir 2016
# 13  Gran Reserva Pinot Noir (Selección del Directo...
# 14          Bordeaux Merlot - Cabernet Sauvignon 2015
# 15                                    Pinot Noir 2016
# 16                    Single Vineyard Pinot Noir 2007
# 17  Bourgogne Hautes-Côtes de Beaune 'Puits de Cha...
# 18                                      Passione 2010
# 19         Old Esteemed Vineyards Sangiovese Oro 2013
# 20                                        Merlot 2009
# 21                           Viña San Juan Tinto 2017
# 22                                Côtes Du Rhône 2017
# 23                                    Pinot Noir 2017
# 24                                        Shiraz 2006
#
#                                     Winefullname(eng)  Rating  num_review  \
# 0                     chateau-la-plaige-bordeaux-2014     3.3          57
# 1           concha-y-toro-gravas-del-maipo-syrah-2010     4.4         755
# 2   silenus-coonawarra-reserve-cabernet-sauvignon-...     3.4          44
# 3       two-hands-wines-samantha-s-garden-shiraz-2012     4.1         141
# 4   la-pousse-d-or-santenay-1er-cru-clos-tavannes-...     4.0          40
# 5                                 scagliola-frem-2011     3.6          89
# 6            ciacci-piccolomini-d-aragona-fabivs-2012     3.6         154
# 7                    casa-silva-coleccion-merlot-2015     3.8          52
# 8          wolf-blass-bilyara-cabernet-sauvignon-2015     3.4          62
# 9                 santa-carolina-merlot-varietal-2017     2.8          39
# 10   cisa-asinari-dolcetto-d-alba-monte-aribaldo-2009     3.3          35
# 11         it-sesta-ripaltella-chianti-superiore-2012     3.6          81
# 12                     mission-estate-pinot-noir-2016     3.3          90
# 13  vina-santa-helena-gran-reserva-pinot-noir-sele...     3.7          91
# 14  barton-guestier-bordeaux-merlot-cabernet-sauvi...     3.6         647
# 15                    catalina-sounds-pinot-noir-2016     3.8         123
# 16         bald-hills-single-vineyard-pinot-noir-2007     3.8          35
# 17  chassorney-bourgogne-hautes-cotes-de-beaune-pu...     3.9          43
# 18                     famiglia-marrone-passione-2010     3.9         103
# 19  contessa-carola-old-esteemed-vineyards-sangiov...     3.7          78
# 20                         stimson-estate-merlot-2009     3.7         225
# 21               felix-solis-vina-san-juan-tinto-2017     3.6         679
# 22                    roger-sabon-cotes-du-rhone-2017     3.9         232
# 23                 cline-pinot-noir-sonoma-coast-2017     3.7        1223
# 24                       brothers-in-arms-shiraz-2006     4.1          73
#
#                                                 image  \
# 0   {'bottle_large': '//images.vivino.com/thumbs/G...
# 1   {'bottle_large': '//images.vivino.com/thumbs/o...
# 2   {'large': '//images.vivino.com/thumbs/011l0eb8...
# 3   {'bottle_large': '//images.vivino.com/thumbs/g...
# 4   {'bottle_large': '//images.vivino.com/thumbs/h...
# 5   {'bottle_large': '//images.vivino.com/thumbs/F...
# 6   {'bottle_large': '//images.vivino.com/thumbs/u...
# 7   {'bottle_large': '//images.vivino.com/thumbs/y...
# 8   {'large': '//images.vivino.com/thumbs/NIW528ge...
# 9   {'bottle_large': '//images.vivino.com/thumbs/p...
# 10  {'bottle_large': '//images.vivino.com/thumbs/S...
# 11  {'bottle_large': '//images.vivino.com/thumbs/Q...
# 12  {'bottle_large': '//images.vivino.com/thumbs/6...
# 13  {'bottle_large': '//images.vivino.com/thumbs/g...
# 14  {'bottle_large': '//images.vivino.com/thumbs/c...
# 15  {'bottle_large': '//images.vivino.com/thumbs/T...
# 16  {'bottle_large': '//images.vivino.com/thumbs/O...
# 17  {'bottle_large': '//images.vivino.com/thumbs/w...
# 18  {'bottle_large': '//images.vivino.com/thumbs/U...
# 19  {'bottle_large': '//images.vivino.com/thumbs/j...
# 20  {'bottle_large': '//images.vivino.com/thumbs/q...
# 21  {'bottle_large': '//images.vivino.com/thumbs/Z...
# 22  {'bottle_large': '//images.vivino.com/thumbs/q...
# 23  {'bottle_large': '//images.vivino.com/thumbs/b...
# 24  {'bottle_large': '//images.vivino.com/thumbs/A...
#
#                                                name2  \
# 0                                           bordeaux
# 1                             gravas-del-maipo-syrah
# 2                         reserve-cabernet-sauvignon
# 3                           samantha-s-garden-shiraz
# 4                     santenay-1er-cru-clos-tavannes
# 5                                               frem
# 6                                             fabivs
# 7                                   coleccion-merlot
# 8                         bilyara-cabernet-sauvignon
# 9                                    merlot-varietal
# 10                    dolcetto-d-alba-monte-aribaldo
# 11                      ripaltella-chianti-superiore
# 12                                        pinot-noir
# 13  gran-reserva-pinot-noir-seleccion-del-directorio
# 14                bordeaux-merlot-cabernet-sauvignon
# 15                                        pinot-noir
# 16                        single-vineyard-pinot-noir
# 17   bourgogne-hautes-cotes-de-beaune-puits-de-chaux
# 18                                          passione
# 19             old-esteemed-vineyards-sangiovese-oro
# 20                                            merlot
# 21                               vina-san-juan-tinto
# 22                                    cotes-du-rhone
# 23                           pinot-noir-sonoma-coast
# 24                                            shiraz
#
#                                        mostusedgrapes  ...    tannin  \
# 0   [{'id': 14, 'name': 'Pinot Noir', 'seo_name': ...  ...  3.851192
# 1   [{'id': 2, 'name': 'Cabernet Sauvignon', 'seo_...  ...  3.063660
# 2   [{'id': 1, 'name': 'Shiraz/Syrah', 'seo_name':...  ...  3.329935
# 3   [{'id': 1, 'name': 'Shiraz/Syrah', 'seo_name':...  ...  3.136560
# 4   [{'id': 14, 'name': 'Pinot Noir', 'seo_name': ...  ...  2.271802
# 5   [{'id': 16, 'name': 'Sangiovese', 'seo_name': ...  ...  2.211386
# 6   [{'id': 16, 'name': 'Sangiovese', 'seo_name': ...  ...  3.119100
# 7   [{'id': 2, 'name': 'Cabernet Sauvignon', 'seo_...  ...  2.052278
# 8   [{'id': 1, 'name': 'Shiraz/Syrah', 'seo_name':...  ...  3.397327
# 9   [{'id': 2, 'name': 'Cabernet Sauvignon', 'seo_...  ...  1.784536
# 10  [{'id': 16, 'name': 'Sangiovese', 'seo_name': ...  ...  2.930345
# 11  [{'id': 16, 'name': 'Sangiovese', 'seo_name': ...  ...  3.605881
# 12  [{'id': 14, 'name': 'Pinot Noir', 'seo_name': ...  ...  2.292278
# 13  [{'id': 2, 'name': 'Cabernet Sauvignon', 'seo_...  ...  1.211418
# 14  [{'id': 14, 'name': 'Pinot Noir', 'seo_name': ...  ...  3.604484
# 15  [{'id': 14, 'name': 'Pinot Noir', 'seo_name': ...  ...  2.189938
# 16  [{'id': 14, 'name': 'Pinot Noir', 'seo_name': ...  ...  2.186855
# 17  [{'id': 14, 'name': 'Pinot Noir', 'seo_name': ...  ...  2.171702
# 18  [{'id': 16, 'name': 'Sangiovese', 'seo_name': ...  ...  2.851590
# 19  [{'id': 16, 'name': 'Sangiovese', 'seo_name': ...  ...  2.745714
# 20  [{'id': 2, 'name': 'Cabernet Sauvignon', 'seo_...  ...  2.608843
# 21  [{'id': 19, 'name': 'Tempranillo', 'seo_name':...  ...  2.970715
# 22  [{'id': 14, 'name': 'Pinot Noir', 'seo_name': ...  ...  3.157281
# 23  [{'id': 2, 'name': 'Cabernet Sauvignon', 'seo_...  ...  2.165296
# 24  [{'id': 1, 'name': 'Shiraz/Syrah', 'seo_name':...  ...  3.123444
#
#    user_structure_count  calculated_structure_count  \
# 0                    13                          19
# 1                    51                          96
# 2                     7                          45
# 3                    66                         107
# 4                    39                          65
# 5                    77                          66
# 6                    53                          69
# 7                    23                          11
# 8                    49                         119
# 9                    10                          22
# 10                  102                          68
# 11                   27                          16
# 12                    7                          27
# 13                   12                          22
# 14                  287                         295
# 15                   23                          74
# 16                   55                          69
# 17                   12                          18
# 18                   45                          46
# 19                   18                          14
# 20                   19                          81
# 21                  123                         130
# 22                   58                         129
# 23                  481                         939
# 24                   80                         116
#
#                                                flavor  \
# 0   [{'group': 'oak', 'stats': {'count': 11, 'scor...
# 1   [{'group': 'oak', 'stats': {'count': 78, 'scor...
# 2   [{'group': 'oak', 'stats': {'count': 14, 'scor...
# 3   [{'group': 'black_fruit', 'stats': {'count': 8...
# 4   [{'group': 'red_fruit', 'stats': {'count': 53,...
# 5   [{'group': 'red_fruit', 'stats': {'count': 27,...
# 6   [{'group': 'oak', 'stats': {'count': 78, 'scor...
# 7   [{'group': 'black_fruit', 'stats': {'count': 4...
# 8   [{'group': 'oak', 'stats': {'count': 52, 'scor...
# 9   [{'group': 'black_fruit', 'stats': {'count': 1...
# 10  [{'group': 'black_fruit', 'stats': {'count': 3...
# 11  [{'group': 'red_fruit', 'stats': {'count': 18,...
# 12  [{'group': 'red_fruit', 'stats': {'count': 25,...
# 13  [{'group': 'oak', 'stats': {'count': 10, 'scor...
# 14  [{'group': 'black_fruit', 'stats': {'count': 1...
# 15  [{'group': 'red_fruit', 'stats': {'count': 49,...
# 16  [{'group': 'red_fruit', 'stats': {'count': 37,...
# 17  [{'group': 'red_fruit', 'stats': {'count': 16,...
# 18  [{'group': 'oak', 'stats': {'count': 23, 'scor...
# 19  [{'group': 'red_fruit', 'stats': {'count': 12,...
# 20  [{'group': 'oak', 'stats': {'count': 62, 'scor...
# 21  [{'group': 'red_fruit', 'stats': {'count': 41,...
# 22  [{'group': 'red_fruit', 'stats': {'count': 59,...
# 23  [{'group': 'oak', 'stats': {'count': 656, 'sco...
# 24  [{'group': 'black_fruit', 'stats': {'count': 6...
#
#                                           description  \
# 0   Bordeaux has a cool marine coastal climate, wi...
# 1                                                None
# 2   The home of Cabernet Sauvignon is in Bordeaux....
# 3   Australia's most popular grape varietal, Shira...
# 4                                                None
# 5   Barbera is the hardy staple grape of the famou...
# 6                                                None
# 7   Merlot is a staple of the wine producing regio...
# 8   The home of Cabernet Sauvignon is in Bordeaux....
# 9   Merlot is a staple of the wine producing regio...
# 10  The wines of Northern Italy include some of th...
# 11  The most commonly consumed wine in Italy, and ...
# 12  New Zealand has received a lot of attention fo...
# 13  Pinot Noir is never a straightforward varietal...
# 14  Bordeaux has a cool marine coastal climate, wi...
# 15  New Zealand has received a lot of attention fo...
# 16  New Zealand has received a lot of attention fo...
# 17  Burgundian reds completely depend on their env...
# 18  The wines of Northern Italy include some of th...
# 19  The wines of Northern Italy include some of th...
# 20  The most popular grape of the 1980s may have g...
# 21  The savory red wines of Spain are brooding and...
# 22  The Southern Rhône is situated in a large, spr...
# 23  Pinot Noir has the well deserved reputation of...
# 24  Australia's most popular grape varietal, Shira...
#
#                                                  food  \
# 0   [{'id': 4, 'name': 'Beef', 'background_image':...
# 1   [{'id': 4, 'name': 'Beef', 'background_image':...
# 2   [{'id': 4, 'name': 'Beef', 'background_image':...
# 3   [{'id': 4, 'name': 'Beef', 'background_image':...
# 4   [{'id': 4, 'name': 'Beef', 'background_image':...
# 5   [{'id': 5, 'name': 'Pasta', 'background_image'...
# 6   [{'id': 4, 'name': 'Beef', 'background_image':...
# 7   [{'id': 4, 'name': 'Beef', 'background_image':...
# 8   [{'id': 4, 'name': 'Beef', 'background_image':...
# 9   [{'id': 4, 'name': 'Beef', 'background_image':...
# 10  [{'id': 4, 'name': 'Beef', 'background_image':...
# 11  [{'id': 4, 'name': 'Beef', 'background_image':...
# 12  [{'id': 4, 'name': 'Beef', 'background_image':...
# 13  [{'id': 4, 'name': 'Beef', 'background_image':...
# 14  [{'id': 4, 'name': 'Beef', 'background_image':...
# 15  [{'id': 4, 'name': 'Beef', 'background_image':...
# 16  [{'id': 4, 'name': 'Beef', 'background_image':...
# 17  [{'id': 4, 'name': 'Beef', 'background_image':...
# 18  [{'id': 4, 'name': 'Beef', 'background_image':...
# 19  [{'id': 4, 'name': 'Beef', 'background_image':...
# 20  [{'id': 4, 'name': 'Beef', 'background_image':...
# 21  [{'id': 4, 'name': 'Beef', 'background_image':...
# 22  [{'id': 4, 'name': 'Beef', 'background_image':...
# 23  [{'id': 4, 'name': 'Beef', 'background_image':...
# 24  [{'id': 4, 'name': 'Beef', 'background_image':...
#
#                                                grapes  \
# 0   [{'id': 2, 'name': 'Cabernet Sauvignon', 'seo_...
# 1   [{'id': 1, 'name': 'Shiraz/Syrah', 'seo_name':...
# 2   [{'id': 2, 'name': 'Cabernet Sauvignon', 'seo_...
# 3   [{'id': 1, 'name': 'Shiraz/Syrah', 'seo_name':...
# 4   [{'id': 14, 'name': 'Pinot Noir', 'seo_name': ...
# 5   [{'id': 31, 'name': 'Barbera', 'seo_name': 'ba...
# 6   [{'id': 2, 'name': 'Cabernet Sauvignon', 'seo_...
# 7   [{'id': 10, 'name': 'Merlot', 'seo_name': 'mer...
# 8   [{'id': 2, 'name': 'Cabernet Sauvignon', 'seo_...
# 9   [{'id': 10, 'name': 'Merlot', 'seo_name': 'mer...
# 10  [{'id': 12, 'name': 'Nebbiolo', 'seo_name': 'n...
# 11  [{'id': 16, 'name': 'Sangiovese', 'seo_name': ...
# 12  [{'id': 14, 'name': 'Pinot Noir', 'seo_name': ...
# 13  [{'id': 14, 'name': 'Pinot Noir', 'seo_name': ...
# 14  [{'id': 2, 'name': 'Cabernet Sauvignon', 'seo_...
# 15  [{'id': 14, 'name': 'Pinot Noir', 'seo_name': ...
# 16  [{'id': 14, 'name': 'Pinot Noir', 'seo_name': ...
# 17  [{'id': 14, 'name': 'Pinot Noir', 'seo_name': ...
# 18  [{'id': 12, 'name': 'Nebbiolo', 'seo_name': 'n...
# 19  [{'id': 12, 'name': 'Nebbiolo', 'seo_name': 'n...
# 20  [{'id': 10, 'name': 'Merlot', 'seo_name': 'mer...
# 21  [{'id': 8, 'name': 'Grenache', 'seo_name': 'gr...
# 22  [{'id': 1, 'name': 'Shiraz/Syrah', 'seo_name':...
# 23  [{'id': 14, 'name': 'Pinot Noir', 'seo_name': ...
# 24  [{'id': 1, 'name': 'Shiraz/Syrah', 'seo_name':...
#
#                                                region  \
# 0   {'id': 383, 'name': 'Bordeaux', 'name_en': '',...
# 1                                                None
# 2                                                None
# 3                                                None
# 4   {'id': 396, 'name': 'Côte de Beaune', 'name_en...
# 5   {'id': 389, 'name': 'Piemonte', 'name_en': 'Pi...
# 6   {'id': 394, 'name': 'Toscana', 'name_en': 'Tus...
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11  {'id': 394, 'name': 'Toscana', 'name_en': 'Tus...
# 12                                               None
# 13                                               None
# 14  {'id': 383, 'name': 'Bordeaux', 'name_en': '',...
# 15                                               None
# 16                                               None
# 17  {'id': 385, 'name': 'Bourgogne', 'name_en': 'B...
# 18                                               None
# 19                                               None
# 20  {'id': 323, 'name': 'Washington', 'name_en': '...
# 21                                               None
# 22  {'id': 400, 'name': 'Rhone Valley', 'name_en':...
# 23  {'id': 24, 'name': 'California', 'name_en': ''...
# 24                                               None
#
#                                               country  \
# 0   {'id': 383, 'name': 'Bordeaux', 'name_en': '',...
# 1                                                None
# 2                                                None
# 3                                                None
# 4   {'id': 396, 'name': 'Côte de Beaune', 'name_en...
# 5   {'id': 389, 'name': 'Piemonte', 'name_en': 'Pi...
# 6   {'id': 394, 'name': 'Toscana', 'name_en': 'Tus...
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11  {'id': 394, 'name': 'Toscana', 'name_en': 'Tus...
# 12                                               None
# 13                                               None
# 14  {'id': 383, 'name': 'Bordeaux', 'name_en': '',...
# 15                                               None
# 16                                               None
# 17  {'id': 385, 'name': 'Bourgogne', 'name_en': 'B...
# 18                                               None
# 19                                               None
# 20  {'id': 323, 'name': 'Washington', 'name_en': '...
# 21                                               None
# 22  {'id': 400, 'name': 'Rhone Valley', 'name_en':...
# 23  {'id': 24, 'name': 'California', 'name_en': ''...
# 24                                               None
#
#                                                   url
# 0   http://www.winebow.co.kr/shop/goods/goods_view...
# 1   http://www.winebow.co.kr/shop/goods/goods_view...
# 2   http://www.winebow.co.kr/shop/goods/goods_view...
# 3   http://www.winebow.co.kr/shop/goods/goods_view...
# 4   http://www.winebow.co.kr/shop/goods/goods_view...
# 5   http://www.winebow.co.kr/shop/goods/goods_view...
# 6   http://www.winebow.co.kr/shop/goods/goods_view...
# 7   http://www.winebow.co.kr/shop/goods/goods_view...
# 8   http://www.winebow.co.kr/shop/goods/goods_view...
# 9   http://www.winebow.co.kr/shop/goods/goods_view...
# 10  http://www.winebow.co.kr/shop/goods/goods_view...
# 11  http://www.winebow.co.kr/shop/goods/goods_view...
# 12  http://www.winebow.co.kr/shop/goods/goods_view...
# 13  http://www.winebow.co.kr/shop/goods/goods_view...
# 14  http://www.winebow.co.kr/shop/goods/goods_view...
# 15  http://www.winebow.co.kr/shop/goods/goods_view...
# 16  http://www.winebow.co.kr/shop/goods/goods_view...
# 17  http://www.winebow.co.kr/shop/goods/goods_view...
# 18  http://www.winebow.co.kr/shop/goods/goods_view...
# 19  http://www.winebow.co.kr/shop/goods/goods_view...
# 20  http://www.winebow.co.kr/shop/goods/goods_view...
# 21  http://www.winebow.co.kr/shop/goods/goods_view...
# 22  http://www.winebow.co.kr/shop/goods/goods_view...
# 23  http://www.winebow.co.kr/shop/goods/goods_view...
# 24  http://www.winebow.co.kr/shop/goods/goods_view...
#
# [25 rows x 24 columns]

# %%
dataframe['image']
# Out:
# 0     {'bottle_large': '//images.vivino.com/thumbs/G...
# 1     {'bottle_large': '//images.vivino.com/thumbs/o...
# 2     {'large': '//images.vivino.com/thumbs/011l0eb8...
# 3     {'bottle_large': '//images.vivino.com/thumbs/g...
# 4     {'bottle_large': '//images.vivino.com/thumbs/h...
# 5     {'bottle_large': '//images.vivino.com/thumbs/F...
# 6     {'bottle_large': '//images.vivino.com/thumbs/u...
# 7     {'bottle_large': '//images.vivino.com/thumbs/U...
# 8     {'bottle_large': '//images.vivino.com/thumbs/y...
# 9     {'large': '//images.vivino.com/thumbs/NIW528ge...
# 10    {'bottle_large': '//images.vivino.com/thumbs/p...
# 11    {'bottle_large': '//images.vivino.com/thumbs/S...
# 12    {'bottle_large': '//images.vivino.com/thumbs/Q...
# 13    {'bottle_large': '//images.vivino.com/thumbs/6...
# 14    {'bottle_large': '//images.vivino.com/thumbs/g...
# 15    {'bottle_large': '//images.vivino.com/thumbs/c...
# 16    {'bottle_large': '//images.vivino.com/thumbs/T...
# 17    {'bottle_large': '//images.vivino.com/thumbs/O...
# 18    {'bottle_large': '//images.vivino.com/thumbs/w...
# 19    {'bottle_large': '//images.vivino.com/thumbs/U...
# 20    {'bottle_large': '//images.vivino.com/thumbs/j...
# 21    {'bottle_large': '//images.vivino.com/thumbs/q...
# 22    {'bottle_large': '//images.vivino.com/thumbs/Z...
# 23    {'bottle_large': '//images.vivino.com/thumbs/q...
# 24    {'bottle_large': '//images.vivino.com/thumbs/b...
# Name: image, dtype: object

# %%
import pandas as pd

df_out=pd.read_csv("data.csv")
df_out.head()
# Out:
#    Year  Wine ID  User Rating  \
# 0  2020  2468359          4.0
# 1  2020  2468359          4.0
# 2  2020  2468359          4.0
# 3  2020  2468359          4.0
# 4  2020  2468359          4.0
#
#                                                 Note  \
# 0  Dusty blackcurrant on the nose. Palate follows...
# 1  A nose of dark berry and light oak gives way t...
# 2  A very fruity wine, hits you in the face with ...
# 3  Lovely flavour, enjoyed this wine. Notes of va...
# 4  I have a terrible memory. It has the advantage...
#
#                   CreatedAt        Winery  \
# 0  2021-12-04T19:16:02.000Z  Casal Branco
# 1  2022-04-03T18:27:14.000Z  Casal Branco
# 2  2022-09-03T16:18:59.000Z  Casal Branco
# 3  2022-02-14T19:30:19.000Z  Casal Branco
# 4  2022-06-26T17:58:16.000Z  Casal Branco
#
#                                      Wine  Rating  num_review
# 0  Lobo e Falcão Wolf & Falcon Tinto 2020     4.0        1734
# 1  Lobo e Falcão Wolf & Falcon Tinto 2020     4.0        1734
# 2  Lobo e Falcão Wolf & Falcon Tinto 2020     4.0        1734
# 3  Lobo e Falcão Wolf & Falcon Tinto 2020     4.0        1734
# 4  Lobo e Falcão Wolf & Falcon Tinto 2020     4.0        1734
