# %% [markdown]
# # Pandas
# > - 데이터 과학자를 위해 **테이블형태**로 데이터를 다룰 수 있게 해주는 패키지(python용 엑셀)
# > - 기존 데이터처리 라이브러리인 numpy 대신 주로 사용
# > - 일반인이 데이터분석을 접하기 쉽게 만들어준 결정적인 라이브러리
# > - pandas만으로도 충분히 데이터 분석이 가능할 정도로 고수준의 함수들을 내장
# > - 앞으로 진행하는 데이터분석 과정에서 주로 사용하게 될 데이터구조

# %% [markdown]
# ## pandas 설치 및 import
#
# > 콘솔창에서 실행 시
# **`pip install pandas`**
# **`conda install pandas`**
#
# > 주피터 노트북으로 실행 시
# **`!pip install pandas`**
#
# 아나콘다 환경으로 python 환경설정 시 기본적으로 설치가 되어있음

# %%
# pandas 설치
# !pip install pandas

# %%
# numpy import
import numpy as np

# pandas import
import pandas as pd
# pd라는 닉네임은 많은 파이썬 유저들이 사용하고 있는 닉네임, 분석을 위한 필수는 아니지만 되도록이면 위와 같이 사용을 해줍시다.

pd.options.display.max_columns = 200
# 불러들이는 데이터에 맞춰 모든 컬럼을 확인 가능하도록 옵션값을 주었습니다.
pd.options.display.max_info_columns =200
# 그냥 실행 시키시고 지금 이해 못하셔도 좋습니다.

# %% [markdown]
# ## DataFrame
# > - 엑셀에 익숙한 사용자를 위해 제작 된 **테이블형태의 데이터 구조**
# > - 다양한 형태의 데이터를 받아 사용할 수 있으며 다양한 **통계, 시각화 함수를 제공**한다.
#
# 실제 데이터를 불러들이고 값을 확인 해 보며 기본적인 pandas 사용법을 익혀보도록 하겠습니다.

# %% [markdown]
# ### 데이터 불러오기
# pandas는 다양한 데이터 파일 형태를 지원하며 주로 csv, xlsx, sql, json을 사용합니다.
#
# > **`read_csv()`**
# **`read_excel()`**
# **`read_sql()`**
# **`read_json()`**
# **`json_normalize()`**

# %%
# DataFrame 의 약자로서 형식적으로 df 변수명을 사용한다.
# pandas패키지의 read_csv() 함수를 사용하여 loan1.csv 파일을 불러들여 데이터프레임을 만들고 df 이름의 변수로 저장
df= pd.read_csv('./data/loan1.csv')

# %%
df
# Out:
#        id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0     NaN        NaN      10000        10000          10000.0   36 months
# 1     NaN        NaN       3500         3500           3500.0   36 months
# 2     NaN        NaN       5000         5000           5000.0   36 months
# 3     NaN        NaN      14000        14000          14000.0   36 months
# 4     NaN        NaN       5000         5000           5000.0   36 months
# ...    ..        ...        ...          ...              ...         ...
# 19995 NaN        NaN      10800        10800          10800.0   36 months
# 19996 NaN        NaN      14000        14000          14000.0   60 months
# 19997 NaN        NaN      35000        35000          35000.0   60 months
# 19998 NaN        NaN      35225        35225          35225.0   60 months
# 19999 NaN        NaN       3500         3500           3500.0   36 months
#
#        int_rate  installment grade sub_grade                emp_title  \
# 0          9.44       320.05     B        B1                 mechanic
# 1         10.42       113.63     B        B3                      NaN
# 2         13.59       169.90     C        C2             Truck driver
# 3         10.91       457.75     B        B4   Confidential Secretary
# 4         13.59       169.90     C        C2          General Manager
# ...         ...          ...   ...       ...                      ...
# 19995      9.44       345.66     B        B1                  Partner
# 19996     14.08       326.34     C        C3  Senior Property Manager
# 19997     12.62       789.57     C        C1        Mechanic engineer
# 19998     19.03       914.34     D        D3                  Teacher
# 19999     17.09       124.95     D        D1       Director of Design
#
#       emp_length home_ownership  annual_inc verification_status   issue_d  \
# 0        6 years       MORTGAGE     80000.0        Not Verified  Dec-2017
# 1            NaN            OWN     90000.0        Not Verified  Dec-2017
# 2      10+ years            OWN    168000.0        Not Verified  Dec-2017
# 3        2 years           RENT     39000.0     Source Verified  Dec-2017
# 4       < 1 year           RENT     55000.0        Not Verified  Dec-2017
# ...          ...            ...         ...                 ...       ...
# 19995    3 years       MORTGAGE    240000.0        Not Verified  Nov-2017
# 19996  10+ years            OWN     53300.0            Verified  Nov-2017
# 19997    7 years           RENT     85000.0     Source Verified  Nov-2017
# 19998    8 years       MORTGAGE     42000.0     Source Verified  Nov-2017
# 19999  10+ years           RENT     87000.0        Not Verified  Nov-2017
#
#       loan_status pymnt_plan  url  desc             purpose  \
# 0         Current          n  NaN   NaN         credit_card
# 1         Current          n  NaN   NaN               other
# 2         Current          n  NaN   NaN               other
# 3         Current          n  NaN   NaN         credit_card
# 4         Current          n  NaN   NaN  debt_consolidation
# ...           ...        ...  ...   ...                 ...
# 19995     Current          n  NaN   NaN      major_purchase
# 19996     Current          n  NaN   NaN      major_purchase
# 19997  Fully Paid          n  NaN   NaN         credit_card
# 19998     Current          n  NaN   NaN  debt_consolidation
# 19999     Current          n  NaN   NaN  debt_consolidation
#
#                          title zip_code addr_state    dti  delinq_2yrs  \
# 0      Credit card refinancing    762xx         TX  14.82          0.0
# 1                        Other    295xx         SC  28.51          0.0
# 2                        Other    788xx         TX  11.62          0.0
# 3      Credit card refinancing    125xx         NY  22.88          0.0
# 4           Debt consolidation    672xx         KS  12.18          0.0
# ...                        ...      ...        ...    ...          ...
# 19995           Major purchase    370xx         TN   9.25          0.0
# 19996           Major purchase    481xx         MI  12.95          0.0
# 19997  Credit card refinancing    030xx         NH  16.77          0.0
# 19998       Debt consolidation    532xx         WI  32.80          0.0
# 19999       Debt consolidation    606xx         IL  20.72          0.0
#
#       earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# 0             Jul-2007             0.0                    34.0
# 1             Jun-2002             0.0                    39.0
# 2             Aug-2002             0.0                    44.0
# 3             Apr-2003             0.0                    74.0
# 4             Jun-1999             0.0                     NaN
# ...                ...             ...                     ...
# 19995         Oct-2005             1.0                    42.0
# 19996         Mar-1987             1.0                    27.0
# 19997         Jul-2002             2.0                    64.0
# 19998         May-2003             0.0                    65.0
# 19999         Nov-1999             0.0                     NaN
#
#        mths_since_last_record  open_acc  pub_rec  revol_bal  revol_util  \
# 0                         NaN       8.0      0.0       5225        73.6
# 1                        28.0      12.0      3.0       6953        51.9
# 2                         NaN       4.0      0.0       3401        97.2
# 3                         NaN       8.0      0.0      12918        59.5
# 4                         NaN       5.0      0.0       4497        91.8
# ...                       ...       ...      ...        ...         ...
# 19995                     NaN       6.0      0.0     128754        68.4
# 19996                     NaN       7.0      0.0       1536        30.7
# 19997                     NaN      11.0      0.0      23115        43.6
# 19998                     NaN      15.0      0.0      10432        60.0
# 19999                     NaN       8.0      0.0      19505        79.3
#
#        total_acc initial_list_status  out_prncp  out_prncp_inv   total_pymnt  \
# 
ol_bal_joint sec_app_earliest_cr_line  sec_app_inq_last_6mths  \
# 0                  NaN                      NaN                     NaN
# 1                  NaN                      NaN                     NaN
# 2                  NaN                      NaN                     NaN
# 3                  NaN                      NaN                     NaN
# 4                  NaN                      NaN                     NaN
# ...                ...                      ...                     ...
# 19995              NaN                      NaN                     NaN
# 19996              NaN                      NaN                     NaN
# 19997          40609.0                 Oct-2006                     1.0
# 19998          29018.0                 May-2004                     0.0
# 19999          69960.0                 Aug-1992                     1.0
#
#        sec_app_mort_acc  sec_app_open_acc  sec_app_revol_util  \
# 0                   NaN               NaN                 NaN
# 1                   NaN               NaN                 NaN
# 2                   NaN               NaN                 NaN
# 3                   NaN               NaN                 NaN
# 4                   NaN               NaN                 NaN
# ...                 ...               ...                 ...
# 19995               NaN               NaN                 NaN
# 19996               NaN               NaN                 NaN
# 19997               0.0              34.0                45.9
# 19998               1.0              11.0                56.0
# 19999               0.0               7.0                94.9
#
#        sec_app_open_act_il  sec_app_num_rev_accts  \
# 0                      NaN                    NaN
# 1                      NaN                    NaN
# 2                      NaN                    NaN
# 3                      NaN                    NaN
# 4                      NaN                    NaN
# ...                    ...                    ...
# 19995                  NaN                    NaN
# 19996                  NaN                    NaN
# 19997                 17.0                   30.0
# 19998                  1.0                   11.0
# 19999                  2.0                    8.0
#
#        sec_app_chargeoff_within_12_mths  sec_app_collections_12_mths_ex_med  \
# 0                                   NaN                                 NaN
# 1                                   NaN                                 NaN
# 2                                   NaN                                 NaN
# 3                                   NaN                                 NaN
# 4                                   NaN                                 NaN
# ...                                 ...                                 ...
# 19995                               NaN                                 NaN
# 19996                               NaN                                 NaN
# 19997                               0.0                                 0.0
# 19998                               0.0                                 0.0
# 19999                               0.0                                 0.0
#
#        sec_app_mths_since_last_major_derog hardship_flag hardship_type  \
# 0                                      NaN             N           NaN
# 1                                      NaN             N           NaN
# 2                                      NaN             N           NaN
# 3                                      NaN             N           NaN
# 4                                      NaN             N           NaN
# ...                                    ...           ...           ...
# 19995                                  NaN             N           NaN
# 19996                                  NaN             N           NaN
# 19997                                 69.0             N           NaN
# 19998                                  NaN             N           NaN
# 19999                                  NaN             N           NaN
#
#       hardship_reason hardship_status  deferral_term  hardship_amount  \
# 0                 NaN             NaN            NaN              NaN
# 1                 NaN             NaN            NaN              NaN
# 2                 NaN             NaN            NaN              NaN
# 3                 NaN             NaN            NaN              NaN
# 4                 NaN             NaN            NaN              NaN
# ...               ...             ...            ...              ...
# 19995             NaN             NaN            NaN              NaN
# 19996             NaN             NaN            NaN              NaN
# 19997             NaN             NaN            NaN              NaN
# 19998             NaN             NaN            NaN              NaN
# 19999             NaN             NaN            NaN              NaN
#
#       hardship_start_date hardship_end_date payment_plan_start_date  \
# 0                     NaN               NaN                     NaN
# 1                     NaN               NaN                     NaN
# 2                     NaN               NaN                     NaN
# 3                     NaN               NaN                     NaN
# 4                     NaN               NaN                     NaN
# ...                   ...               ...                     ...
# 19995                 NaN               NaN                     NaN
# 19996                 NaN               NaN                     NaN
# 19997                 NaN               NaN                     NaN
# 19998                 NaN               NaN                     NaN
# 19999                 NaN               NaN                     NaN
#
#        hardship_length  hardship_dpd hardship_loan_status  \
# 0                  NaN           NaN                  NaN
# 1                  NaN           NaN                  NaN
# 2                  NaN           NaN                  NaN
# 3                  NaN           NaN                  NaN
# 4                  NaN           NaN                  NaN
# ...                ...           ...                  ...
# 19995              NaN           NaN                  NaN
# 19996              NaN           NaN                  NaN
# 19997              NaN           NaN                  NaN
# 19998              NaN           NaN                  NaN
# 19999              NaN           NaN                  NaN
#
#        orig_projected_additional_accrued_interest  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 19995                                         NaN
# 19996                                         NaN
# 19997                                         NaN
# 19998                                         NaN
# 19999                                         NaN
#
#        hardship_payoff_balance_amount  hardship_last_payment_amount  \
# 0                                 NaN                           NaN
# 1                                 NaN                           NaN
# 2                                 NaN                           NaN
# 3                                 NaN                           NaN
# 4                                 NaN                           NaN
# ...                               ...                           ...
# 19995                             NaN                           NaN
# 19996                             NaN                           NaN
# 19997                             NaN                           NaN
# 19998                             NaN                           NaN
# 19999                             NaN                           NaN
#
#       disbursement_method debt_settlement_flag debt_settlement_flag_date  \
# 0                    Cash                    N                       NaN
# 1                    Cash                    N                       NaN
# 2                    Cash                    N                       NaN
# 3                    Cash                    N                       NaN
# 4                    Cash                    N                       NaN
# ...                   ...                  ...                       ...
# 19995                Cash                    N                       NaN
# 19996                Cash                    N                       NaN
# 19997                Cash                    N                       NaN
# 19998                Cash                    N                       NaN
# 19999                Cash                    N                       NaN
#
#       settlement_status settlement_date  settlement_amount  \
# 0                   NaN             NaN                NaN
# 1                   NaN             NaN                NaN
# 2                   NaN             NaN                NaN
# 3                   NaN             NaN                NaN
# 4                   NaN             NaN                NaN
# ...                 ...             ...                ...
# 19995               NaN             NaN                NaN
# 19996               NaN             NaN                NaN
# 19997               NaN             NaN                NaN
# 19998               NaN             NaN                NaN
# 19999               NaN             NaN                NaN
#
#        settlement_percentage  settlement_term
# 0                        NaN              NaN
# 1                        NaN              NaN
# 2                        NaN              NaN
# 3                        NaN              NaN
# 4                        NaN              NaN
# ...                      ...              ...
# 19995                    NaN              NaN
# 19996                    NaN              NaN
# 19997                    NaN              NaN
# 19998                    NaN              NaN
# 19999                    NaN              NaN
#
# [20000 rows x 145 columns]

# %%
# !pip install xlrd
# Out:
# Requirement already satisfied: xlrd in c:\users\tjtmd\anaconda3\lib\site-packages (2.0.1)

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\tjtmd\anaconda3\lib\site-packages (3.0.9)
# Requirement already satisfied: et-xmlfile in c:\users\tjtmd\anaconda3\lib\site-packages (from openpyxl) (1.1.0)

# %%
# 만약 모듈을 찾을 수 없는 오류가 발생한다면 추가 모듈 설치
# 필요 모듈 import
# !pip install pyxlsb
# Out:
# Collecting pyxlsb
#   Downloading pyxlsb-1.0.9-py2.py3-none-any.whl (23 kB)
# Installing collected packages: pyxlsb
# Successfully installed pyxlsb-1.0.9

# %%
# 엑셀파일에 시트에 따라 데이터 구분이 지어진 경우 시트별로 데이터프레임 제작 가능
# 다른 엑셀파일형식을 가져올 때 engine파라메터 추가해주시면 됩니다.
df1 = pd.read_excel('./data/loan1.xlsx')
"""df1 = pd.read_excel('./data/loan1.xlsx', 
                    sheet_name='구매영수증상세+상품마스터포함', 
                    engine='pyxlsb',
                    encoding='utf-8') # 윈도우의 경우 cp949"""
# Out:
# "df1 = pd.read_excel('./data/loan1.xlsx', \n                    sheet_name='구매영수증상세+상품마스터포함', \n                    engine='pyxlsb',\n                    encoding='utf-8') # 윈도우의 경우 cp949"

# %%
df1
# Out:
#        Unnamed: 0  id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0               0 NaN        NaN      10000        10000          10000.0
# 1               1 NaN        NaN       3500         3500           3500.0
# 2               2 NaN        NaN       5000         5000           5000.0
# 3               3 NaN        NaN      14000        14000          14000.0
# 4               4 NaN        NaN       5000         5000           5000.0
# ...           ...  ..        ...        ...          ...              ...
# 49995       49995 NaN        NaN      13000        13000          13000.0
# 49996       49996 NaN        NaN      12000        12000          12000.0
# 49997       49997 NaN        NaN      20000        20000          20000.0
# 49998       49998 NaN        NaN       7000         7000           7000.0
# 49999       49999 NaN        NaN       6000         6000           6000.0
#
#              term  int_rate  installment grade sub_grade  \
# 0       36 months      9.44       320.05     B        B1
# 1       36 months     10.42       113.63     B        B3
# 2       36 months     13.59       169.90     C        C2
# 3       36 months     10.91       457.75     B        B4
# 4       36 months     13.59       169.90     C        C2
# ...           ...       ...          ...   ...       ...
# 49995   60 months     18.06       330.54     D        D2
# 49996   60 months     13.59       276.68     C        C2
# 49997   60 months     15.05       476.33     C        C4
# 49998   36 months      7.35       217.27     A        A4
# 49999   36 months     13.59       203.88     C        C2
#
#                     emp_title emp_length home_ownership  annual_inc  \
# 0                    mechanic    6 years       MORTGAGE     80000.0
# 1                         NaN        NaN            OWN     90000.0
# 2                Truck driver  10+ years            OWN    168000.0
# 3      Confidential Secretary    2 years           RENT     39000.0
# 4             General Manager   < 1 year           RENT     55000.0
# ...                       ...        ...            ...         ...
# 49995     Clinical Supervisor  10+ years           RENT     60000.0
# 49996              consultant    2 years           RENT     90000.0
# 49997       Controls Engineer    2 years       MORTGAGE    105000.0
# 49998            Hair Stylist   < 1 year           RENT     30000.0
# 49999          Store manager      1 year           RENT     50000.0
#
#       verification_status   issue_d loan_status pymnt_plan  url  desc  \
# 0            Not Verified  Dec-2017     Current          n  NaN   NaN
# 1            Not Verified  Dec-2017     Current          n  NaN   NaN
# 2            Not Verified  Dec-2017     Current          n  NaN   NaN
# 3         Source Verified  Dec-2017     Current          n  NaN   NaN
# 4            Not Verified  Dec-2017     Current          n  NaN   NaN
# ...                   ...       ...         ...        ...  ...   ...
# 49995        Not Verified  Nov-2017     Current          n  NaN   NaN
# 49996        Not Verified  Nov-2017  Fully Paid          n  NaN   NaN
# 49997        Not Verified  Nov-2017     Current          n  NaN   NaN
# 49998            Verified  Nov-2017     Current          n  NaN   NaN
# 49999        Not Verified  Nov-2017  Fully Paid          n  NaN   NaN
#
#                   purpose                    title zip_code addr_state    dti  \
# 0             credit_card  Credit card refinancing    762xx         TX  14.82
# 1                   other                    Other    295xx         SC  28.51
# 2                   other                    Other    788xx         TX  11.62
# 3             credit_card  Credit card refinancing    125xx         NY  22.88
# 4      debt_consolidation       Debt consolidation    672xx         KS  12.18
# ...                   ...                      ...      ...        ...    ...
# 49995  debt_consolidation       Debt consolidation    554xx         MN  37.24
# 49996         credit_card  Credit card refinancing    773xx         TX   6.19
# 49997  debt_consolidation       Debt consolidation    458xx         OH  15.17
# 49998         credit_card  Credit card refinancing    112xx         NY  32.64
# 49999         credit_card  Credit card refinancing    060xx         CT   8.19
#
#        delinq_2yrs earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# 0                0         Jul-2007               0                    34.0
# 1                0         Jun-2002               0                    39.0
# 2                0         Aug-2002               0                    44.0
# 3                0         Apr-2003               0                    74.0
# 4                0         Jun-1999               0                     NaN
# ...            ...              ...             ...                     ...
# 49995            0         Jun-2003               1                     NaN
# 49996            0         Sep-2003               1                     NaN
# 49997            0         Sep-2005               0                     NaN
# 49998            1         Nov-2000               0                    10.0
# 49999            0         Mar-2006               1                     NaN
#
#        mths_since_last_record  open_acc  pub_rec  revol_bal  revol_util  \
# 0                         NaN         8        0       5225        73.6
# 1                        28.0        12        3       6953        51.9
# 2                         NaN         4        0       3401        97.2
# 3                         NaN         8        0      12918        59.5
# 4                         NaN         5        0       4497        91.8
# ...                       ...       ...      ...        ...         ...
# 49995                     NaN        25        0      12046        35.3
# 49996                     NaN        12        0      16142        29.1
# 49997                     NaN         9        0       4791        51.0
# 49998                     NaN        11        0       6654        15.7
# 49999                     NaN        14        0       6500        38.7
#
#        total_acc initial_list_status  out_prncp  out_prncp_inv   total_pymnt  \
# 0             30                   w    6442.28        6442.28   4493.810000
# 1             38                   w    2266.55        2266.55   1586.770000
# 2             12                   w    3291.95        3291.95   2371.050000
# 3             16                   w    9090.87        9090.87   6391.530000
# 4              6                   w    3291.95        3291.95   2371.050000
# ...          ...                 ...        ...            ...           ...
# 49995         44                   w   10748.94       10748.94   4932.010000
# 49996         25                   w       0.00           0.00  13886.761900
# 49997         34                   w   16309.59       16309.59   7128.230000
# 49998         28                   w    4268.88        4268.88   3256.190000
# 49999         15                   w       0.00           0.00   6451.428886
#
#        total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  \
# 0              4493.81          3557.72         936.09                 0.0
# 1              1586.77          1233.45         353.32                 0.0
# 2              2371.05          1708.05         663.00                 0.0
# 3              6391.53          4909.13        1482.40                 0.0
# 4              2371.05          1708.05         663.00                 0.0
# ...                ...              ...            ...                 ...
# 49995          4932.01          2251.06        2680.95                 0.0
# 49996         13886.76         12000.00        1886.76                 0.0
# 49997          7128.23          3690.41        3437.82                 0.0
# 49998          3256.19          2731.12         525.07                 0.0
# 49999          6451.43          6000.00         451.43                 0.0
#
#        recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt  \
# 0             0
100.0
#
#        percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 0                  25.0                     0          0           196130
# 1                  75.0                     0          3           416685
# 2                 100.0                     0          0            82176
# 3                  33.3                     0          0            38704
# 4                 100.0                     0          0            26841
# ...                 ...                   ...        ...              ...
# 49995              25.0                     0          0           160629
# 49996              14.3                     0          0           151664
# 49997             100.0                     0          0           159023
# 49998               0.0                     0          0            77748
# 49999              14.3                     0          0            22060
#
#        total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# 0                  17756            7100                       31992
# 1                  83454            4600                      110595
# 2                  51673            3500                       78676
# 3                  29103           18900                       17004
# 4                   7202            4900                       21941
# ...                  ...             ...                         ...
# 49995             108816           32100                      126529
# 49996             115385           55400                       96264
# 49997              50711            2300                       61623
# 49998              31450           31500                       35248
# 49999              11645           13500                        5260
#
#        revol_bal_joint sec_app_earliest_cr_line  sec_app_inq_last_6mths  \
# 0                  NaN                      NaN                     NaN
# 1                  NaN                      NaN                     NaN
# 2                  NaN                      NaN                     NaN
# 3                  NaN                      NaN                     NaN
# 4                  NaN                      NaN                     NaN
# ...                ...                      ...                     ...
# 49995              NaN                      NaN                     NaN
# 49996              NaN                      NaN                     NaN
# 49997              NaN                      NaN                     NaN
# 49998          11338.0                 Aug-2014                     0.0
# 49999              NaN                      NaN                     NaN
#
#        sec_app_mort_acc  sec_app_open_acc  sec_app_revol_util  \
# 0                   NaN               NaN                 NaN
# 1                   NaN               NaN                 NaN
# 2                   NaN               NaN                 NaN
# 3                   NaN               NaN                 NaN
# 4                   NaN               NaN                 NaN
# ...                 ...               ...                 ...
# 49995               NaN               NaN                 NaN
# 49996               NaN               NaN                 NaN
# 49997               NaN               NaN                 NaN
# 49998               0.0               4.0                62.2
# 49999               NaN               NaN                 NaN
#
#        sec_app_open_act_il  sec_app_num_rev_accts  \
# 0                      NaN                    NaN
# 1                      NaN                    NaN
# 2                      NaN                    NaN
# 3                      NaN                    NaN
# 4                      NaN                    NaN
# ...                    ...                    ...
# 49995                  NaN                    NaN
# 49996                  NaN                    NaN
# 49997                  NaN                    NaN
# 49998                  0.0                    4.0
# 49999                  NaN                    NaN
#
#        sec_app_chargeoff_within_12_mths  sec_app_collections_12_mths_ex_med  \
# 0                                   NaN                                 NaN
# 1                                   NaN                                 NaN
# 2                                   NaN                                 NaN
# 3                                   NaN                                 NaN
# 4                                   NaN                                 NaN
# ...                                 ...                                 ...
# 49995                               NaN                                 NaN
# 49996                               NaN                                 NaN
# 49997                               NaN                                 NaN
# 49998                               0.0                                 0.0
# 49999                               NaN                                 NaN
#
#        sec_app_mths_since_last_major_derog hardship_flag hardship_type  \
# 0                                      NaN             N           NaN
# 1                                      NaN             N           NaN
# 2                                      NaN             N           NaN
# 3                                      NaN             N           NaN
# 4                                      NaN             N           NaN
# ...                                    ...           ...           ...
# 49995                                  NaN             N           NaN
# 49996                                  NaN             N           NaN
# 49997                                  NaN             N           NaN
# 49998                                  NaN             N           NaN
# 49999                                  NaN             N           NaN
#
#       hardship_reason hardship_status  deferral_term  hardship_amount  \
# 0                 NaN             NaN            NaN              NaN
# 1                 NaN             NaN            NaN              NaN
# 2                 NaN             NaN            NaN              NaN
# 3                 NaN             NaN            NaN              NaN
# 4                 NaN             NaN            NaN              NaN
# ...               ...             ...            ...              ...
# 49995             NaN             NaN            NaN              NaN
# 49996             NaN             NaN            NaN              NaN
# 49997             NaN             NaN            NaN              NaN
# 49998             NaN             NaN            NaN              NaN
# 49999             NaN             NaN            NaN              NaN
#
#       hardship_start_date hardship_end_date payment_plan_start_date  \
# 0                     NaN               NaN                     NaN
# 1                     NaN               NaN                     NaN
# 2                     NaN               NaN                     NaN
# 3                     NaN               NaN                     NaN
# 4                     NaN               NaN                     NaN
# ...                   ...               ...                     ...
# 49995                 NaN               NaN                     NaN
# 49996                 NaN               NaN                     NaN
# 49997                 NaN               NaN                     NaN
# 49998                 NaN               NaN                     NaN
# 49999                 NaN               NaN                     NaN
#
#        hardship_length  hardship_dpd hardship_loan_status  \
# 0                  NaN           NaN                  NaN
# 1                  NaN           NaN                  NaN
# 2                  NaN           NaN                  NaN
# 3                  NaN           NaN                  NaN
# 4                  NaN           NaN                  NaN
# ...                ...           ...                  ...
# 49995              NaN           NaN                  NaN
# 49996              NaN           NaN                  NaN
# 49997              NaN           NaN                  NaN
# 49998              NaN           NaN                  NaN
# 49999              NaN           NaN                  NaN
#
#        orig_projected_additional_accrued_interest  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 49995                                         NaN
# 49996                                         NaN
# 49997                                         NaN
# 49998                                         NaN
# 49999                                         NaN
#
#        hardship_payoff_balance_amount  hardship_last_payment_amount  \
# 0                                 NaN                           NaN
# 1                                 NaN                           NaN
# 2                                 NaN                           NaN
# 3                                 NaN                           NaN
# 4                                 NaN                           NaN
# ...                               ...                           ...
# 49995                             NaN                           NaN
# 49996                             NaN                           NaN
# 49997                             NaN                           NaN
# 49998                             NaN                           NaN
# 49999                             NaN                           NaN
#
#       disbursement_method debt_settlement_flag debt_settlement_flag_date  \
# 0                    Cash                    N                       NaN
# 1                    Cash                    N                       NaN
# 2                    Cash                    N                       NaN
# 3                    Cash                    N                       NaN
# 4                    Cash                    N                       NaN
# ...                   ...                  ...                       ...
# 49995                Cash                    N                       NaN
# 49996                Cash                    N                       NaN
# 49997                Cash                    N                       NaN
# 49998                Cash                    N                       NaN
# 49999                Cash                    N                       NaN
#
#       settlement_status settlement_date  settlement_amount  \
# 0                   NaN             NaN                NaN
# 1                   NaN             NaN                NaN
# 2                   NaN             NaN                NaN
# 3                   NaN             NaN                NaN
# 4                   NaN             NaN                NaN
# ...                 ...             ...                ...
# 49995               NaN             NaN                NaN
# 49996               NaN             NaN                NaN
# 49997               NaN             NaN                NaN
# 49998               NaN             NaN                NaN
# 49999               NaN             NaN                NaN
#
#        settlement_percentage  settlement_term
# 0                        NaN              NaN
# 1                        NaN              NaN
# 2                        NaN              NaN
# 3                        NaN              NaN
# 4                        NaN              NaN
# ...                      ...              ...
# 49995                    NaN              NaN
# 49996                    NaN              NaN
# 49997                    NaN              NaN
# 49998                    NaN              NaN
# 49999                    NaN              NaN
#
# [50000 rows x 146 columns]

# %%
# Out:
# \    /\
#  )  ( ')
# (  /  )
#  \(__)|

# %%
# 참고! 실습은 하지 않습니다만 쿼리를 사용하여 데이터베이스로부터 데이터프레임을 만드는 것도 가능합니다.
# 데이터베이스로 부터 자료 읽기

# 필요한 모듈 추가 설치 - 각 데이터베이스 별로 다릅니다.
# !pip install pymysql

# sql 모듈 로드하기
# import pymysql
# mysql, mariadb, sqlite, postgresql, ms-sql, oracle, mongodb

# 접속하기
# 접속방법 또한 DB 종류에 따라 다릅니다.
# con = pymysql.connect(host='db서버주소', port=3306, user='id', passwd='pwd', db='dbname')

# query 만들기
# query = 'select * from samples'

# 자료 불러오기
# data = pd.read_sql(query, con=con)

# %% [markdown]
# ### 데이터 저장하기
# 불러들인 혹은 작업을 마친 데이터프레임을 다양한 파일형태로 저장이 가능합니다.
#
# > **`to_csv()`**
# **`to_excel()`**
# **`to_sql()`**

# %%
# index=False 파라메터는 기존 데이터프레임의 인덱스를 무시하고 저장
df.to_csv('./data/save_test.csv', index=False)

# %% [markdown]
# ### 사용 데이터 간략 설명
# > 미국 핀테크 회사인 lending club의 대출 데이터베이스
# 클라우드펀딩과 대출을 결합한 핀테크의 시초라고 부를 수 있는 회사
# 방대한 양의 대출정보를 공개하면서 금융정보분석에도 기여한 공이 큰 데이터
# 2007 ~ 2015 년 대출정보 및 개인정보를 담고 있음
# 226만건, 145항목 정보를 담고있음
# 실습데이터는 이 중 4만건을 추출한 데이터를 사용합니다.
#
# 데이터출처: https://www.kaggle.com/wordsforthewise/lending-club

# %% [markdown]
# ### 데이터 살펴보기

# %%
# 데이터를 불러들인 후 가장 처음 하는 작업
# 데이터의 구조, 형태 파악하기
# 데이터의 첫 5개 데이터 하나(샘플, 인스턴스) 확인하기
df.head()
# 10개를 확인하려면?
# Out:
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN      10000        10000          10000.0   36 months
# 1 NaN        NaN       3500         3500           3500.0   36 months
# 2 NaN        NaN       5000         5000           5000.0   36 months
# 3 NaN        NaN      14000        14000          14000.0   36 months
# 4 NaN        NaN       5000         5000           5000.0   36 months
#
#    int_rate  installment grade sub_grade               emp_title emp_length  \
# 0      9.44       320.05     B        B1                mechanic    6 years
# 1     10.42       113.63     B        B3                     NaN        NaN
# 2     13.59       169.90     C        C2            Truck driver  10+ years
# 3     10.91       457.75     B        B4  Confidential Secretary    2 years
# 4     13.59       169.90     C        C2         General Manager   < 1 year
#
#   home_ownership  annual_inc verification_status   issue_d loan_status  \
# 0       MORTGAG
0
#
#    total_cu_tl  inq_last_12m  acc_open_past_24mths  avg_cur_bal  \
# 0          0.0           0.0                   2.0      21639.0
# 1          5.0           1.0                   5.0      28252.0
# 2          0.0           3.0                   1.0      12918.0
# 3          6.0           0.0                   7.0       3638.0
# 4          1.0           0.0                   0.0       1440.0
#
#    bc_open_to_buy  bc_util  chargeoff_within_12_mths  delinq_amnt  \
# 0          1875.0     73.6                       0.0          0.0
# 1           808.0     82.4                       0.0          0.0
# 2            99.0     97.2                       0.0          0.0
# 3          7265.0     61.6                       0.0          0.0
# 4           403.0     91.8                       0.0          0.0
#
#    mo_sin_old_il_acct  mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  \
# 0               125.0                  78.0                   26.0
# 1               164.0                 186.0                    7.0
# 2               135.0                 184.0                   54.0
# 3                36.0                 176.0                    7.0
# 4               149.0                 222.0                   43.0
#
#    mo_sin_rcnt_tl  mort_acc  mths_since_recent_bc  mths_since_recent_bc_dlq  \
# 0            23.0       3.0                  26.0                       NaN
# 1             7.0       2.0                   7.0                      39.0
# 2             5.0       0.0                  54.0                      44.0
# 3             4.0       0.0                   7.0                       NaN
# 4            43.0       0.0                  43.0                       NaN
#
#    mths_since_recent_inq  mths_since_recent_revol_delinq  \
# 0                   21.0                             NaN
# 1                    7.0                            39.0
# 2                    5.0                            44.0
# 3                   16.0                            74.0
# 4                    NaN                             NaN
#
#    num_accts_ever_120_pd  num_actv_bc_tl  num_actv_rev_tl  num_bc_sats  \
# 0                    0.0             2.0              2.0          4.0
# 1                    0.0             4.0              7.0          4.0
# 2                    2.0             1.0              1.0          1.0
# 3                    1.0             2.0              4.0          3.0
# 4                    0.0             4.0              4.0          4.0
#
#    num_bc_tl  num_il_tl  num_op_rev_tl  num_rev_accts  num_rev_tl_bal_gt_0  \
# 0        4.0       21.0            4.0            5.0                  2.0
# 1       10.0       19.0            7.0           17.0                  7.0
# 2        4.0        6.0            1.0            6.0                  1.0
# 3        4.0        4.0            7.0           12.0                  4.0
# 4        4.0        2.0            4.0            4.0                  4.0
#
#    num_sats  num_tl_120dpd_2m  num_tl_30dpd  num_tl_90g_dpd_24m  \
# 0       8.0               0.0           0.0                 0.0
# 1      12.0               0.0           0.0                 0.0
# 2       4.0               0.0           0.0                 0.0
# 3       8.0               0.0           0.0                 0.0
# 4       5.0               0.0           0.0                 0.0
#
#    num_tl_op_past_12m  pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  \
# 0                 0.0            96.4              25.0                   0.0
# 1                 1.0            97.3              75.0                   0.0
# 2                 1.0            83.3             100.0                   0.0
# 3                 2.0            93.8              33.3                   0.0
# 4                 0.0           100.0             100.0                   0.0
#
#    tax_liens  tot_hi_cred_lim  total_bal_ex_mort  total_bc_limit  \
# 0        0.0         196130.0            17756.0          7100.0
# 1        3.0         416685.0            83454.0          4600.0
# 2        0.0          82176.0            51673.0          3500.0
# 3        0.0          38704.0            29103.0         18900.0
# 4        0.0          26841.0             7202.0          4900.0
#
#    total_il_high_credit_limit  revol_bal_joint sec_app_earliest_cr_line  \
# 0                     31992.0              NaN                      NaN
# 1                    110595.0              NaN                      NaN
# 2                     78676.0              NaN                      NaN
# 3                     17004.0              NaN                      NaN
# 4                     21941.0              NaN                      NaN
#
#    sec_app_inq_last_6mths  sec_app_mort_acc  sec_app_open_acc  \
# 0                     NaN               NaN               NaN
# 1                     NaN               NaN               NaN
# 2                     NaN               NaN               NaN
# 3                     NaN               NaN               NaN
# 4                     NaN               NaN               NaN
#
#    sec_app_revol_util  sec_app_open_act_il  sec_app_num_rev_accts  \
# 0                 NaN                  NaN                    NaN
# 1                 NaN                  NaN                    NaN
# 2                 NaN                  NaN                    NaN
# 3                 NaN                  NaN                    NaN
# 4                 NaN                  NaN                    NaN
#
#    sec_app_chargeoff_within_12_mths  sec_app_collections_12_mths_ex_med  \
# 0                               NaN                                 NaN
# 1                               NaN                                 NaN
# 2                               NaN                                 NaN
# 3                               NaN                                 NaN
# 4                               NaN                                 NaN
#
#    sec_app_mths_since_last_major_derog hardship_flag hardship_type  \
# 0                                  NaN             N           NaN
# 1                                  NaN             N           NaN
# 2                                  NaN             N           NaN
# 3                                  NaN             N           NaN
# 4                                  NaN             N           NaN
#
#   hardship_reason hardship_status  deferral_term  hardship_amount  \
# 0             NaN             NaN            NaN              NaN
# 1             NaN             NaN            NaN              NaN
# 2             NaN             NaN            NaN              NaN
# 3             NaN             NaN            NaN              NaN
# 4             NaN             NaN            NaN              NaN
#
#   hardship_start_date hardship_end_date payment_plan_start_date  \
# 0                 NaN               NaN                     NaN
# 1                 NaN               NaN                     NaN
# 2                 NaN               NaN                     NaN
# 3                 NaN               NaN                     NaN
# 4                 NaN               NaN                     NaN
#
#    hardship_length  hardship_dpd hardship_loan_status  \
# 0              NaN           NaN                  NaN
# 1              NaN           NaN                  NaN
# 2              NaN           NaN                  NaN
# 3              NaN           NaN                  NaN
# 4              NaN           NaN                  NaN
#
#    orig_projected_additional_accrued_interest  hardship_payoff_balance_amount  \
# 0                                         NaN                             NaN
# 1                                         NaN                             NaN
# 2                                         NaN                             NaN
# 3                                         NaN                             NaN
# 4                                         NaN                             NaN
#
#    hardship_last_payment_amount disbursement_method debt_settlement_flag  \
# 0                           NaN                Cash                    N
# 1                           NaN                Cash                    N
# 2                           NaN                Cash                    N
# 3                           NaN                Cash                    N
# 4                           NaN                Cash                    N
#
#   debt_settlement_flag_date settlement_status settlement_date  \
# 0                       NaN               NaN             NaN
# 1                       NaN               NaN             NaN
# 2                       NaN               NaN             NaN
# 3                       NaN               NaN             NaN
# 4                       NaN               NaN             NaN
#
#    settlement_amount  settlement_percentage  settlement_term
# 0                NaN                    NaN              NaN
# 1                NaN                    NaN              NaN
# 2                NaN                    NaN              NaN
# 3                NaN                    NaN              NaN
# 4                NaN                    NaN              NaN

# %%
# 데이터의 마지막 5개 샘플 확인하기
# 데이터가 잘 가져왔는지 확인 할 때 보통 씁니다.
df

# %%
# 데이터의 갯수를 살펴봅니다
df.shape
# Out:
# (20000, 145)

# %%
# 데이터의 전반적인 정보를 확인합니다.
df.info()
# dtype 정보에서는 각 컬럼별 데이터 타입을 확인 할 수 있습니다.
# object == str 이라고 생각하셔도 무방합니다.
# verbose, null_counts
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 145 columns):
#  #    Column                                      Non-Null Count  Dtype
# ---   ------                                      --------------  -----
#  0    id                                          0 non-null      float64
#  1    member_id                                   0 non-null      float64
#  2    loan_amnt                                   20000 non-null  int64
#  3    funded_amnt                                 20000 non-null  int64
#  4    funded_amnt_inv                             20000 non-null  float64
#  5    term                                        20000 non-null  object
#  6    int_rate                                    20000 non-null  float64
#  7    installment                                 20000 non-null  float64
#  8    grade                                       20000 non-null  object
#  9    sub_grade                                   20000 non-null  object
#  10   emp_title                                   18269 non-null  object
#  11   emp_length                                  18296 non-null  object
#  12   home_ownership                              20000 non-null  object
#  13   annual_inc                                  20000 non-null  float64
#  14   verification_status                         20000 non-null  object
#  15   issue_d                                     20000 non-null  object
#  16   loan_status                                 20000 non-null  object
#  17   pymnt_plan                                  20000 non-null  object
#  18   url                                         0 non-null      float64
#  19   desc                                        0 non-null      float64
#  20   purpose                                     20000 non-null  object
#  21   title                                       20000 non-null  object
#  22   zip_code                                    20000 non-null  object
#  23   addr_state                                  20000 non-null  object
#  24   dti                                         19961 non-null  float64
#  25   delinq_2yrs                                 20000 non-null  float64
#  26   earliest_cr_line                            20000 non-null  object
#  27   inq_last_6mths                              20000 non-null  float64
#  28   mths_since_last_delinq                      8992 non-null   float64
#  29   mths_since_last_record                      2914 non-null   float64
#  30   open_acc                                    20000 non-null  float64
#  31   pub_rec                                     20000 non-null  float64
#  32   revol_bal                                   20000 non-null  int64
#  33   revol_util                                  19963 non-null  float64
#  34   total_acc                                   20000 non-null  float64
#  35   initial_list_status                         20000 non-null  object
#  36   out_prncp                                   20000 non-null  float64
#  37   out_prncp_inv                               20000 non-null  float64
#  38   total_pymnt                                 20000 non-null  float64
#  39   total_pymnt_inv                             20000 non-null  float64
#  40   total_rec_prncp                             20000 non-null  float64
#  41   total_rec_int                               20000 non-null  float64
#  42   total_rec_late_fee                          20000 non-null  float64
#  43   recoveries                                  20000 non-null  float64
#  44   collection_recovery_fee                     20000 non-null  float64
#  45   last_pymnt_d                                19970 non-null  object
#  46   last_pymnt_amnt                             20000 non-null  float64
#  47   next_pymnt_d                                15056 non-null  object
#  48   last_credit_pull_d                          20000 non-null  object
#  49   collections_12_mths_ex_med                  20000 non-null  float64
#  50   mths_since_last_major_derog                 4862 non-null   float64
#  51   policy_code                                 20000 non-null  int64
#  52   application_type                            20000 non-null  object
#  53   annual_inc_joint                            2792 non-null   float64
#  54   dti_joint                                   2792 non-null   float64
#  55   verification_status_joint                   2792 non-null   object
#  56   acc_now_delinq                              20000 non-null  float64
#  57   tot_coll_amt                                20000 non-null  float64
#  58   tot_cur_bal                                 20000 non-null  float64
#  59   open_acc_6m                                 20000 non-null  float64
#  60   open_act_il                                 20000 non-null  float64
#  61   open_il_12m                                 20000 non-null  float64
#  62   open_il_24m                                 20000 non-null  float64
#  63   mths_since_rcnt_il                          19242 non-null  float64
#  64   total_bal_il                                20000 non-null  float64
#  65   il_util                                     16740 non-null  float64
#  66   open_rv_12m                                 20000 non-null  float64
#  67   open_rv_24m                                 20000 non-null  float64
#  68   max_bal_bc                                  20000 non-null  float64
#  69   all_util                                    19994 non-null  float64
#  70   total_rev_hi_lim                            20000 non-null  float64
#  71   inq_fi                                      20000 non-null  float64
#  72   total_cu_tl                                 20000 non-null  float64
#  73   inq_last_12m                                20000 non-null  float64
#  74   acc_open_past_24mths                        20000 non-null  float64
#  75   avg_cur_bal                                 19997 non-null  float64
#  76   bc_open_to_buy                              19653 non-null  float64
#  77   bc_util                                     19646 non-null  float64
#  78   chargeoff_within_12_mths                    20000 non-null  float64
#  79   delinq_amnt                                 20000 non-null  float64
#  80   mo_sin_old_il_acct                          19242 non-null  float64
#  81   mo_sin_old_rev_tl_op                        20000 non-null  float64
#  82   mo_sin_rcnt_rev_tl_op                       20000 non-null  float64
#  83   mo_sin_rcnt_tl                              20000 non-null  float64
#  84   mort_acc                                    20000 non-null  float64
#  85   mths_since_recent_bc                        19672 non-null  float64
#  86   mths_since_recent_bc_dlq                    4076 non-null   float64
#  87   mths_since_recent_inq                       17495 non-null  float64
#  88   mths_since_recent_revol_delinq              5889 non-null   float64
#  89   num_accts_ever_120_pd                       20000 non-null  float64
#  90   num_actv_bc_tl                              20000 non-null  float64
#  91   num_actv_rev_tl                             20000 non-null  float64
#  92   num_bc_sats                                 20000 non-null  float64
#  93   num_bc_tl                                   20000 non-null  float64
#  94   num_il_tl                                   20000 non-null  float64
#  95   num_op_rev_tl                               20000 non-null  float64
#  96   num_rev_accts                               20000 non-null  float64
#  97   num_rev_tl_bal_gt_0                         20000 non-null  float64
#  98   num_sats                                    20000 non-null  float64
#  99   num_tl_120dpd_2m                            18819 non-null  float64
#  100  num_tl_30dpd                                20000 non-null  float64
#  101  num_tl_90g_dpd_24m                          20000 non-null  float64
#  102  num_tl_op_past_12m                          20000 non-null  float64
#  103  pct_tl_nvr_dlq                              20000 non-null  float64
#  104  percent_bc_gt_75                            19651 non-null  float64
#  105  pub_rec_bankruptcies                        20000 non-null  float64
#  106  tax_liens                                   20000 non-null  float64
#  107  tot_hi_cred_lim                             20000 non-null  float64
#  108  total_bal_ex_mort                           20000 non-null  float64
#  109  total_bc_limit                              20000 non-null  float64
#  110  total_il_high_credit_limit                  20000 non-null  float64
#  111  revol_bal_joint                             2792 non-null   float64
#  112  sec_app_earliest_cr_line                    2792 non-null   object
#  113  sec_app_inq_last_6mths                      2792 non-null   float64
#  114  sec_app_mort_acc                            2792 non-null   float64
#  115  sec_app_open_acc                            2792 non-null   float64
#  116  sec_app_revol_util                          2745 non-null   float64
#  117  sec_app_open_act_il                         2792 non-null   float64
#  118  sec_app_num_rev_accts                       2792 non-null   float64
#  119  sec_app_chargeoff_within_12_mths            2792 non-null   float64
#  120  sec_app_collections_12_mths_ex_med          2792 non-null   float64
#  121  sec_app_mths_since_last_major_derog         998 non-null    float64
#  122  hardship_flag                               20000 non-null  object
#  123  hardship_type                               64 non-null     object
#  124  hardship_reason                             64 non-null     object
#  125  hardship_status                             64 non-null     object
#  126  deferral_term                               64 non-null     float64
#  127  hardship_amount                             64 non-null     float64
#  128  hardship_start_date                         64 non-null     object
#  129  hardship_end_date                           64 non-null     object
#  130  payment_plan_start_date                     64 non-null     object
#  131  hardship_length                             64 non-null     float64
#  132  hardship_dpd                                64 non-null     float64
#  133  hardship_loan_status                        64 non-null     object
#  134  orig_projected_additional_accrued_interest  50 non-null     float64
#  135  hardship_payoff_balance_amount              64 non-null     float64
#  136  hardship_last_payment_amount                64 non-null     float64
#  137  disbursement_method                         20000 non-null  object
#  138  debt_settlement_flag                        20000 non-null  object
#  139  debt_settlement_flag_date                   61 non-null     object
#  140  settlement_status                           61 non-null     object
#  141  settlement_date                             61 non-null     object
#  142  settlement_amount                           61 non-null     float64
#  143  settlement_percentage                       61 non-null     float64
#  144  settlement_term                             61 non-null     float64
# dtypes: float64(106), int64(4), object(35)
# memory usage: 22.1+ MB

# %%
# 데이터의 기초통계량을 확인합니다.
df.describe()
# Out:
#         id  member_id     loan_amnt   funded_amnt  funded_amnt_inv  \
# count  0.0        0.0  20000.000000  20000.000000     20000.000000
# mean   NaN        NaN  15382.568750  15382.568750     15373.741922
# std    NaN        NaN  10011.645757  10011.645757     10010.591629
# min    NaN        NaN   1000.000000   1000.000000      1000.000000
# 25%    NaN        NaN   8000.000000   8000.000000      7975.000000
# 50%    NaN        NaN  12500.000000  12500.000000     12500.000000
# 75%    NaN        NaN  20156.250000  20156.250000     20156.250000
# max    NaN        NaN  40000.000000  40000.000000     40000.000000
#
#            int_rate   installment    annual_inc  url  desc           dti  \
# count  20000.000000  20000.000000  2.000000e+04  0.0   0.0  19961.000000
# mean      12.606765    446.811954  7.842926e+04  NaN   NaN     19.214833
# std        4.929089    283.619373  8.363096e+04  NaN   NaN     21.957008
# min        5.320000      7.610000  0.000000e+00  NaN   NaN      0.000000
# 25%        9.440000    238.170000  4.500000e+04  NaN   NaN     10.850000
# 50%       11.990000    369.000000  6.500000e+04  NaN   NaN     17.260000
# 75%       15.050000    605.670000  9.500000e+04  NaN   NaN     24.580000
# max       30.990000   1618.030000  6.500031e+06  NaN   NaN    999.000000
#
#         delinq_2yrs  inq_last_6mths  mths_since_last_delinq  \
# count  20000.000000     20000.00000             8992.000000
# mean       0.246400         0.49650               36.956962
# std        0.834938         0.78238               22.055265
# min        0.000000         0.00000                0.000000
# 25%        0.000000         0.00000               19.000000
# 50%        0.000000         0.00000               34.000000
# 75%        0.000000         1.00000               54.000000
# max       36.000000         5.00000              150.000000
#
#        mths_since_last_record      open_acc       pub_rec      revol_bal  \
# count             2914.000000  20000.000000  20000.000000   20000.000000
# mean                77.992793     11.057900      0.165250   15415.688150
# std                 24.543570      5.687958      0.464277   22845.011859
# min                  1.000000      0.000000      0.000000       0.000000
# 25%                 63.000000      7.000000      0.000000    4739.000000
# 50%                 81.000000     10.000000      0.000000    9867.500000
# 75%                 97.000000     14.000000      0.000000   18336.000000
# max                120.000000     56.000000     18.000000  629372.000000
#
#          revol_util     total_acc     out_prncp  out_prncp_inv   total_pymnt  \
# count  19963.000000  20000.000000  20000.000000   20000.000000  20000.000000
# mean      43.516676     22.127800   8377.290489    8372.905008   8031.681974
# std       25.409374     11.731788   8291.549106    8290.262906   6951.524721
# min        0.000000      2.000000      0.000000       0.000000      0.000000
# 25%       23.400000     14.000000      8.182500       8.182500   3590.550000
# 50%       41.500000     20.000000   6391.410000    6391.400000   5941.780000
# 75%       62.000000     28.000000  12951.920000   12950.137500  10284.092500
# max      125.000000     96.000000  35250.640000   35250.640000  47101.212295
#
#        total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  \
# count

#
#        hardship_payoff_balance_amount  hardship_last_payment_amount  \
# count                       64.000000                     64.000000
# mean                     14786.188750                    231.527187
# std                       8707.436533                    223.560399
# min                       1012.110000                      0.240000
# 25%                       7370.455000                     52.777500
# 50%                      13231.040000                    159.820000
# 75%                      21705.242500                    332.567500
# max                      32738.120000                    979.360000
#
#        settlement_amount  settlement_percentage  settlement_term
# count          61.000000              61.000000        61.000000
# mean         8129.444590              53.103443        17.327869
# std          5727.283541              10.408760         6.922719
# min           645.000000              40.000000         1.000000
# 25%          3542.960000              45.000000        14.000000
# 50%          6422.000000              50.000000        18.000000
# 75%         12162.660000              60.000000        24.000000
# max         23000.000000              94.330000        24.000000

# %%
# numpy 함수로 데이터 shape 확인

# %%
# 인덱스
df.index
# Out:
# RangeIndex(start=0, stop=20000, step=1)

# %%
# 컬럼
df.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        ...
#        'hardship_payoff_balance_amount', 'hardship_last_payment_amount',
#        'disbursement_method', 'debt_settlement_flag',
#        'debt_settlement_flag_date', 'settlement_status', 'settlement_date',
#        'settlement_amount', 'settlement_percentage', 'settlement_term'],
#       dtype='object', length=145)

# %% [markdown]
# 데이터셋을 살펴 본 결과 정체를 알 수 없는 많은 컬럼이 있는 걸 확인했고,
#
# 50000개의 샘플이 불러들여진 것을 확인 할 수 있었습니다.
#
# 추가로 데이터 중간 중간 비어있는 값도 있는 것을 확인했습니다.

# %% [markdown]
# ### 데이터접근 (인덱싱, 슬라이싱, 샘플링)

# %%
# 첫 샘플 혹은 레코드(대출건)에 대한 데이터를 살펴보겠습니다.
# 인덱스넘버로 데이터에 접근하는 .iloc[색인]
# 각 컬럼이나, 행단위 접근했을 때 출력되는 벡터 데이터를 Serise(시리즈) 라고 하는 자료구조
# index, values로 각각의 속성에 접근 가능
df.iloc[0]
# Out:
# id                           NaN
# member_id                    NaN
# loan_amnt                  10000
# funded_amnt                10000
# funded_amnt_inv          10000.0
#                           ...
# settlement_status            NaN
# settlement_date              NaN
# settlement_amount            NaN
# settlement_percentage        NaN
# settlement_term              NaN
# Name: 0, Length: 145, dtype: object

# %%
df.iloc[0].values
# Out:
# array([nan, nan, 10000, 10000, 10000.0, ' 36 months', 9.44, 320.05, 'B',
#        'B1', 'mechanic', '6 years', 'MORTGAGE', 80000.0, 'Not Verified',
#        'Dec-2017', 'Current', 'n', nan, nan, 'credit_card',
#        'Credit card refinancing', '762xx', 'TX', 14.82, 0.0, 'Jul-2007',
#        0.0, 34.0, nan, 8.0, 0.0, 5225, 73.6, 30.0, 'w', 6442.28, 6442.28,
#        4493.81, 4493.81, 3557.72, 936.09, 0.0, 0.0, 0.0, 'Feb-2019',
#        320.05, 'Mar-2019', 'Feb-2019', 0.0, nan, 1, 'Individual', nan,
#        nan, nan, 0.0, 0.0, 173110.0, 0.0, 2.0, 0.0, 2.0, 23.0, 12496.0,
#        39.0, 0.0, 0.0, 3949.0, 45.0, 7100.0, 1.0, 0.0, 0.0, 2.0, 21639.0,
#        1875.0, 73.6, 0.0, 0.0, 125.0, 78.0, 26.0, 23.0, 3.0, 26.0, nan,
#        21.0, nan, 0.0, 2.0, 2.0, 4.0, 4.0, 21.0, 4.0, 5.0, 2.0, 8.0, 0.0,
#        0.0, 0.0, 0.0, 96.4, 25.0, 0.0, 0.0, 196130.0, 17756.0, 7100.0,
#        31992.0, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        'N', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, 'Cash', 'N', nan, nan, nan, nan, nan, nan], dtype=object)

# %%
df.iloc[0].values== ' 36 months'
# Out:
# array([False, False, False, False, False,  True, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False])

# %%
# 10번 인덱스 부터 20번 인덱스 샘플 접근
# start, end+1, step
df.iloc[[10, 21, 1]]
# Out:
#     id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 10 NaN        NaN      40000        40000          40000.0   60 months
# 21 NaN        NaN      20000        20000          20000.0   36 months
# 1  NaN        NaN       3500         3500           3500.0   36 months
#
#     int_rate  installment grade sub_grade                      emp_title  \
# 10     16.02       973.15     C        C5  IT Manager - Business Process
# 21      6.08       609.17     A        A2        Control System Designer
# 1      10.42       113.63     B        B3                            NaN
#
#    emp_length home_ownership  annual_inc verification_status   issue_d  \
# 10  10+ years            OWN    140000.0            Verified  Dec-2017
# 21    2 years            OWN    149000.0            Verified  Dec-2017
# 1         NaN            OWN     90000.0        Not Verified  Dec-2017
#
#    loan_status pymnt_plan  url  desc             purpose               title  \
# 10     Current          n  NaN   NaN  debt_consolidation  Debt consolidation
# 21     Current          n  NaN   NaN               other               Other
# 1      Current          n  NaN   NaN               other               Other
#
#    zip_code addr_state    dti  delinq_2yrs earliest_cr_line  inq_last_6mths  \
# 10    292xx         SC  31.79          1.0         Aug-1999             0.0
# 21    770xx         TX  13.31          0.0         Jul-1999             0.0
# 1     295xx         SC  28.51          0.0         Jun-2002             0.0
#
#     mths_since_last_delinq  mths_since_last_record  open_acc  pub_rec  \
# 10                     3.0                     NaN      11.0      0.0
# 21                     NaN                     NaN      16.0      0.0
# 1                     39.0                    28.0      12.0      3.0
#
#     revol_bal  revol_util  total_acc initial_list_status  out_prncp  \
# 10      34632        59.5       52.0                   w   33288.83
# 21       5049         5.3       27.0                   w   12651.33
# 1        6953        51.9       38.0                   w    2266.55
#
#     out_prncp_inv  total_pymnt  total_pymnt_inv  total_rec_prncp  \
# 10       33288.83     13602.03         13602.03          6711.17
# 21       12651.33      8470.96          8470.96          7348.67
# 1         2266.55      1586.77          1586.77          1233.45
#
#     total_rec_int  total_rec_late_fee  recoveries  collection_recovery_fee  \
# 10        6890.86                 0.0         0.0                      0.0
# 21        1122.29                 0.0         0.0                      0.0
# 1          353.32                 0.0         0.0                      0.0
#
#    last_pymnt_d  last_pymnt_amnt next_pymnt_d last_credit_pull_d  \
# 10     Feb-2019           973.15     Mar-2019           Feb-2019
# 21     Feb-2019           609.17     Mar-2019           Feb-2019
# 1      Feb-2019           113.63     Mar-2019           Feb-2019
#
#     collections_12_mths_ex_med  mths_since_last_major_derog  policy_code  \
# 10                         0.0                          NaN            1
# 21                         0.0                          NaN            1
# 1                          0.0                          NaN            1
#
#    application_type  annual_inc_joint  dti_joint verification_status_joint  \
# 10       Individual               NaN        NaN                       NaN
# 21       Individual               NaN        NaN                       NaN
# 1        Individual               NaN        NaN                       NaN
#
#     acc_now_delinq  tot_coll_amt  tot_cur_bal  open_acc_6m  open_act_il  \
# 10             0.0          59.0      81346.0          0.0          3.0
# 21             0.0           0.0     399842.0          1.0          3.0
# 1              0.0           0.0     339028.0          0.0          4.0
#
#     open_il_12m  open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  \
# 10          0.0          0.0                29.0       46714.0     50.0
# 21          2.0          2.0                 5.0       92121.0     74.0
# 1           0.0          3.0                22.0       76501.0     69.0
#
#     open_rv_12m  open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  \
# 10          0.0          1.0     19100.0      53.0          104500.0     0.0
# 21          3.0          8.0      4983.0      26.0           94800.0     0.0
# 1           1.0          2.0      1628.0      65.0           13400.0     1.0
#
#     total_cu_tl  inq_last_12m  acc_open_past_24mths  avg_cur_bal  \
# 10          0.0           1.0                   1.0       8135.0
# 21          1.0           1.0                  11.0      24990.0
# 1           5.0           1.0                   5.0      28252.0
#
#     bc_open_to_buy  bc_util  chargeoff_within_12_mths  delinq_amnt  \
# 10         63703.0     57.9                       0.0          0.0
# 21         50951.0      9.0                       0.0          0.0
# 1            808.0     82.4                       0.0          0.0
#
#     mo_sin_old_il_acct  mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  \
# 10               220.0                 213.0                   13.0
# 21               130.0                 221.0                    8.0
# 1                164.0                 186.0                    7.0
#
#     mo_sin_rcnt_tl  mort_acc  mths_since_recent_bc  mths_since_recent_bc_dlq  \
# 10            13.0       0.0                  13.0                       NaN
# 21             5.0       1.0                   8.0                       NaN
# 1              7.0       2.0                   7.0                      39.0
#
#     mths_since_recent_inq  mths_since_recent_revol_delinq  \
# 10                    9.0                             3.0
# 21                   12.0                             NaN
# 1                     7.0                            39.0
#
#     num_accts_ever_120_pd  num_actv_bc_tl  num_actv_rev_tl  num_bc_sats  \
# 10                    0.0             2.0              6.0          2.0
# 21                    0.0             2.0              2.0          9.0
# 1                     0.0             4.0              7.0          4.0
#
#     num_bc_tl  num_il_tl  num_op_rev_tl  num_rev_accts  num_rev_tl_bal_gt_0  \
# 10       17.0       22.0            8.0           30.0                  6.0
# 21       15.0        7.0           12.0           19.0                  2.0
# 1        10.0       19.0            7.0           17.0                  7.0
#
#     num_sats  num_tl_120dpd_2m  num_tl_30dpd  num_tl_90g_dpd_24m  \
# 10      11.0               0.0           0.0                 0.0
# 21      16.0               0.0           0.0                 0.0
# 1       12.0               0.0           0.0                 0.0
#
#     num_tl_op_past_12m  pct_tl_nvr_dlq  percent_bc_gt_75  \
# 10                 0.0            98.0               0.0
# 21                 5.0           100.0               0.0
# 1                  1.0            97.3              75.0
#
#     pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  total_bal_ex_mort  \
# 10                   0.0        0.0         197500.0            81346.0
# 21                   0.0        0.0         527931.0            97170.0
# 1                    0.0        3.0         416685.0            83454.0
#
#     total_bc_limit  total_il_high_credit_limit  revol_bal_joint  \
# 10         88000.0                     93000.0              NaN
# 21         56000.0                    110531.0              NaN
# 1           4600.0                    110595.0              NaN
#
#    sec_app_earliest_cr_line  sec_app_inq_last_6mths  sec_app_mort_acc  \
# 10                      NaN                     NaN               NaN
# 21                      NaN                     NaN               NaN
# 1                       NaN                     NaN               NaN
#
#     sec_app_open_acc  sec_app_revol_util  sec_app_open_act_il  \
# 10               NaN                 NaN                  NaN
# 21               NaN                 NaN                  NaN
# 1                NaN                 NaN                  NaN
#
#     sec_app_num_rev_accts  sec_app_chargeoff_within_12_mths  \
# 10                    NaN                               NaN
# 21                    NaN                               NaN
# 1                     NaN                               NaN
#
#     sec_app_collections_12_mths_ex_med  sec_app_mths_since_last_major_derog  \
# 10                                 NaN                                  NaN
# 21                                 NaN                                  NaN
# 1                                  NaN                                  NaN
#
#    hardship_flag hardship_type hardship_reason hardship_status  deferral_term  \
# 10             N           NaN             NaN             NaN            NaN
# 21             N           NaN             NaN             NaN            NaN
# 1              N           NaN             NaN             NaN            NaN
#
#     hardship_amount hardship_start_date hardship_end_date  \
# 10              NaN                 NaN               NaN
# 21              NaN                 NaN               NaN
# 1               NaN                 NaN               NaN
#
#    payment_plan_start_date  hardship_length  hardship_dpd  \
# 10                     NaN              NaN           NaN
# 21                     NaN              NaN           NaN
# 1                      NaN              NaN           NaN
#
#    hardship_loan_status  orig_projected_additional_accrued_interest  \
# 10                  NaN                                         NaN
# 21                  NaN                                         NaN
# 1                   NaN                                         NaN
#
#     hardship_payoff_balance_amount  hardship_last_payment_amount  \
# 10                             NaN                           NaN
# 21                             NaN                           NaN
# 1                              NaN                           NaN
#
#    disbursement_method debt_settlement_flag debt_settlement_flag_date  \
# 10                Cash                    N                       NaN
# 21                Cash                    N                       NaN
# 1                 Cash                    N                       NaN
#
#    settlement_status settlement_date  settlement_amount  \
# 10               NaN             NaN                NaN
# 21               NaN             NaN                NaN
# 1                NaN             NaN                NaN
#
#     settlement_percentage  settlement_term
# 10                    NaN              NaN
# 21                    NaN              NaN
# 1                     NaN              NaN

# %%
# 컬럼 단위 샘플 접근
df['grade']
# df[텍스트형태의 컬럼명]
# 인덱싱이나 슬라이싱으로 데이터에 접근을 할 때 큰 단위를 선택하고 그 결과에서 인덱싱 혹은 슬라이싱을 하면
# 조금 더 편하게, 쉽게 데이터 접근이 가능하다.
# Out:
# 0        B
# 1        B
# 2        C
# 3        B
# 4        C
#         ..
# 19995    B
# 19996    C
# 19997    C
# 19998    D
# 19999    D
# Name: grade, Length: 20000, dtype: object

# %%
# 여러 컬럼 동시 접근
df[['installment', 'grade', 'sub_grade']]
# Out:
#        installment grade sub_grade
# 0           320.05     B        B1
# 1           113.63     B        B3
# 2           169.90     C        C2
# 3           457.75     B        B4
# 4           169.90     C        C2
# ...            ...   ...       ...
# 19995       345.66     B        B1
# 19996       326.34     C        C3
# 19997       789.57     C        C1
# 19998       914.34     D        D3
# 19999       124.95     D        D1
#
# [20000 rows x 3 columns]

# %%
# row와 columns을 동시에 슬라이싱 하는 속성
# df.loc[인덱스, 컬럼명]
df.loc[0:30, ['grade', 'sub_grade']]
# Out:
#    grade sub_grade
# 0      B        B1
# 1      B        B3
# 2      C        C2
# 3      B        B4
# 4      C        C2
# 5      C        C3
# 6      B        B2
# 7      B        B4
# 8      C        C5
# 9      A        A2
# 10     C        C5
# 11     C        C2
# 12     D        D1
# 13     B        B1
# 14     B        B5
# 15     C        C1
# 16     D        D3
# 17     D        D5
# 18     C        C1
# 19     D        D2
# 20     D        D4
# 21     A        A2
# 22     B        B3
# 23     C        C1
# 24     D        D2
# 25     C        C4
# 26     D        D3
# 27     D        D3
# 28     C        C2
# 29     A        A3
# 30     C        C5

# %%
# df의 컬럼명을 순환하면서 컬럼단위로 접근하고 각 컬럼의 고유값을 출력해주는 코드

# %%
# 고윳값 갯수 출력

# %% [markdown]
# ### 팬시인덱싱
# > **`bool`** 형태의 array를 조건을 전달하여 다차원 배열을 인덱싱하는 방법.
# 조건식을 사용하여 분석에 필요한 데이터샘플을 추출하기 용이합니다.

# %%
# 신용등급이 A인 샘플의 emp_title 확인
df.loc[df['grade']=='A']
# Out:
#        id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 9     NaN        NaN      35000        35000          35000.0   36 months
# 21    NaN        NaN      20000        20000          20000.0   36 months
# 29    NaN        NaN      21600        21600          21600.0   36 months
# 32    NaN        NaN       6500         6500           6500.0   36 months
# 37    NaN        NaN      10000        10000           9975.0   36 months
# ...    ..        ...        ...          ...              ...         ...
# 19957 NaN        NaN       2400         2400           2400.0   36 months
# 19960 NaN        NaN      10000        10000          10000.0   36 months
# 19964 NaN        NaN       2000         2000           2000.0   36 months
# 19975 NaN        NaN      15000        15000          15000.0   36 months
# 19980 NaN        NaN      10000        10000          10000.0   36 months
#
#        int_rate  installment grade sub_grade                       emp_title  \
# 9          6.08      1066.04     A        A2                             NaN
# 21         6.08       609.17     A        A2         Control System Designer
# 29         6.72       664.19     A        A3                  Policy Analyst
# 32         7.97       203.60     A        A5           Science lab director
# 37         5.32       301.15     A        A1                     EHS Manager
# ...         ...          ...   ...       ...                             ...
# 19957      7.97        75.18     A        A5                Talent Keyholder
# 19960      7.97       313.23     A        A5                 cpourt reporter
# 19964      7.35        62.08     A        A4                  Security Guard
# 19975      5.32       451.73     A        A1  Vice President/General Manager
# 19980      7.97       313.23     A        A5                 Project manager
#
#       emp_length home_ownership  annual_inc verification_status   issue_d  \
# 9            NaN            OWN     76000.0            Verified  Dec-2017
# 21       2 years            OWN    149000.0            Verified  Dec-2017
# 29      < 1 year           RENT     44000.0        Not Verified  Dec-2017
# 32     10+ years            OWN     40000.0     Source Verified  Dec-2017
# 37       3 years       MORTGAGE     95000.0        Not Verified  Dec-2017
# ...          ...            ...         ...                 ...       ...
# 19957    6 years            OWN     24000.0     Source Verified  Nov-2017
# 19960  10+ years           RENT     56000.0        Not Verified  Nov-2017
# 19964    2 years           RENT     36000.0        Not Verified  Nov-2017
# 19975  10+ years       MORTGAGE    170000.0        Not Verified  Nov-2017
# 19980    2 years           RENT     49400.0     Source Verified  Nov-2017
#
#       loan_status pymnt_plan  url  desc             purpose  \
# 9         Current          n  NaN   NaN         credit_card
# 21        Current          n  NaN   NaN               other
# 29        Current          n  NaN   NaN  debt_consolidation
# 32        Current          n  NaN   NaN         credit_card
# 37        Current          n  NaN   NaN  debt_consolidation
# ...           ...        ...  ...   ...                 ...
# 19957  Fully Paid          n  NaN   NaN         credit_card
# 19960     Current          n  NaN   NaN         credit_card
# 19964     Current          n  NaN   NaN            vacation
# 19975     Current          n  NaN   NaN    home_improvement
# 19980     Current          n  NaN   NaN  debt_consolidation
#
#                          title zip_code addr_state    dti  delinq_2yrs  \
# 9      Credit card refinancing    388xx         MS  34.28          0.0
# 21                       Other    770xx         TX  13.31          0.0
# 29          Debt consolidation    973xx         OR  17.21          0.0
# 32     Credit card refinancing    333xx         FL  32.67          0.0
# 37          Debt consolidation    307xx         GA   9.55          0.0
# ...                        ...      ...        ...    ...          ...
# 19957  Credit card refinancing    941xx         CA  26.55          0.0
# 19960  Credit card refinancing    926xx         CA  19.91          0.0
# 19964                 Vacation    066xx         CT  34.89          0.0
# 19975         Home improvement    770xx         TX  19.64          0.0
# 19980       Debt consolidation    900xx         CA  15.23          0.0
#
#       earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# 9             Aug-1994             1.0                     NaN
# 21            Jul-1999             0.0                     NaN
# 29            Sep-2008             0.0                     NaN
# 32            Apr-1987             0.0                    53.0
# 37            Nov-1989             0.0                    51.0
# ...                ...             ...                     ...
# 19957         Aug-2010             0.0                     NaN
# 19960         Apr-1986             0.0                     NaN
# 19964         Oct-2010             1.0                     NaN
# 19975         Jan-2002             0.0                     NaN
# 19980         Dec-2013             0.0                     NaN
#
#        mths_since_last_record  open_acc  pub_rec  revol_bal  revol_util  \
# 9                         NaN      23.0      0.0      47145        48.0
# 21                        NaN      16.0      0.0       5049         5.3
# 29                        NaN       8.0      0.0       9929        38.0
# 32                        NaN      10.0      0.0      18333         5.9
# 37                        NaN      11.0      0.0       8471        22.1
# ...                       ...       ...      ...        ...         ...
# 19957                     NaN       9.0      0.0       3345         9.8
# 19960                     NaN      11.0      0.0      12095        59.0
# 19964                     NaN      12.0      0.0       8367        12.8
# 19975                     NaN       9.0      0.0       6223        10.8
# 19980                     NaN      10.0      0.0       9489        32.5
#
#        total_acc initial_list_status  out_prncp  out_prncp_inv   total_pymnt  \
# 9           42.0                   w   22139.93       22139.93  14900.920000
# 21          27.0                   w   12651.33       12651.33   8470.960000
# 29          25.0                   w   13711.65       13711.65   9282.530000
# 32          20.0                   w    4154.40        4154.40   2834.280000
# 37          24.0                   f    6299.10        6283.35   4210.190000
# ...          ...                 ...        ...            ...           ...
# 19957       10.0                   w       0.00           0.00   2578.501235
# 19960       14.0                   w    6120.62        6120.62   4689.590000
# 19964       14.0                   w    1219.64        1219.64    929.570000
# 19975       28.0                   w    9038.73        9038.73   6767.080000
# 19980       14.0                   w    6120.62        6120.62   4689.590000
#
#        total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  \
#
             NaN                           NaN
#
#       disbursement_method debt_settlement_flag debt_settlement_flag_date  \
# 9               DirectPay                    N                       NaN
# 21                   Cash                    N                       NaN
# 29                   Cash                    N                       NaN
# 32                   Cash                    N                       NaN
# 37              DirectPay                    N                       NaN
# ...                   ...                  ...                       ...
# 19957                Cash                    N                       NaN
# 19960                Cash                    N                       NaN
# 19964                Cash                    N                       NaN
# 19975                Cash                    N                       NaN
# 19980                Cash                    N                       NaN
#
#       settlement_status settlement_date  settlement_amount  \
# 9                   NaN             NaN                NaN
# 21                  NaN             NaN                NaN
# 29                  NaN             NaN                NaN
# 32                  NaN             NaN                NaN
# 37                  NaN             NaN                NaN
# ...                 ...             ...                ...
# 19957               NaN             NaN                NaN
# 19960               NaN             NaN                NaN
# 19964               NaN             NaN                NaN
# 19975               NaN             NaN                NaN
# 19980               NaN             NaN                NaN
#
#        settlement_percentage  settlement_term
# 9                        NaN              NaN
# 21                       NaN              NaN
# 29                       NaN              NaN
# 32                       NaN              NaN
# 37                       NaN              NaN
# ...                      ...              ...
# 19957                    NaN              NaN
# 19960                    NaN              NaN
# 19964                    NaN              NaN
# 19975                    NaN              NaN
# 19980                    NaN              NaN
#
# [4461 rows x 145 columns]

# %%
df.loc[df['grade']=='A','emp_title']
# Out:
# 9                                   NaN
# 21              Control System Designer
# 29                       Policy Analyst
# 32                Science lab director
# 37                          EHS Manager
#                       ...
# 19957                  Talent Keyholder
# 19960                   cpourt reporter
# 19964                    Security Guard
# 19975    Vice President/General Manager
# 19980                   Project manager
# Name: emp_title, Length: 4461, dtype: object

# %%
df.loc[df['grade']=='A','emp_title'].value_counts()
# Out:
# Manager                             90
# Teacher                             72
# Owner                               68
# Registered Nurse                    40
# Driver                              36
#                                     ..
# Senior VP                            1
# Systems Development Engineer         1
# Transfusion Services Supervisor      1
# Sr Creative Fragrance Manager        1
# Vice President/General Manager       1
# Name: emp_title, Length: 2628, dtype: int64

# %%
# 대출금액평균
df['loan_amnt'].mean()
# Out:
# 15382.56875

# %%
# 조건식 샘플링 emp_title 이 ceo인 샘플들
df.loc[df['emp_title']]=='ceo'
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21856/3195304306.py in <module>
#       1 # 조건식 샘플링 emp_title 이 ceo인 샘플들
# ----> 2 df.loc[df['emp_title']]=='ceo'
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1151                     raise ValueError("Cannot index with multidimensional key")
#    1152
# -> 1153                 return self._getitem_iterable(key, axis=axis)
#    1154
#    1155             # nested tuple slicing
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_iterable(self, key, axis)
#    1091
#    1092         # A collection of keys
# -> 1093         keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1094         return self.obj._reindex_with_indexers(
#    1095             {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1372                 if use_interval_msg:
#    1373                     key = list(key)
# -> 1374                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index([                   'mechanic',                           nan,\n                      'Truck driver',      'Confidential Secretary',\n                   'General Manager',                     'NDT III',\n       'Supervisory program analyst', 'Commercial Property Manager',\n              'Equipment technician',                           nan,\n       ...\n                                 nan,     'Maintenance Technician ',\n          'senior software engineer',           'Design Specialist',\n                          'Salesman',                     'Partner',\n           'Senior Property Manager',           'Mechanic engineer',\n                           'Teacher',          'Director of Design'],\n      dtype='object', length=20000)] are in the [index]"

# %%
# 신용등급 A와 B인 샘플접근

# 조건식을 여러개 써야 한다면 조건마다 ()로 감싸주시는 것이 좋습니다.

# %%
# df loan_amnt 컬럼값이 10000이상인 채권샘플의 grade
df.loc[df['loan_amnt']] >= 10000
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21856/2789728136.py in <module>
#       1 # df loan_amnt 컬럼값이 10000이상인 채권샘플의 grade
# ----> 2 df.loc[df['loan_amnt']] >= 10000
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1151                     raise ValueError("Cannot index with multidimensional key")
#    1152
# -> 1153                 return self._getitem_iterable(key, axis=axis)
#    1154
#    1155             # nested tuple slicing
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_iterable(self, key, axis)
#    1091
#    1092         # A collection of keys
# -> 1093         keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1094         return self.obj._reindex_with_indexers(
#    1095             {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 1377             raise KeyError(f"{not_found} not in index")
#    1378
#    1379
#
# KeyError

# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_logical_op(x, y, op)
#     301         #  (xint or xbool) and (yint or bool)
# --> 302         result = op(x, y)
#     303     except TypeError:
#
# ~\anaconda3\lib\site-packages\pandas\core\roperator.py in ror_(left, right)
#      55 def ror_(left, right):
# ---> 56     return operator.or_(right, left)
#      57
#
# TypeError: unsupported operand type(s) for |: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_logical_op(x, y, op)
#     315             try:
# --> 316                 result = libops.scalar_binop(x, y, op)
#     317             except (
#
# ~\anaconda3\lib\site-packages\pandas\_libs\ops.pyx in pandas._libs.ops.scalar_binop()
#
# ~\anaconda3\lib\site-packages\pandas\core\roperator.py in ror_(left, right)
#      55 def ror_(left, right):
# ---> 56     return operator.or_(right, left)
#      57
#
# TypeError: unsupported operand type(s) for |: 'bool' and 'str'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21856/3937910387.py in <module>
#       1 # df grade C 와 D 인 채권샘플 annual_inc 최대값인 인덱스 빼오기 (idxmax)
#       2 # 최대값 인덱스 빼와서 샘플까지 출력
# ----> 3 df.loc[(df['grade']=='C' | df['grade']=='D'), 'annual_inc'].idmax()
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# ~\anaconda3\lib\site-packages\pandas\core\arraylike.py in __ror__(self, other)
#      72     @unpack_zerodim_and_defer("__ror__")
#      73     def __ror__(self, other):
# ---> 74         return self._logical_method(other, roperator.ror_)
#      75
#      76     @unpack_zerodim_and_defer("__xor__")
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _logical_method(self, other, op)
#    5511         rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    5512
# -> 5513         res_values = ops.logical_op(lvalues, rvalues, op)
#    5514         return self._construct_result(res_values, name=res_name)
#    5515
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in logical_op(left, right, op)
#     390         filler = fill_int if is_self_int_dtype and is_other_int_dtype else fill_bool
#     391
# --> 392         res_values = na_logical_op(lvalues, rvalues, op)
#     393         # error: Cannot call function of unknown type
#     394         res_values = filler(res_values)  # type: ignore[operator]
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_logical_op(x, y, op)
#     323             ) as err:
#     324                 typ = type(y).__name__
# --> 325                 raise TypeError(
#     326                     f"Cannot perform '{op.__name__}' with a dtyped [{x.dtype}] array "
#     327                     f"and scalar of type [{typ}]"
#
# TypeError: Cannot perform 'ror_' with a dtyped [object] array and scalar of type [bool]

# %%
# 컬럼 내 문자열 내에 우리가 찾고싶은 문자열이 포함되어 있는지를 기준으로 샘플링

# %% [markdown]
# ## 데이터프레임 병합
# > 실제 분석업무를 진행하다보면 데이터가 여기저기 분산되어 있을 경우가 더 많습니다.
# 조각난 데이터를 분석에 필요한 데이터셋으로 만들기 위해 데이터프레임 병합을 많이 사용합니다.
# 한개 이상의 데이터프레임을 병합 할 때 주로 사용하는 함수 2가지를 알아보겠습니다.

# %% [markdown]
# ### 데이터 병합에 사용가능한 key(병합할 기준이 되는 행 or 열)값이 있는경우
# **`pd.merge`**(베이스데이터프레임, 병합할데이터프레임)
# > 사용 가능 한 파라메터
# - `how` : 'left', 'right', 'inner', 'outer'
# - `left_on` : key값이 다를 경우 베이스데이터프레임의 key 설정
# - `right_on` : key값이 다를 경우 병합데이터프레임의 key 설정
#
# ### 단순 데이터 연결
# **`pd.concat`**([베이스데이터프레임, 병합할데이터프레임], axis=0 or 1)
# > 사용 가능 한 파라메터
# - `axis` : 축 방향 설정

# %% [markdown]
# ### merge 예시

# %%
merge_df1 = pd.DataFrame({
    '이름': ['원영', '사쿠라', '유리', '예나', '유진', '나코', '은비', '혜원', '히토미', '채원', '민주', '째욘'],
    '국어': [100, 70, 70, 70, 60, 90, 90, 70, 70, 80, 100, 100],
    '영어': [100, 90, 80, 50, 70, 100, 70, 90, 100, 100, 80, 100]
    }, columns=['이름', '국어', '영어']) 

merge_df2 = pd.DataFrame({
    '일어': [80, 100, 100, 90, 70, 50, 100],
    '수학': [90, 70, 100, 80, 70, 80, 90],
    '이름': ['원영', '사쿠라', '나코', '히토미', '예나', '은비', '째욘'],
    }, columns=['일어', '수학', '이름'])

# %%
# 데이터프레임 확인
merge_df2
# Out:
#     일어   수학   이름
# 0   80   90   원영
# 1  100   70  사쿠라
# 2  100  100   나코
# 3   90   80  히토미
# 4   70   70   예나
# 5   50   80   은비
# 6  100   90   째욘

# %%
# 병합 테스트
pd.merge(merge_df1, merge_df2)
# Out:
#     이름   국어   영어   일어   수학
# 0   원영  100  100   80   90
# 1  사쿠라   70   90  100   70
# 2   예나   70   50   70   70
# 3   나코   90  100  100  100
# 4   은비   90   70   50   80
# 5  히토미   70  100   90   80
# 6   째욘  100  100  100   90

# %%
# 양쪽 데이터가 모두 있는경우
#pd.merge(merge_df1, merge_df2, how='inner')
# 한쪽 데이터만 있는 경우도 함침
#pd.merge(merge_df1, merge_df2, how='outer')
# 왼쪽 기준
#pd.merge(merge_df1, merge_df2, how='left')
# 오른쪽 데이터 기준
pd.merge(merge_df1, merge_df2, how='right')
# Out:
#     이름   국어   영어   일어   수학
# 0   원영  100  100   80   90
# 1  사쿠라   70   90  100   70
# 2   나코   90  100  100  100
# 3  히토미   70  100   90   80
# 4   예나   70   50   70   70
# 5   은비   90   70   50   80
# 6   째욘  100  100  100   90

# %%
merge_df1 = pd.DataFrame({
    '이름': ['원영', '사쿠라', '유리', '예나', '유진', '나코', '은비', '혜원', '히토미', '채원', '민주', '째욘'],
    '국어': [100, 70, 70, 70, 60, 90, 90, 70, 70, 80, 100, 100],
    '영어': [100, 90, 80, 50, 70, 100, 70, 90, 100, 100, 80, 100]
    }, columns=['이름', '국어', '영어']) 

merge_df2 = pd.DataFrame({
    '일어': [80, 100, 100, 90, 70, 50, 100],
    '수학': [90, 70, 100, 80, 70, 80, 90],
    'name': ['원영', '사쿠라', '나코', '히토미', '예나', '은비', '째욘'],
    }, columns=['일어', '수학', 'name'])

# %%
merge_df2
# Out:
#     일어   수학 name
# 0   80   90   원영
# 1  100   70  사쿠라
# 2  100  100   나코
# 3   90   80  히토미
# 4   70   70   예나
# 5   50   80   은비
# 6  100   90   째욘

# %%
pd.merge(merge_df1, merge_df2, left_on='이름', right_on='name')
# Out:
#     이름   국어   영어   일어   수학 name
# 0   원영  100  100   80   90   원영
# 1  사쿠라   70   90  100   70  사쿠라
# 2   예나   70   50   70   70   예나
# 3   나코   90  100  100  100   나코
# 4   은비   90   70   50   80   은비
# 5  히토미   70  100   90   80  히토미
# 6   째욘  100  100  100   90   째욘

# %% [markdown]
# ### concat 예시
# 현재 df에 저장되어있는 데이터에 추가로 2만개의 데이터를 이어붙여보겠습니다. df1이라는 변수에 이어붙일 데이터를 불러들여 병합을 진행해보겠습니다.

# %%
# df1 변수에 loan2.csv 파일을 읽어들입니다.
df1 = open('./data/loan2.csv', encoding='cp949')

# %%
# 데이터프레임 확인
df1
# Out:
# <_io.TextIOWrapper name='./data/loan2.csv' mode='r' encoding='cp949'>

# %%
# df 와 df1 shape 확인
df1.shape()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21856/2389678948.py in <module>
#       1 # df 와 df1 shape 확인
# ----> 2 df1.shape()
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'shape'

# %%
# 데이터프레임 행단위 병합

# %%
# 병합 데이터프레임 shape 확인

# %%
# 병합 데이터프레임 index 확인

# %% [markdown]
# ## 인덱스 편집
# 방금 전 concat으로 병합한 데이터프레임의 이상한 점을 찾으셨나요?
# 데이터 자체는 잘 붙였지만 인덱스가 꼬여있습니다. 인덱스 편집은 데이터분석을 위해 필요한 인덱스를 설정하기 위해 필요합니다.

# %%
# 인덱스리셋
concat_df.reset_index(drop=True, inplace=True)
# 원본값 변경해라 inplace
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21856/773704662.py in <module>
#       1 # 인덱스리셋
# ----> 2 concat_df.reset_index(drop=True)
#
# NameError: name 'concat_df' is not defined

# %%
# 기존 컬럼값을 취해 index로 사용

# %% [markdown]
# ## 컬럼편집
# 인덱스편집과 마찬가지로 데이터프레임의 컬럼을 변경해야 할 경우도 있습니다. 데이터프레임은 컬럼단위 샘플링 및 인덱싱, 이름변경이 가능합니다.

# %% [markdown]
# ### 컬럼선택

# %%
# df 컬럼명 접근
df.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        ...
#        'hardship_payoff_balance_amount', 'hardship_last_payment_amount',
#        'disbursement_method', 'debt_settlement_flag',
#        'debt_settlement_flag_date', 'settlement_status', 'settlement_date',
#        'settlement_amount', 'settlement_percentage', 'settlement_term'],
#       dtype='object', length=145)

# %%
# columns 속성도 인덱싱 및 슬라이싱이 가능합니다.
df.columns[0:30]
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title',
#        'emp_length', 'home_ownership', 'annual_inc', 'verification_status',
#        'issue_d', 'loan_status', 'pymnt_plan', 'url', 'desc', 'purpose',
#        'title', 'zip_code', 'addr_state', 'dti', 'delinq_2yrs',
#        'earliest_cr_line', 'inq_last_6mths', 'mths_since_last_delinq',
#        'mths_since_last_record'],
#       dtype='object')

# %% [markdown]
# 저는 개인정보에 관한 부분에 관심이 많습니다. 데이터셋 중 필요한 부분만을 컬럼단위로 추려보겠습니다.

# %%
# df의 개인정보에 관한 컬럼만을 색인으로 df를 슬라이싱하고 person_df 변수에 할당
person_df=df[df.columns[0:25]]

# %%
person_df
# Out:
#        id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0     NaN        NaN      10000        10000          10000.0   36 months
# 1     NaN        NaN       3500         3500           3500.0   36 months
# 2     NaN        NaN       5000         5000           5000.0   36 months
# 3     NaN        NaN      14000        14000          14000.0   36 months
# 4     NaN        NaN       5000         5000           5000.0   36 months
# ...    ..        ...        ...          ...              ...         ...
# 19995 NaN        NaN      10800        10800          10800.0   36 months
# 19996 NaN        NaN      14000        14000          14000.0   60 months
# 19997 NaN        NaN      35000        35000          35000.0   60 months
# 19998 NaN        NaN      35225        35225          35225.0   60 months
# 19999 NaN        NaN       3500         3500           3500.0   36 months
#
#        int_rate  installment grade sub_grade                emp_title  \
# 0          9.44       320.05     B        B1                 mechanic
# 1         10.42       113.63     B        B3                      NaN
# 2         13.59       169.90     C        C2             Truck driver
# 3         10.91       457.75     B        B4   Confidential Secretary
# 4         13.59       169.90     C        C2          General Manager
# ...         ...          ...   ...       ...                      ...
# 19995      9.44       345.66     B        B1                  Partner
# 19996     14.08       326.34     C        C3  Senior Property Manager
# 19997     12.62       789.57     C        C1        Mechanic engineer
# 19998     19.03       914.34     D        D3                  Teacher
# 19999     17.09       124.95     D        D1       Director of Design
#
#       emp_length home_ownership  annual_inc verification_status   issue_d  \
# 0        6 years       MORTGAGE     80000.0        Not Verified  Dec-2017
# 1            NaN            OWN     90000.0        Not Verified  Dec-2017
# 2      10+ years            OWN    168000.0        Not Verified  Dec-2017
# 3        2 years           RENT     39000.0     Source Verified  Dec-2017
# 4       < 1 year           RENT     55000.0        Not Verified  Dec-2017
# ...          ...            ...         ...                 ...       ...
# 19995    3 years       MORTGAGE    240000.0        Not Verified  Nov-2017
# 19996  10+ years            OWN     53300.0            Verified  Nov-2017
# 19997    7 years           RENT     85000.0     Source Verified  Nov-2017
# 19998    8 years       MORTGAGE     42000.0     Source Verified  Nov-2017
# 19999  10+ years           RENT     87000.0        Not Verified  Nov-2017
#
#       loan_status pymnt_plan  url  desc             purpose  \
# 0         Current          n  NaN   NaN         credit_card
# 1         Current          n  NaN   NaN               other
# 2         Current          n  NaN   NaN               other
# 3         Current          n  NaN   NaN         credit_card
# 4         Current          n  NaN   NaN  debt_consolidation
# ...           ...        ...  ...   ...                 ...
# 19995     Current          n  NaN   NaN      major_purchase
# 19996     Current          n  NaN   NaN      major_purchase
# 19997  Fully Paid          n  NaN   NaN         credit_card
# 19998     Current          n  NaN   NaN  debt_consolidation
# 19999     Current          n  NaN   NaN  debt_consolidation
#
#                          title zip_code addr_state    dti
# 0      Credit card refinancing    762xx         TX  14.82
# 1                        Other    295xx         SC  28.51
# 2                        Other    788xx         TX  11.62
# 3      Credit card refinancing    125xx         NY  22.88
# 4           Debt consolidation    672xx         KS  12.18
# ...                        ...      ...        ...    ...
# 19995           Major purchase    370xx         TN   9.25
# 19996           Major purchase    481xx         MI  12.95
# 19997  Credit card refinancing    030xx         NH  16.77
# 19998       Debt consolidation    532xx         WI  32.80
# 19999       Debt consolidation    606xx         IL  20.72
#
# [20000 rows x 25 columns]

# %% [markdown]
# ### 컬럼삭제
# 현재 데이터셋에는 개인식별정보가 지워져서 데이터가 존재하지 않습니다. 불필요한 데이터 column을 지우도록 하겠습니다.

# %%
# 지울 column의 데이터값이 모두 NaN인지 확인
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 145 columns):
#  #    Column                                      Non-Null Count  Dtype
# ---   ------                                      --------------  -----
#  0    id                                          0 non-null      float64
#  1    member_id                                   0 non-null      float64
#  2    loan_amnt                                   20000 non-null  int64
#  3    funded_amnt                                 20000 non-null  int64
#  4    funded_amnt_inv                             20000 non-null  float64
#  5    term                                        20000 non-null  object
#  6    int_rate                                    20000 non-null  float64
#  7    installment                                 20000 non-null  float64
#  8    grade                                       20000 non-null  object
#  9    sub_grade                                   20000 non-null  object
#  10   emp_title                                   18269 non-null  object
#  11   emp_length                                  18296 non-null  object
#  12   home_ownership                              20000 non-null  object
#  13   annual_inc                                  20000 non-null  float64
#  14   verification_status                         20000 non-null  object
#  15   issue_d                                     20000 non-null  object
#  16   loan_status                                 20000 non-null  object
#  17   pymnt_plan                                  20000 non-null  object
#  18   url                                         0 non-null      float64
#  19   desc                                        0 non-null      float64
#  20   purpose                                     20000 non-null  object
#  21   title                                       20000 non-null  object
#  22   zip_code                                    20000 non-null  object
#  23   addr_state                                  20000 non-null  object
#  24   dti                                         19961 non-null  float64
#  25   delinq_2yrs                                 20000 non-null  float64
#  26   earliest_cr_line                            20000 non-null  object
#  27   inq_last_6mths                              20000 non-null  float64
#  28   mths_since_last_delinq                      8992 non-null   float64
#  29   mths_since_last_record                      2914 non-null   float64
#  30   open_acc                                    20000 non-null  float64
#  31   pub_rec                                     20000 non-null  float64
#  32   revol_bal                                   20000 non-null  int64
#  33   revol_util                                  19963 non-null  float64
#  34   total_acc                                   20000 non-null  float64
#  35   initial_list_status                         20000 non-null  object
#  36   out_prncp                                   20000 non-null  float64
#  37   out_prncp_inv                               20000 non-null  float64
#  38   total_pymnt                                 20000 non-null  float64
#  39   total_pymnt_inv                             20000 non-null  float64
#  40   total_rec_prncp                             20000 non-null  float64
#  41   total_rec_int                               20000 non-null  float64
#  42   total_rec_late_fee                          20000 non-null  float64
#  43   recoveries                                  20000 non-null  float64
#  44   collection_recovery_fee                     20000 non-null  float64
#  45   last_pymnt_d                                19970 non-null  object
#  46   last_pymnt_amnt                             20000 non-null  float64
#  47   next_pymnt_d                                15056 non-null  object
#  48   last_credit_pull_d                          20000 non-null  object
#  49   collections_12_mths_ex_med                  20000 non-null  float64
#  50   mths_since_last_major_derog                 4862 non-null   float64
#  51   policy_code                                 20000 non-null  int64
#  52   application_type                            20000 non-null  object
#  53   annual_inc_joint                            2792 non-null   float64
#  54   dti_joint                                   2792 non-null   float64
#  55   verification_status_joint                   2792 non-null   object
#  56   acc_now_delinq                              20000 non-null  float64
#  57   tot_coll_amt                                20000 non-null  float64
#  58   tot_cur_bal                                 20000 non-null  float64
#  59   open_acc_6m                                 20000 non-null  float64
#  60   open_act_il                                 20000 non-null  float64
#  61   open_il_12m                                 20000 non-null  float64
#  62   open_il_24m                                 20000 non-null  float64
#  63   mths_since_rcnt_il                          19242 non-null  float64
#  64   total_bal_il                                20000 non-null  float64
#  65   il_util                                     16740 non-null  float64
#  66   open_rv_12m                                 20000 non-null  float64
#  67   open_rv_24m                                 20000 non-null  float64
#  68   max_bal_bc                                  20000 non-null  float64
#  69   all_util                                    19994 non-null  float64
#  70   total_rev_hi_lim                            20000 non-null  float64
#  71   inq_fi                                      20000 non-null  float64
#  72   total_cu_tl                                 20000 non-null  float64
#  73   inq_last_12m                                20000 non-null  float64
#  74   acc_open_past_24mths                        20000 non-null  float64
#  75   avg_cur_bal                                 19997 non-null  float64
#  76   bc_open_to_buy                              19653 non-null  float64
#  77   bc_util                                     19646 non-null  float64
#  78   chargeoff_within_12_mths                    20000 non-null  float64
#  79   delinq_amnt                                 20000 non-null  float64
#  80   mo_sin_old_il_acct                          19242 non-null  float64
#  81   mo_sin_old_rev_tl_op                        20000 non-null  float64
#  82   mo_sin_rcnt_rev_tl_op                       20000 non-null  float64
#  83   mo_sin_rcnt_tl                              20000 non-null  float64
#  84   mort_acc                                    20000 non-null  float64
#  85   mths_since_recent_bc                        19672 non-null  float64
#  86   mths_since_recent_bc_dlq                    4076 non-null   float64
#  87   mths_since_recent_inq                       17495 non-null  float64
#  88   mths_since_recent_revol_delinq              5889 non-null   float64
#  89   num_accts_ever_120_pd                       20000 non-null  float64
#  90   num_actv_bc_tl                              20000 non-null  float64
#  91   num_actv_rev_tl                             20000 non-null  float64
#  92   num_bc_sats                                 20000 non-null  float64
#  93   num_bc_tl                                   20000 non-null  float64
#  94   num_il_tl                                   20000 non-null  float64
#  95   num_op_rev_tl                               20000 non-null  float64
#  96   num_rev_accts                               20000 non-null  float64
#  97   num_rev_tl_bal_gt_0                         20000 non-null  float64
#  98   num_sats                                    20000 non-null  float64
#  99   num_tl_120dpd_2m                            18819 non-null  float64
#  100  num_tl_30dpd                                20000 non-null  float64
#  101  num_tl_90g_dpd_24m                          20000 non-null  float64
#  102  num_tl_op_past_12m                          20000 non-null  float64
#  103  pct_tl_nvr_dlq                              20000 non-null  float64
#  104  percent_bc_gt_75                            19651 non-null  float64
#  105  pub_rec_bankruptcies                        20000 non-null  float64
#  106  tax_liens                                   20000 non-null  float64
#  107  tot_hi_cred_lim                             20000 non-null  float64
#  108  total_bal_ex_mort                           20000 non-null  float64
#  109  total_bc_limit                              20000 non-null  float64
#  110  total_il_high_credit_limit                  20000 non-null  float64
#  111  revol_bal_joint                             2792 non-null   float64
#  112  sec_app_earliest_cr_line                    2792 non-null   object
#  113  sec_app_inq_last_6mths                      2792 non-null   float64
#  114  sec_app_mort_acc                            2792 non-null   float64
#  115  sec_app_open_acc                            2792 non-null   float64
#  116  sec_app_revol_util                          2745 non-null   float64
#  117  sec_app_open_act_il                         2792 non-null   float64
#  118  sec_app_num_rev_accts                       2792 non-null   float64
#  119  sec_app_chargeoff_within_12_mths            2792 non-null   float64
#  120  sec_app_collections_12_mths_ex_med          2792 non-null   float64
#  121  sec_app_mths_since_last_major_derog         998 non-null    float64
#  122  hardship_flag                               20000 non-null  object
#  123  hardship_type                               64 non-null     object
#  124  hardship_reason                             64 non-null     object
#  125  hardship_status                             64 non-null     object
#  126  deferral_term                               64 non-null     float64
#  127  hardship_amount                             64 non-null     float64
#  128  hardship_start_date                         64 non-null     object
#  129  hardship_end_date                           64 non-null     object
#  130  payment_plan_start_date                     64 non-null     object
#  131  hardship_length                             64 non-null     float64
#  132  hardship_dpd                                64 non-null     float64
#  133  hardship_loan_status                        64 non-null     object
#  134  orig_projected_additional_accrued_interest  50 non-null     float64
#  135  hardship_payoff_balance_amount              64 non-null     float64
#  136  hardship_last_payment_amount                64 non-null     float64
#  137  disbursement_method                         20000 non-null  object
#  138  debt_settlement_flag                        20000 non-null  object
#  139  debt_settlement_flag_date                   61 non-null     object
#  140  settlement_status                           61 non-null     object
#  141  settlement_date                             61 non-null     object
#  142  settlement_amount                           61 non-null     float64
#  143  settlement_percentage                       61 non-null     float64
#  144  settlement_term                             61 non-null     float64
# dtypes: float64(106), int64(4), object(35)
# memory usage: 22.1+ MB

# %%
df['id'].isna().all()
# Out:
# True

# %% [markdown]
# 삭제할 컬럼 모두 데이터가 없는 것을 확인했습니다.

# %%
# 컬럼 삭제 (drop, del, pop)
df.drop('id', axis=1, inplace=True)
df
# Out:
#        member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0            NaN      10000        10000          10000.0   36 months
# 1            NaN       3500         3500           3500.0   36 months
# 2            NaN       5000         5000           5000.0   36 months
# 3            NaN      14000        14000          14000.0   36 months
# 4            NaN       5000         5000           5000.0   36 months
# ...          ...        ...          ...              ...         ...
# 19995        NaN      10800        10800          10800.0   36 months
# 19996        NaN      14000        14000          14000.0   60 months
# 19997        NaN      35000        35000          35000.0   60 months
# 19998        NaN      35225        35225          35225.0   60 months
# 19999        NaN       3500         3500           3500.0   36 months
#
#        int_rate  installment grade sub_grade                emp_title  \
# 0          9.44       320.05     B        B1                 mechanic
# 1         10.42       113.63     B        B3                      NaN
# 2         13.59       169.90     C        C2             Truck driver
# 3         10.91       457.75     B        B4   Confidential Secretary
# 4         13.59       169.90     C        C2          General Manager
# ...         ...          ...   ...       ...                      ...
# 19995      9.44       345.66     B        B1                  Partner
# 19996     14.08       326.34     C        C3  Senior Property Manager
# 19997     12.62       789.57     C        C1        Mechanic engineer
# 19998     19.03       914.34     D        D3                  Teacher
# 19999     17.09       124.95     D        D1       Director of Design
#
#       emp_length home_ownership  annual_inc verification_status   issue_d  \
# 0        6 years       MORTGAGE     80000.0        Not Verified  Dec-2017
# 1            NaN            OWN     90000.0        Not Verified  Dec-2017
# 2      10+ years            OWN    168000.0        Not Verified  Dec-2017
# 3        2 years           RENT     39000.0     Source Verified  Dec-2017
# 4       < 1 year           RENT     55000.0        Not Verified  Dec-2017
# ...          ...            ...         ...                 ...       ...
# 19995    3 years       MORTGAGE    240000.0        Not Verified  Nov-2017
# 19996  10+ years            OWN     53300.0            Verified  Nov-2017
# 19997    7 years           RENT     85000.0     Source Verified  Nov-2017
# 19998    8 years       MORTGAGE     42000.0     Source Verified  Nov-2017
# 19999  10+ years           RENT     87000.0        Not Verified  Nov-2017
#
#       loan_status pymnt_plan  url  desc             purpose  \
# 0         Current          n  NaN   NaN         credit_card
# 1         Current          n  NaN   NaN               other
# 2         Current          n  NaN   NaN               other
# 3         Current          n  NaN   NaN         credit_card
# 4         Current          n  NaN   NaN  debt_consolidation
# ...           ...        ...  ...   ...                 ...
# 19995     Current          n  NaN   NaN      major_purchase
# 19996     Current          n  NaN   NaN      major_purchase
# 19997  Fully Paid          n  NaN   NaN         credit_card
# 19998     Current          n  NaN   NaN  debt_consolidation
# 19999     Current          n  NaN   NaN  debt_consolidation
#
#                          title zip_code addr_state    dti  delinq_2yrs  \
# 0      Credit card refinancing    762xx         TX  14.82          0.0
# 1                        Other    295xx         SC  28.51          0.0
# 2                        Other    788xx         TX  11.62          0.0
# 3      Credit card refinancing    125xx         NY  22.88          0.0
# 4           Debt consolidation    672xx         KS  12.18          0.0
# ...                        ...      ...        ...    ...          ...
# 19995           Major purchase    370xx         TN   9.25          0.0
# 19996           Major purchase    481xx         MI  12.95          0.0
# 19997  Credit card refinancing    030xx         NH  16.77          0.0
# 19998       Debt consolidation    532xx         WI  32.80          0.0
# 19999       Debt consolidation    606xx         IL  20.72          0.0
#
#       earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# 0             Jul-2007             0.0                    34.0
# 1             Jun-2002             0.0                    39.0
# 2             Aug-2002             0.0                    44.0
# 3             Apr-2003             0.0                    74.0
# 4             Jun-1999             0.0                     NaN
# ...                ...             ...                     ...
# 19995         Oct-2005             1.0                    42.0
# 19996         Mar-1987             1.0                    27.0
# 19997         Jul-2002             2.0                    64.0
# 19998         May-2003             0.0                    65.0
# 19999         Nov-1999             0.0                     NaN
#
#        mths_since_last_record  open_acc  pub_rec  revol_bal  revol_util  \
# 0                         NaN       8.0      0.0       5225        73.6
# 1                        28.0      12.0      3.0       6953        51.9
# 2                         NaN       4.0      0.0       3401        97.2
# 3                         NaN       8.0      0.0      12918        59.5
# 4                         NaN       5.0      0.0       4497        91.8
# ...                       ...       ...      ...        ...         ...
# 19995                     NaN       6.0      0.0     128754        68.4
# 19996                     NaN       7.0      0.0       1536        30.7
# 19997                     NaN      11.0      0.0      23115        43.6
# 19998                     NaN      15.0      0.0      10432        60.0
# 19999                     NaN       8.0      0.0      19505        79.3
#
#        total_acc initial_list_status  out_prncp  out_prncp_inv   total_pymnt  \
# 
ol_bal_joint sec_app_earliest_cr_line  sec_app_inq_last_6mths  \
# 0                  NaN                      NaN                     NaN
# 1                  NaN                      NaN                     NaN
# 2                  NaN                      NaN                     NaN
# 3                  NaN                      NaN                     NaN
# 4                  NaN                      NaN                     NaN
# ...                ...                      ...                     ...
# 19995              NaN                      NaN                     NaN
# 19996              NaN                      NaN                     NaN
# 19997          40609.0                 Oct-2006                     1.0
# 19998          29018.0                 May-2004                     0.0
# 19999          69960.0                 Aug-1992                     1.0
#
#        sec_app_mort_acc  sec_app_open_acc  sec_app_revol_util  \
# 0                   NaN               NaN                 NaN
# 1                   NaN               NaN                 NaN
# 2                   NaN               NaN                 NaN
# 3                   NaN               NaN                 NaN
# 4                   NaN               NaN                 NaN
# ...                 ...               ...                 ...
# 19995               NaN               NaN                 NaN
# 19996               NaN               NaN                 NaN
# 19997               0.0              34.0                45.9
# 19998               1.0              11.0                56.0
# 19999               0.0               7.0                94.9
#
#        sec_app_open_act_il  sec_app_num_rev_accts  \
# 0                      NaN                    NaN
# 1                      NaN                    NaN
# 2                      NaN                    NaN
# 3                      NaN                    NaN
# 4                      NaN                    NaN
# ...                    ...                    ...
# 19995                  NaN                    NaN
# 19996                  NaN                    NaN
# 19997                 17.0                   30.0
# 19998                  1.0                   11.0
# 19999                  2.0                    8.0
#
#        sec_app_chargeoff_within_12_mths  sec_app_collections_12_mths_ex_med  \
# 0                                   NaN                                 NaN
# 1                                   NaN                                 NaN
# 2                                   NaN                                 NaN
# 3                                   NaN                                 NaN
# 4                                   NaN                                 NaN
# ...                                 ...                                 ...
# 19995                               NaN                                 NaN
# 19996                               NaN                                 NaN
# 19997                               0.0                                 0.0
# 19998                               0.0                                 0.0
# 19999                               0.0                                 0.0
#
#        sec_app_mths_since_last_major_derog hardship_flag hardship_type  \
# 0                                      NaN             N           NaN
# 1                                      NaN             N           NaN
# 2                                      NaN             N           NaN
# 3                                      NaN             N           NaN
# 4                                      NaN             N           NaN
# ...                                    ...           ...           ...
# 19995                                  NaN             N           NaN
# 19996                                  NaN             N           NaN
# 19997                                 69.0             N           NaN
# 19998                                  NaN             N           NaN
# 19999                                  NaN             N           NaN
#
#       hardship_reason hardship_status  deferral_term  hardship_amount  \
# 0                 NaN             NaN            NaN              NaN
# 1                 NaN             NaN            NaN              NaN
# 2                 NaN             NaN            NaN              NaN
# 3                 NaN             NaN            NaN              NaN
# 4                 NaN             NaN            NaN              NaN
# ...               ...             ...            ...              ...
# 19995             NaN             NaN            NaN              NaN
# 19996             NaN             NaN            NaN              NaN
# 19997             NaN             NaN            NaN              NaN
# 19998             NaN             NaN            NaN              NaN
# 19999             NaN             NaN            NaN              NaN
#
#       hardship_start_date hardship_end_date payment_plan_start_date  \
# 0                     NaN               NaN                     NaN
# 1                     NaN               NaN                     NaN
# 2                     NaN               NaN                     NaN
# 3                     NaN               NaN                     NaN
# 4                     NaN               NaN                     NaN
# ...                   ...               ...                     ...
# 19995                 NaN               NaN                     NaN
# 19996                 NaN               NaN                     NaN
# 19997                 NaN               NaN                     NaN
# 19998                 NaN               NaN                     NaN
# 19999                 NaN               NaN                     NaN
#
#        hardship_length  hardship_dpd hardship_loan_status  \
# 0                  NaN           NaN                  NaN
# 1                  NaN           NaN                  NaN
# 2                  NaN           NaN                  NaN
# 3                  NaN           NaN                  NaN
# 4                  NaN           NaN                  NaN
# ...                ...           ...                  ...
# 19995              NaN           NaN                  NaN
# 19996              NaN           NaN                  NaN
# 19997              NaN           NaN                  NaN
# 19998              NaN           NaN                  NaN
# 19999              NaN           NaN                  NaN
#
#        orig_projected_additional_accrued_interest  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 19995                                         NaN
# 19996                                         NaN
# 19997                                         NaN
# 19998                                         NaN
# 19999                                         NaN
#
#        hardship_payoff_balance_amount  hardship_last_payment_amount  \
# 0                                 NaN                           NaN
# 1                                 NaN                           NaN
# 2                                 NaN                           NaN
# 3                                 NaN                           NaN
# 4                                 NaN                           NaN
# ...                               ...                           ...
# 19995                             NaN                           NaN
# 19996                             NaN                           NaN
# 19997                             NaN                           NaN
# 19998                             NaN                           NaN
# 19999                             NaN                           NaN
#
#       disbursement_method debt_settlement_flag debt_settlement_flag_date  \
# 0                    Cash                    N                       NaN
# 1                    Cash                    N                       NaN
# 2                    Cash                    N                       NaN
# 3                    Cash                    N                       NaN
# 4                    Cash                    N                       NaN
# ...                   ...                  ...                       ...
# 19995                Cash                    N                       NaN
# 19996                Cash                    N                       NaN
# 19997                Cash                    N                       NaN
# 19998                Cash                    N                       NaN
# 19999                Cash                    N                       NaN
#
#       settlement_status settlement_date  settlement_amount  \
# 0                   NaN             NaN                NaN
# 1                   NaN             NaN                NaN
# 2                   NaN             NaN                NaN
# 3                   NaN             NaN                NaN
# 4                   NaN             NaN                NaN
# ...                 ...             ...                ...
# 19995               NaN             NaN                NaN
# 19996               NaN             NaN                NaN
# 19997               NaN             NaN                NaN
# 19998               NaN             NaN                NaN
# 19999               NaN             NaN                NaN
#
#        settlement_percentage  settlement_term
# 0                        NaN              NaN
# 1                        NaN              NaN
# 2                        NaN              NaN
# 3                        NaN              NaN
# 4                        NaN              NaN
# ...                      ...              ...
# 19995                    NaN              NaN
# 19996                    NaN              NaN
# 19997                    NaN              NaN
# 19998                    NaN              NaN
# 19999                    NaN              NaN
#
# [20000 rows x 144 columns]

# %%
del df['member_id']

# %%
df.pop('dsec')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'dsec'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21856/3754851158.py in <module>
# ----> 1 df.pop('dsec')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in pop(self, item)
#    5224         3  monkey        NaN
#    5225         """
# -> 5226         return super().pop(item=item)
#    5227
#    5228     @doc(NDFrame.replace, **_shared_doc_kwargs)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in pop(self, item)
#     868
#     869     def pop(self, item: Hashable) -> Series | Any:
# --> 870         result = self[item]
#     871         del self[item]
#     872
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'dsec'

# %% [markdown]
# ### 컬럼명 변경
#     경우에 따라서는 데이터셋 제작 중 컬럼명을 변경해야 할 경우도 있습니다.
#     국내 수집 데이터 사용 시 컬럼이 한글일 경우 영어로 변경을 많이 합니다.

# %%
# home_ownership을 간략하게 home으로 변경
# 한글도 가능합니다만 권장하지는 않습니다.

# %% [markdown]
# ## 데이터 샘플링 및 분석
# > 데이터병합, 인덱스편집, 컬럼선택만으로도 불필요한 정보를 삭제하고 새롭게 데이터셋을 만들 수 있는것을 확인했습니다.
# 위에 학습한 내용도 데이터 샘플링에 속한 내용이지만 지금부터는 데이터셋의 데이터를 살펴보면서 의미있는 데이터를 추려보도록 하겠습니다.
#
# **데이터프레임의 기본적인 인덱싱, 슬라이싱, 조건부 샘플링을 조합하면 데이터의 샘플을 확인 하는 과정만으로도 데이터분석이 가능해집니다.**

# %%
# 분석에 필요한 데이터프레임을 만들었으니 원본값을 사용하겠습니다. 기존 df에 person_df 값을 덮어 씌웁니다.

# %%
# 분석에 필요한 데이터셋을 생성했다면 파일로도 저장 해둡시다.

# %% [markdown]
# ### 저는 채권자의 개인정보에 관심이 많습니다. 고객의 직업을 살펴보겠습니다.

# %%
# emp_title 접근

# %%
# 값을 카운트 하는 함수 value_counts()

# %% [markdown]
# ### 데이터프레임 형변환

# %%
# Owner, owner 같은 직업이지만 대소문자 구분에 따라 다른 값으로 취급되는 문제가 있네요.
# 대소문자 구분을 없애기 위해 모두 소문자로 데이터값을 변경하겠습니다.
# 소문자 변환 전 혹시모를 int, float 데이터가 있을지 모를 상황에 대비해서 모두 문자열로 변경해주겠습니다.
# 형변환 함수 astype(데이터타입)

# %%
# 반복문을 사용한 데이터 변경도 가능
# 하지만 파이썬의 강점을 살리지 못한 코드

# %% [markdown]
# ### 배운사람들의 코드, 고오급 python 스킬
# numpy를 학습하면서 브로드캐스팅에 관하여 잠깐 언급했었습니다. 그렇다면 그 파워풀하다던 브로드캐스팅은 어떻게 사용해야할까요?
#
# >기타 언어에서는 지원하지 않는 기능이니만큼 파이썬의 특징을 가장 잘 살리는 코드
# **`apply`** 함수를 사용하여 인자로 받는 모든 데이터에 함수를 적용

# %% [markdown]
# #### apply 함수로 컬럼에 적용시키는 코드 구조
#     df['컬럼명'] = df['컬럼명'].apply(lambda x: func(x) if 조건문)
#     df['컬럼명'] = df['컬럼명'].apply(func_nm)

# %%
# 대문자 만드는 함수
def make_upper(x):
    return x.upper()

# %%
make_upper('apple')
# Out:
# 'APPLE'

# %%
# apply() 함수사용 반복이 가능한 데이터구조의 모든 인자에 적용
# lambda 각 인자에 적용할 함수 혹은 연산
df = df.astype({'emp_title':'str'})
df['emp_title'].apply(make_upper)
# Out:
# 0                       MECHANIC
# 1                            NAN
# 2                   TRUCK DRIVER
# 3         CONFIDENTIAL SECRETARY
# 4                GENERAL MANAGER
#                   ...
# 19995                    PARTNER
# 19996    SENIOR PROPERTY MANAGER
# 19997          MECHANIC ENGINEER
# 19998                    TEACHER
# 19999         DIRECTOR OF DESIGN
# Name: emp_title, Length: 20000, dtype: object

# %%
# 위 3칸과 같음.
df['emp_title'] = df['emp_title'].apply(lambda x: x.lower())

# %%
# 대소문자 구분을 처리한 값 확인
df['emp_title'].value_counts().head(20)
# 기존 value_count 값과 차이가 있음을 확인 할 수 있습니다.
# 제공 된 데이터셋이라도 이와 같은 작은 차이가 있을 수 있습니다.
# 데이터를 꼼꼼하게 살펴볼 수록 디테일한 차이를 만들 수 있습니다.
# Out:
# nan                   1731
# owner                  474
# manager                414
# teacher                388
# driver                 203
# registered nurse       201
# sales                  182
# supervisor             158
# rn                     139
# truck driver           128
# general manager        113
# office manager         106
# project manager         99
# president               93
# nurse                   79
# director                78
# sales manager           76
# engineer                72
# operations manager      70
# police officer          63
# Name: emp_title, dtype: int64

# %%
# owner인 사람들 샘플링
owner_df=df.loc[df['emp_title']=='owner']

# %%
# 샘플링 된 데이터프레임의 단일 컬럼 접근
owner_df
# Out:
#        loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  \
# 58          6000         6000           5975.0   36 months     15.05
# 176        17525        17525          17525.0   60 months     20.00
# 327         7000         7000           7000.0   36 months     12.62
# 354         8000         8000           8000.0   36 months      6.72
# 362        15000        15000          15000.0   60 months      7.35
# ...          ...          ...              ...         ...       ...
# 19875      10000        10000          10000.0   60 months     20.00
# 19931      20000        20000          20000.0   60 months     17.09
# 19961      28500        28500          28500.0   36 months      9.93
# 19972      11000        11000          11000.0   36 months     11.99
# 19989      25000        25000          25000.0   36 months      9.44
#
#        installment grade sub_grade emp_title emp_length home_ownership  \
# 58          208.14     C        C4     owner  10+ years            OWN
# 176         464.31     D        D4     owner    4 years           RENT
# 327         234.58     C        C1     owner  10+ years           RENT
# 354         246.00     A        A3     owner    5 years           RENT
# 362         299.51     A        A4     owner  10+ years       MORTGAGE
# ...            ...   ...       ...       ...        ...            ...
# 19875       264.94     D        D4     owner    4 years           RENT
# 19931       498.02     D        D1     owner  10+ years            OWN
# 19961       918.68     B        B2     owner    6 years            OWN
# 19972       365.31     B        B5     owner   < 1 year       MORTGAGE
# 19989       800.13     B        B1     owner    8 years       MORTGAGE
#
#        annual_inc verification_status   issue_d  loan_status pymnt_plan  url  \
# 58        55000.0        Not Verified  Dec-2017      Current          n  NaN
# 176        6000.0        Not Verified  Dec-2017   Fully Paid          n  NaN
# 327       72000.0     Source Verified  Dec-2017      Current          n  NaN
# 354       42000.0        Not Verified  Dec-2017      Current          n  NaN
# 362       70000.0        Not Verified  Dec-2017      Current          n  NaN
# ...           ...                 ...       ...          ...        ...  ...
# 19875     24000.0        Not Verified  Dec-2017      Current          n  NaN
# 19931    240000.0     Source Verified  Nov-2017  Charged Off          n  NaN
# 19961     70000.0        Not Verified  Dec-2017      Current          n  NaN
# 19972     45000.0        Not Verified  Nov-2017      Current          n  NaN
# 19989    160000.0     Source Verified  Nov-2017      Current          n  NaN
#
#        desc             purpose                    title zip_code addr_state  \
# 58      NaN  debt_consolidation       Debt consolidation    372xx         TN
# 176     NaN  debt_consolidation       Debt consolidation    320xx         FL
# 327     NaN  debt_consolidation       Debt consolidation    947xx         CA
# 354     NaN         credit_card  Credit card refinancing    329xx         FL
# 362     NaN      small_business                 Business    410xx         KY
# ...     ...                 ...                      ...      ...        ...
# 19875   NaN         credit_card  Credit card refinancing    070xx         NJ
# 19931   NaN    home_improvement         Home improvement    117xx         NY
# 19961   NaN  debt_consolidation       Debt consolidation    750xx         TX
# 19972   NaN      small_business                 Business    184xx         PA
# 19989   NaN    home_improvement         Home improvement    791xx         TX
#
#          dti  delinq_2yrs earliest_cr_line  inq_last_6mths  \
# 58     20.07          1.0         Mar-2004             1.0
# 176    21.40          0.0         Sep-2005             0.0
# 327     7.18          0.0         Apr-2004             0.0
# 354    18.00          0.0         Sep-2002             0.0
# 362    14.44          0.0         Aug-1997             0.0
# ...      ...          ...              ...             ...
# 19875  27.75          0.0         Jun-2012             0.0
# 19931  21.15          0.0         Oct-2004             3.0
# 19961  38.19          0.0         Sep-1992             0.0
# 19972  19.07          1.0         Oct-1998             0.0
# 19989   5.36          0.0         Jan-2004             0.0
#
#        mths_since_last_delinq  mths_since_last_record  open_acc  pub_rec  \
# 58                       12.0                     NaN      11.0      0.0
# 176                      66.0                     NaN       7.0      0.0
# 327                       NaN                     NaN       7.0      0.0
# 354                       NaN                     NaN       5.0      0.0
# 362                       NaN                     NaN      23.0      0.0
# ...                       ...                     ...       ...      ...
# 19875                     NaN                     NaN       8.0      0.0
# 19931                     NaN                    71.0      20.0      1.0
# 19961                     NaN                     NaN       8.0      0.0
# 19972                    19.0                     NaN       7.0      0.0
# 19989                     NaN                     NaN       5.0      0.0
#
#        revol_bal  revol_util  total_acc initial_list_status  out_prncp  \
# 58          4655        14.5       14.0                   f    3980.00
# 176         2600        25.5       11.0                   w       0.00
# 327        11504        68.9       12.0                   w    4585.80
# 354        10369        54.0       13.0                   w    5078.34
# 362         9936         7.4       27.0                   w   11974.50
# ...          ...         ...        ...                 ...        ...
# 19875      18232        61.2       10.0                   w    8464.72
# 19931      38397        53.3       29.0                   f       0.00
# 19961      27339        24.2       22.0                   w   18408.59
# 19972      11041        43.6       26.0                   w    6889.07
# 19989       9488        50.5       15.0                   w   15432.19
#
#        out_prncp_inv   total_pymnt  total_pymnt_inv  total_rec_prncp  \
# 58           3963.41   2903.930000          2891.83          2020.00
# 176             0.00  19794.786529         19794.79         17525.00
# 327          4585.80   3279.210000          3279.21          2414.20
# 354          5078.34   3441.010000          3441.01          2921.66
# 362         11974.50   4180.890000          4180.89          3025.50
# ...              ...           ...              ...              ...
# 19875        8464.72   3686.940000          3686.94          1535.28
# 19931           0.00   3198.600000          3198.60           213.19
# 19961       18408.59  12845.800000         12845.80         10091.41
# 19972        6889.07   5465.000000          5465.00          4110.93
# 19989       15432.19  11975.730000         11975.73          9567.81
#
#        total_rec_int  total_rec_late_fee  recoveries  collection_recovery_fee  \
#
#
#        sec_app_mort_acc  sec_app_open_acc  sec_app_revol_util  \
# 58                  NaN               NaN                 NaN
# 176                 1.0              14.0                37.1
# 327                 NaN               NaN                 NaN
# 354                 NaN               NaN                 NaN
# 362                 NaN               NaN                 NaN
# ...                 ...               ...                 ...
# 19875               NaN               NaN                 NaN
# 19931               NaN               NaN                 NaN
# 19961               NaN               NaN                 NaN
# 19972               NaN               NaN                 NaN
# 19989               NaN               NaN                 NaN
#
#        sec_app_open_act_il  sec_app_num_rev_accts  \
# 58                     NaN                    NaN
# 176                    7.0                   10.0
# 327                    NaN                    NaN
# 354                    NaN                    NaN
# 362                    NaN                    NaN
# ...                    ...                    ...
# 19875                  NaN                    NaN
# 19931                  NaN                    NaN
# 19961                  NaN                    NaN
# 19972                  NaN                    NaN
# 19989                  NaN                    NaN
#
#        sec_app_chargeoff_within_12_mths  sec_app_collections_12_mths_ex_med  \
# 58                                  NaN                                 NaN
# 176                                 0.0                                 0.0
# 327                                 NaN                                 NaN
# 354                                 NaN                                 NaN
# 362                                 NaN                                 NaN
# ...                                 ...                                 ...
# 19875                               NaN                                 NaN
# 19931                               NaN                                 NaN
# 19961                               NaN                                 NaN
# 19972                               NaN                                 NaN
# 19989                               NaN                                 NaN
#
#        sec_app_mths_since_last_major_derog hardship_flag hardship_type  \
# 58                                     NaN             N           NaN
# 176                                   56.0             N           NaN
# 327                                    NaN             N           NaN
# 354                                    NaN             N           NaN
# 362                                    NaN             N           NaN
# ...                                    ...           ...           ...
# 19875                                  NaN             N           NaN
# 19931                                  NaN             N           NaN
# 19961                                  NaN             N           NaN
# 19972                                  NaN             N           NaN
# 19989                                  NaN             N           NaN
#
#       hardship_reason hardship_status  deferral_term  hardship_amount  \
# 58                NaN             NaN            NaN              NaN
# 176               NaN             NaN            NaN              NaN
# 327               NaN             NaN            NaN              NaN
# 354               NaN             NaN            NaN              NaN
# 362               NaN             NaN            NaN              NaN
# ...               ...             ...            ...              ...
# 19875             NaN             NaN            NaN              NaN
# 19931             NaN             NaN            NaN              NaN
# 19961             NaN             NaN            NaN              NaN
# 19972             NaN             NaN            NaN              NaN
# 19989             NaN             NaN            NaN              NaN
#
#       hardship_start_date hardship_end_date payment_plan_start_date  \
# 58                    NaN               NaN                     NaN
# 176                   NaN               NaN                     NaN
# 327                   NaN               NaN                     NaN
# 354                   NaN               NaN                     NaN
# 362                   NaN               NaN                     NaN
# ...                   ...               ...                     ...
# 19875                 NaN               NaN                     NaN
# 19931                 NaN               NaN                     NaN
# 19961                 NaN               NaN                     NaN
# 19972                 NaN               NaN                     NaN
# 19989                 NaN               NaN                     NaN
#
#        hardship_length  hardship_dpd hardship_loan_status  \
# 58                 NaN           NaN                  NaN
# 176                NaN           NaN                  NaN
# 327                NaN           NaN                  NaN
# 354                NaN           NaN                  NaN
# 362                NaN           NaN                  NaN
# ...                ...           ...                  ...
# 19875              NaN           NaN                  NaN
# 19931              NaN           NaN                  NaN
# 19961              NaN           NaN                  NaN
# 19972              NaN           NaN                  NaN
# 19989              NaN           NaN                  NaN
#
#        orig_projected_additional_accrued_interest  \
# 58                                            NaN
# 176                                           NaN
# 327                                           NaN
# 354                                           NaN
# 362                                           NaN
# ...                                           ...
# 19875                                         NaN
# 19931                                         NaN
# 19961                                         NaN
# 19972                                         NaN
# 19989                                         NaN
#
#        hardship_payoff_balance_amount  hardship_last_payment_amount  \
# 58                                NaN                           NaN
# 176                               NaN                           NaN
# 327                               NaN                           NaN
# 354                               NaN                           NaN
# 362                               NaN                           NaN
# ...                               ...                           ...
# 19875                             NaN                           NaN
# 19931                             NaN                           NaN
# 19961                             NaN                           NaN
# 19972                             NaN                           NaN
# 19989                             NaN                           NaN
#
#       disbursement_method debt_settlement_flag debt_settlement_flag_date  \
# 58                   Cash                    N                       NaN
# 176                  Cash                    N                       NaN
# 327                  Cash                    N                       NaN
# 354                  Cash                    N                       NaN
# 362                  Cash                    N                       NaN
# ...                   ...                  ...                       ...
# 19875                Cash                    N                       NaN
# 19931                Cash                    N                       NaN
# 19961                Cash                    N                       NaN
# 19972                Cash                    N                       NaN
# 19989                Cash                    N                       NaN
#
#       settlement_status settlement_date  settlement_amount  \
# 58                  NaN             NaN                NaN
# 176                 NaN             NaN                NaN
# 327                 NaN             NaN                NaN
# 354                 NaN             NaN                NaN
# 362                 NaN             NaN                NaN
# ...                 ...             ...                ...
# 19875               NaN             NaN                NaN
# 19931               NaN             NaN                NaN
# 19961               NaN             NaN                NaN
# 19972               NaN             NaN                NaN
# 19989               NaN             NaN                NaN
#
#        settlement_percentage  settlement_term
# 58                       NaN              NaN
# 176                      NaN              NaN
# 327                      NaN              NaN
# 354                      NaN              NaN
# 362                      NaN              NaN
# ...                      ...              ...
# 19875                    NaN              NaN
# 19931                    NaN              NaN
# 19961                    NaN              NaN
# 19972                    NaN              NaN
# 19989                    NaN              NaN
#
# [474 rows x 143 columns]

# %%
# 컬럼 평균값 계산
owner_df['annual_inc'].mean()
# Out:
# 90019.41139240506

# %%
# 코드 하나 변경으로 간단한 분석 가능
# owner가 아닌 사람들의 평균
df.loc[df['emp_title']!='owner']['annual_inc'].mean()
# Out:
# 78147.9090248899

# %% [markdown]
# ## 데이터 재구조화

# %%
# 각 직업별 평균연봉이 궁금하다 groupby
# 엑셀의 pivol table 과 비슷한 기능
# df.groupby('emp_title').mean()
df.groupby('emp_title').mean()['annual_inc'].sort_values(ascending=False)[:20]
# Out:
# emp_title
# trash truck driver                    6500031.0
# billing analyst                       4784000.0
# tourist guide                         2416960.0
# full-time rn                          1116000.0
# film editor                            988000.0
# manager director fixed income          900000.0
# senior client partner                  850000.0
# terminal operator                      810000.0
# sales & marketing                      741250.0
# senior partner                         712000.0
# partner and managing director          700000.0
# cardiologist                           650000.0
# partner - attorney                     635000.0
# senior trader                          550000.0
# founder ceo                            550000.0
# portfolio manager                      535000.0
# vp valuations                          525000.0
# 1st vice president of wealth mgmt.     512000.0
# orthopaedic surgeon                    500000.0
# chief ops officer                      500000.0
# Name: annual_inc, dtype: float64

# %%
df.columns
# Out:
# Index(['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate',
#        'installment', 'grade', 'sub_grade', 'emp_title', 'emp_length',
#        ...
#        'hardship_payoff_balance_amount', 'hardship_last_payment_amount',
#        'disbursement_method', 'debt_settlement_flag',
#        'debt_settlement_flag_date', 'settlement_status', 'settlement_date',
#        'settlement_amount', 'settlement_percentage', 'settlement_term'],
#       dtype='object', length=143)

# %%
# pivot_table
table = pd.pivot_table(
    df,
    values='int_rate',
    index='grade',
    columns='term',
    aggfunc=len

)

# %%
table
# Out:
# term    36 months   60 months
# grade
# A            4257         204
# B            4621        1689
# C            3168        2178
# D            1626        1394
# E             221         473
# F               7         130
# G               3          29

# %% [markdown]
# ## 결측치 처리
# > 데이터 분석을 위해서는 데이터셋 내에 빈 값이 있는 경우 분석에 방해가 될 수 있는 여지가 많습니다.
# 모든 결측치를 없애야 하는 것은 아니지만 되도록이면 결측치를 채우는 방법, 혹은 없애는 방법등으로 결측치를 처리합니다.
# 몇가지 예시를 살펴보면서 결측치 처리에 대해 알아봅시다.

# %%
# info() 함수는 결측치에 대한 정보도 보여줍니다.
# 컬럼별 isnull() 함수를 사용해도 무방합니다.b
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 143 columns):
#  #    Column                                      Non-Null Count  Dtype
# ---   ------                                      --------------  -----
#  0    loan_amnt                                   20000 non-null  int64
#  1    funded_amnt                                 20000 non-null  int64
#  2    funded_amnt_inv                             20000 non-null  float64
#  3    term                                        20000 non-null  object
#  4    int_rate                                    20000 non-null  float64
#  5    installment                                 20000 non-null  float64
#  6    grade                                       20000 non-null  object
#  7    sub_grade                                   20000 non-null  object
#  8    emp_title                                   20000 non-null  object
#  9    emp_length                                  18296 non-null  object
#  10   home_ownership                              20000 non-null  object
#  11   annual_inc                                  20000 non-null  float64
#  12   verification_status                         20000 non-null  object
#  13   issue_d                                     20000 non-null  object
#  14   loan_status                                 20000 non-null  object
#  15   pymnt_plan                                  20000 non-null  object
#  16   url                                         0 non-null      float64
#  17   desc                                        0 non-null      float64
#  18   purpose                                     20000 non-null  object
#  19   title                                       20000 non-null  object
#  20   zip_code                                    20000 non-null  object
#  21   addr_state                                  20000 non-null  object
#  22   dti                                         19961 non-null  float64
#  23   delinq_2yrs                                 20000 non-null  float64
#  24   earliest_cr_line                            20000 non-null  object
#  25   inq_last_6mths                              20000 non-null  float64
#  26   mths_since_last_delinq                      8992 non-null   float64
#  27   mths_since_last_record                      2914 non-null   float64
#  28   open_acc                                    20000 non-null  float64
#  29   pub_rec                                     20000 non-null  float64
#  30   revol_bal                                   20000 non-null  int64
#  31   revol_util                                  19963 non-null  float64
#  32   total_acc                                   20000 non-null  float64
#  33   initial_list_status                         20000 non-null  object
#  34   out_prncp                                   20000 non-null  float64
#  35   out_prncp_inv                               20000 non-null  float64
#  36   total_pymnt                                 20000 non-null  float64
#  37   total_pymnt_inv                             20000 non-null  float64
#  38   total_rec_prncp                             20000 non-null  float64
#  39   total_rec_int                               20000 non-null  float64
#  40   total_rec_late_fee                          20000 non-null  float64
#  41   recoveries                                  20000 non-null  float64
#  42   collection_recovery_fee                     20000 non-null  float64
#  43   last_pymnt_d                                19970 non-null  object
#  44   last_pymnt_amnt                             20000 non-null  float64
#  45   next_pymnt_d                                15056 non-null  object
#  46   last_credit_pull_d                          20000 non-null  object
#  47   collections_12_mths_ex_med                  20000 non-null  float64
#  48   mths_since_last_major_derog                 4862 non-null   float64
#  49   policy_code                                 20000 non-null  int64
#  50   application_type                            20000 non-null  object
#  51   annual_inc_joint                            2792 non-null   float64
#  52   dti_joint                                   2792 non-null   float64
#  53   verification_status_joint                   2792 non-null   object
#  54   acc_now_delinq                              20000 non-null  float64
#  55   tot_coll_amt                                20000 non-null  float64
#  56   tot_cur_bal                                 20000 non-null  float64
#  57   open_acc_6m                                 20000 non-null  float64
#  58   open_act_il                                 20000 non-null  float64
#  59   open_il_12m                                 20000 non-null  float64
#  60   open_il_24m                                 20000 non-null  float64
#  61   mths_since_rcnt_il                          19242 non-null  float64
#  62   total_bal_il                                20000 non-null  float64
#  63   il_util                                     16740 non-null  float64
#  64   open_rv_12m                                 20000 non-null  float64
#  65   open_rv_24m                                 20000 non-null  float64
#  66   max_bal_bc                                  20000 non-null  float64
#  67   all_util                                    19994 non-null  float64
#  68   total_rev_hi_lim                            20000 non-null  float64
#  69   inq_fi                                      20000 non-null  float64
#  70   total_cu_tl                                 20000 non-null  float64
#  71   inq_last_12m                                20000 non-null  float64
#  72   acc_open_past_24mths                        20000 non-null  float64
#  73   avg_cur_bal                                 19997 non-null  float64
#  74   bc_open_to_buy                              19653 non-null  float64
#  75   bc_util                                     19646 non-null  float64
#  76   chargeoff_within_12_mths                    20000 non-null  float64
#  77   delinq_amnt                                 20000 non-null  float64
#  78   mo_sin_old_il_acct                          19242 non-null  float64
#  79   mo_sin_old_rev_tl_op                        20000 non-null  float64
#  80   mo_sin_rcnt_rev_tl_op                       20000 non-null  float64
#  81   mo_sin_rcnt_tl                              20000 non-null  float64
#  82   mort_acc                                    20000 non-null  float64
#  83   mths_since_recent_bc                        19672 non-null  float64
#  84   mths_since_recent_bc_dlq                    4076 non-null   float64
#  85   mths_since_recent_inq                       17495 non-null  float64
#  86   mths_since_recent_revol_delinq              5889 non-null   float64
#  87   num_accts_ever_120_pd                       20000 non-null  float64
#  88   num_actv_bc_tl                              20000 non-null  float64
#  89   num_actv_rev_tl                             20000 non-null  float64
#  90   num_bc_sats                                 20000 non-null  float64
#  91   num_bc_tl                                   20000 non-null  float64
#  92   num_il_tl                                   20000 non-null  float64
#  93   num_op_rev_tl                               20000 non-null  float64
#  94   num_rev_accts                               20000 non-null  float64
#  95   num_rev_tl_bal_gt_0                         20000 non-null  float64
#  96   num_sats                                    20000 non-null  float64
#  97   num_tl_120dpd_2m                            18819 non-null  float64
#  98   num_tl_30dpd                                20000 non-null  float64
#  99   num_tl_90g_dpd_24m                          20000 non-null  float64
#  100  num_tl_op_past_12m                          20000 non-null  float64
#  101  pct_tl_nvr_dlq                              20000 non-null  float64
#  102  percent_bc_gt_75                            19651 non-null  float64
#  103  pub_rec_bankruptcies                        20000 non-null  float64
#  104  tax_liens                                   20000 non-null  float64
#  105  tot_hi_cred_lim                             20000 non-null  float64
#  106  total_bal_ex_mort                           20000 non-null  float64
#  107  total_bc_limit                              20000 non-null  float64
#  108  total_il_high_credit_limit                  20000 non-null  float64
#  109  revol_bal_joint                             2792 non-null   float64
#  110  sec_app_earliest_cr_line                    2792 non-null   object
#  111  sec_app_inq_last_6mths                      2792 non-null   float64
#  112  sec_app_mort_acc                            2792 non-null   float64
#  113  sec_app_open_acc                            2792 non-null   float64
#  114  sec_app_revol_util                          2745 non-null   float64
#  115  sec_app_open_act_il                         2792 non-null   float64
#  116  sec_app_num_rev_accts                       2792 non-null   float64
#  117  sec_app_chargeoff_within_12_mths            2792 non-null   float64
#  118  sec_app_collections_12_mths_ex_med          2792 non-null   float64
#  119  sec_app_mths_since_last_major_derog         998 non-null    float64
#  120  hardship_flag                               20000 non-null  object
#  121  hardship_type                               64 non-null     object
#  122  hardship_reason                             64 non-null     object
#  123  hardship_status                             64 non-null     object
#  124  deferral_term                               64 non-null     float64
#  125  hardship_amount                             64 non-null     float64
#  126  hardship_start_date                         64 non-null     object
#  127  hardship_end_date                           64 non-null     object
#  128  payment_plan_start_date                     64 non-null     object
#  129  hardship_length                             64 non-null     float64
#  130  hardship_dpd                                64 non-null     float64
#  131  hardship_loan_status                        64 non-null     object
#  132  orig_projected_additional_accrued_interest  50 non-null     float64
#  133  hardship_payoff_balance_amount              64 non-null     float64
#  134  hardship_last_payment_amount                64 non-null     float64
#  135  disbursement_method                         20000 non-null  object
#  136  debt_settlement_flag                        20000 non-null  object
#  137  debt_settlement_flag_date                   61 non-null     object
#  138  settlement_status                           61 non-null     object
#  139  settlement_date                             61 non-null     object
#  140  settlement_amount                           61 non-null     float64
#  141  settlement_percentage                       61 non-null     float64
#  142  settlement_term                             61 non-null     float64
# dtypes: float64(104), int64(4), object(35)
# memory usage: 21.8+ MB

# %%
df.loc[df['dti'].isnull(), 'dti']

# %% [markdown]
#     확인결과 emp_title, emp_length, dti에 결측치가 존재합니다.
#     해당 컬럼의 결측치 샘플들을 살펴보고 결측치를 처리해 보겠습니다.

# %%
# 컬럼별 결측치 확인을 위한 isnull()함수 리턴값이 bool 형태로 반환되어 조건부 샘플링이 가능합니다.
df['dti'].isnull().sum()/len(df) * 100
# Out:
# 0.19499999999999998

# %%
# dti 컬럼에 결측치가 존재하는 샘플 확인

# %% [markdown]
#     직업과 근속연수에 관한 부분은 데이터를 통한 유추나 계산값을 통해 채워넣을 수 있는 항목은 아닌 것 같습니다.
#     다만 dti의 경우 실수로 채워져 있는 부분이니 수업을 위해 평균값 혹은 근사치를 계산하여 채워보도록 하겠습니다.

# %% [markdown]
# ### 결측치 채우기

# %%
# fillna() 함수로 NaN 값을 dti 컬럼의 평균으로 채우기
df['dti'].fillna(df['dti'].mean(), inplace=True)
# fillna() 함수의 다양한 채우기 방법 파라메터 확인해보기
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21856/298508487.py in <module>
#       1 # fillna() 함수로 NaN 값을 dti 컬럼의 평균으로 채우기
# ----> 2 df['dti'].fillna(df['dti'].mean()).info
#       3 # fillna() 함수의 다양한 채우기 방법 파라메터 확인해보기
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'info'

# %% [markdown]
# ### 결측치 제거

# %%
# emp_title 결측치가 있는 샘플 확인
df.loc[df['emp_title'].isna()]
# Out:
# Empty DataFrame
# Columns: [loan_amnt, funded_amnt, funded_amnt_inv, term, int_rate, installment, grade, sub_grade, emp_title, emp_length, home_ownership, annual_inc, verification_status, issue_d, loan_status, pymnt_plan, url, desc, purpose, title, zip_code, addr_state, dti, delinq_2yrs, earliest_cr_line, inq_last_6mths, mths_since_last_delinq, mths_since_last_record, open_acc, pub_rec, revol_bal, revol_util, total_acc, initial_list_status, out_prncp, out_prncp_inv, total_pymnt, total_pymnt_inv, total_rec_prncp, total_rec_int, total_rec_late_fee, recoveries, collection_recovery_fee, last_pymnt_d, last_pymnt_amnt, next_pymnt_d, last_credit_pull_d, collections_12_mths_ex_med, mths_since_last_major_derog, policy_code, application_type, annual_inc_joint, dti_joint, verification_status_joint, acc_now_delinq, tot_coll_amt, tot_cur_bal, open_acc_6m, open_act_il, open_il_12m, open_il_24m, mths_since_rcnt_il, total_bal_il, il_util, open_rv_12m, open_rv_24m, max_bal_bc, all_util, total_rev_hi_lim, inq_fi, total_cu_tl, inq_last_12m, acc_open_past_24mths, avg_cur_bal, bc_open_to_buy, bc_util, chargeoff_within_12_mths, delinq_amnt, mo_sin_old_il_acct, mo_sin_old_rev_tl_op, mo_sin_rcnt_rev_tl_op, mo_sin_rcnt_tl, mort_acc, mths_since_recent_bc, mths_since_recent_bc_dlq, mths_since_recent_inq, mths_since_recent_revol_delinq, num_accts_ever_120_pd, num_actv_bc_tl, num_actv_rev_tl, num_bc_sats, num_bc_tl, num_il_tl, num_op_rev_tl, num_rev_accts, num_rev_tl_bal_gt_0, num_sats, num_tl_120dpd_2m, num_tl_30dpd, num_tl_90g_dpd_24m, ...]
# Index: []

# %%
# view값으로 dropna 결과값 확인
df.dropna()
# Out:
# Empty DataFrame
# Columns: [loan_amnt, funded_amnt, funded_amnt_inv, term, int_rate, installment, grade, sub_grade, emp_title, emp_length, home_ownership, annual_inc, verification_status, issue_d, loan_status, pymnt_plan, url, desc, purpose, title, zip_code, addr_state, dti, delinq_2yrs, earliest_cr_line, inq_last_6mths, mths_since_last_delinq, mths_since_last_record, open_acc, pub_rec, revol_bal, revol_util, total_acc, initial_list_status, out_prncp, out_prncp_inv, total_pymnt, total_pymnt_inv, total_rec_prncp, total_rec_int, total_rec_late_fee, recoveries, collection_recovery_fee, last_pymnt_d, last_pymnt_amnt, next_pymnt_d, last_credit_pull_d, collections_12_mths_ex_med, mths_since_last_major_derog, policy_code, application_type, annual_inc_joint, dti_joint, verification_status_joint, acc_now_delinq, tot_coll_amt, tot_cur_bal, open_acc_6m, open_act_il, open_il_12m, open_il_24m, mths_since_rcnt_il, total_bal_il, il_util, open_rv_12m, open_rv_24m, max_bal_bc, all_util, total_rev_hi_lim, inq_fi, total_cu_tl, inq_last_12m, acc_open_past_24mths, avg_cur_bal, bc_open_to_buy, bc_util, chargeoff_within_12_mths, delinq_amnt, mo_sin_old_il_acct, mo_sin_old_rev_tl_op, mo_sin_rcnt_rev_tl_op, mo_sin_rcnt_tl, mort_acc, mths_since_recent_bc, mths_since_recent_bc_dlq, mths_since_recent_inq, mths_since_recent_revol_delinq, num_accts_ever_120_pd, num_actv_bc_tl, num_actv_rev_tl, num_bc_sats, num_bc_tl, num_il_tl, num_op_rev_tl, num_rev_accts, num_rev_tl_bal_gt_0, num_sats, num_tl_120dpd_2m, num_tl_30dpd, num_tl_90g_dpd_24m, ...]
# Index: []

# %%
# 결측치 제거
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 143 columns):
#  #    Column                                      Non-Null Count  Dtype
# ---   ------                                      --------------  -----
#  0    loan_amnt                                   20000 non-null  int64
#  1    funded_amnt                                 20000 non-null  int64
#  2    funded_amnt_inv                             20000 non-null  float64
#  3    term                                        20000 non-null  object
#  4    int_rate                                    20000 non-null  float64
#  5    installment                                 20000 non-null  float64
#  6    grade                                       20000 non-null  object
#  7    sub_grade                                   20000 non-null  object
#  8    emp_title                                   20000 non-null  object
#  9    emp_length                                  18296 non-null  object
#  10   home_ownership                              20000 non-null  object
#  11   annual_inc                                  20000 non-null  float64
#  12   verification_status                         20000 non-null  object
#  13   issue_d                                     20000 non-null  object
#  14   loan_status                                 20000 non-null  object
#  15   pymnt_plan                                  20000 non-null  object
#  16   url                                         0 non-null      float64
#  17   desc                                        0 non-null      float64
#  18   purpose                                     20000 non-null  object
#  19   title                                       20000 non-null  object
#  20   zip_code                                    20000 non-null  object
#  21   addr_state                                  20000 non-null  object
#  22   dti                                         19961 non-null  float64
#  23   delinq_2yrs                                 20000 non-null  float64
#  24   earliest_cr_line                            20000 non-null  object
#  25   inq_last_6mths                              20000 non-null  float64
#  26   mths_since_last_delinq                      8992 non-null   float64
#  27   mths_since_last_record                      2914 non-null   float64
#  28   open_acc                                    20000 non-null  float64
#  29   pub_rec                                     20000 non-null  float64
#  30   revol_bal                                   20000 non-null  int64
#  31   revol_util                                  19963 non-null  float64
#  32   total_acc                                   20000 non-null  float64
#  33   initial_list_status                         20000 non-null  object
#  34   out_prncp                                   20000 non-null  float64
#  35   out_prncp_inv                               20000 non-null  float64
#  36   total_pymnt                                 20000 non-null  float64
#  37   total_pymnt_inv                             20000 non-null  float64
#  38   total_rec_prncp                             20000 non-null  float64
#  39   total_rec_int                               20000 non-null  float64
#  40   total_rec_late_fee                          20000 non-null  float64
#  41   recoveries                                  20000 non-null  float64
#  42   collection_recovery_fee                     20000 non-null  float64
#  43   last_pymnt_d                                19970 non-null  object
#  44   last_pymnt_amnt                             20000 non-null  float64
#  45   next_pymnt_d                                15056 non-null  object
#  46   last_credit_pull_d                          20000 non-null  object
#  47   collections_12_mths_ex_med                  20000 non-null  float64
#  48   mths_since_last_major_derog                 4862 non-null   float64
#  49   policy_code                                 20000 non-null  int64
#  50   application_type                            20000 non-null  object
#  51   annual_inc_joint                            2792 non-null   float64
#  52   dti_joint                                   2792 non-null   float64
#  53   verification_status_joint                   2792 non-null   object
#  54   acc_now_delinq                              20000 non-null  float64
#  55   tot_coll_amt                                20000 non-null  float64
#  56   tot_cur_bal                                 20000 non-null  float64
#  57   open_acc_6m                                 20000 non-null  float64
#  58   open_act_il                                 20000 non-null  float64
#  59   open_il_12m                                 20000 non-null  float64
#  60   open_il_24m                                 20000 non-null  float64
#  61   mths_since_rcnt_il                          19242 non-null  float64
#  62   total_bal_il                                20000 non-null  float64
#  63   il_util                                     16740 non-null  float64
#  64   open_rv_12m                                 20000 non-null  float64
#  65   open_rv_24m                                 20000 non-null  float64
#  66   max_bal_bc                                  20000 non-null  float64
#  67   all_util                                    19994 non-null  float64
#  68   total_rev_hi_lim                            20000 non-null  float64
#  69   inq_fi                                      20000 non-null  float64
#  70   total_cu_tl                                 20000 non-null  float64
#  71   inq_last_12m                                20000 non-null  float64
#  72   acc_open_past_24mths                        20000 non-null  float64
#  73   avg_cur_bal                                 19997 non-null  float64
#  74   bc_open_to_buy                              19653 non-null  float64
#  75   bc_util                                     19646 non-null  float64
#  76   chargeoff_within_12_mths                    20000 non-null  float64
#  77   delinq_amnt                                 20000 non-null  float64
#  78   mo_sin_old_il_acct                          19242 non-null  float64
#  79   mo_sin_old_rev_tl_op                        20000 non-null  float64
#  80   mo_sin_rcnt_rev_tl_op                       20000 non-null  float64
#  81   mo_sin_rcnt_tl                              20000 non-null  float64
#  82   mort_acc                                    20000 non-null  float64
#  83   mths_since_recent_bc                        19672 non-null  float64
#  84   mths_since_recent_bc_dlq                    4076 non-null   float64
#  85   mths_since_recent_inq                       17495 non-null  float64
#  86   mths_since_recent_revol_delinq              5889 non-null   float64
#  87   num_accts_ever_120_pd                       20000 non-null  float64
#  88   num_actv_bc_tl                              20000 non-null  float64
#  89   num_actv_rev_tl                             20000 non-null  float64
#  90   num_bc_sats                                 20000 non-null  float64
#  91   num_bc_tl                                   20000 non-null  float64
#  92   num_il_tl                                   20000 non-null  float64
#  93   num_op_rev_tl                               20000 non-null  float64
#  94   num_rev_accts                               20000 non-null  float64
#  95   num_rev_tl_bal_gt_0                         20000 non-null  float64
#  96   num_sats                                    20000 non-null  float64
#  97   num_tl_120dpd_2m                            18819 non-null  float64
#  98   num_tl_30dpd                                20000 non-null  float64
#  99   num_tl_90g_dpd_24m                          20000 non-null  float64
#  100  num_tl_op_past_12m                          20000 non-null  float64
#  101  pct_tl_nvr_dlq                              20000 non-null  float64
#  102  percent_bc_gt_75                            19651 non-null  float64
#  103  pub_rec_bankruptcies                        20000 non-null  float64
#  104  tax_liens                                   20000 non-null  float64
#  105  tot_hi_cred_lim                             20000 non-null  float64
#  106  total_bal_ex_mort                           20000 non-null  float64
#  107  total_bc_limit                              20000 non-null  float64
#  108  total_il_high_credit_limit                  20000 non-null  float64
#  109  revol_bal_joint                             2792 non-null   float64
#  110  sec_app_earliest_cr_line                    2792 non-null   object
#  111  sec_app_inq_last_6mths                      2792 non-null   float64
#  112  sec_app_mort_acc                            2792 non-null   float64
#  113  sec_app_open_acc                            2792 non-null   float64
#  114  sec_app_revol_util                          2745 non-null   float64
#  115  sec_app_open_act_il                         2792 non-null   float64
#  116  sec_app_num_rev_accts                       2792 non-null   float64
#  117  sec_app_chargeoff_within_12_mths            2792 non-null   float64
#  118  sec_app_collections_12_mths_ex_med          2792 non-null   float64
#  119  sec_app_mths_since_last_major_derog         998 non-null    float64
#  120  hardship_flag                               20000 non-null  object
#  121  hardship_type                               64 non-null     object
#  122  hardship_reason                             64 non-null     object
#  123  hardship_status                             64 non-null     object
#  124  deferral_term                               64 non-null     float64
#  125  hardship_amount                             64 non-null     float64
#  126  hardship_start_date                         64 non-null     object
#  127  hardship_end_date                           64 non-null     object
#  128  payment_plan_start_date                     64 non-null     object
#  129  hardship_length                             64 non-null     float64
#  130  hardship_dpd                                64 non-null     float64
#  131  hardship_loan_status                        64 non-null     object
#  132  orig_projected_additional_accrued_interest  50 non-null     float64
#  133  hardship_payoff_balance_amount              64 non-null     float64
#  134  hardship_last_payment_amount                64 non-null     float64
#  135  disbursement_method                         20000 non-null  object
#  136  debt_settlement_flag                        20000 non-null  object
#  137  debt_settlement_flag_date                   61 non-null     object
#  138  settlement_status                           61 non-null     object
#  139  settlement_date                             61 non-null     object
#  140  settlement_amount                           61 non-null     float64
#  141  settlement_percentage                       61 non-null     float64
#  142  settlement_term                             61 non-null     float64
# dtypes: float64(104), int64(4), object(35)
# memory usage: 21.8+ MB
